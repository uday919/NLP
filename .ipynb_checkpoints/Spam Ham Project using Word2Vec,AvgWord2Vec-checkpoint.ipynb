# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /opt/anaconda3/lib/python3.11/site-packages (4.3.0)
# Requirement already satisfied: numpy>=1.18.5 in /opt/anaconda3/lib/python3.11/site-packages (from gensim) (1.24.4)
# Requirement already satisfied: scipy>=1.7.0 in /opt/anaconda3/lib/python3.11/site-packages (from gensim) (1.10.1)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/anaconda3/lib/python3.11/site-packages (from gensim) (5.2.1)
# Requirement already satisfied: FuzzyTM>=0.4.0 in /opt/anaconda3/lib/python3.11/site-packages (from gensim) (2.0.9)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.11/site-packages (from FuzzyTM>=0.4.0->gensim) (1.5.3)
# Requirement already satisfied: pyfume in /opt/anaconda3/lib/python3.11/site-packages (from FuzzyTM>=0.4.0->gensim) (0.3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2023.3.post1)
# Requirement already satisfied: simpful==2.12.0 in /opt/anaconda3/lib/python3.11/site-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (2.12.0)
# Requirement already satisfied: fst-pso==1.8.1 in /opt/anaconda3/lib/python3.11/site-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (1.8.1)
# Requirement already satisfied: miniful in /opt/anaconda3/lib/python3.11/site-packages (from fst-pso==1.8.1->pyfume->FuzzyTM>=0.4.0->gensim) (0.0.6)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas->FuzzyTM>=0.4.0->gensim) (1.16.0)

# %%
import gensim
from gensim.models import Word2Vec,KeyedVectors

# %%
import gensim.downloader as api
wv=api.load('word2vec-google-news-300')
vec_king=wv['king']

# %%
vec_king.shape
# Out:
# (300,)

# %%
import pandas as pd
messages=pd.read_csv('SMSSpamCollection.txt',sep='\t',names=["label","message"])

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()

# %%
import re
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/udaykiran/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
corpus=[]
for i in range(0,len(messages)):
    review=re.sub('[^a-zA-z]',' ',messages['message'][i])
    review=review.lower()
    review=review.split()
    review=[lemmatizer.lemmatize(word) for word in review]
    review=' '.join(review)
    corpus.append(review)

# %%
[[i,j,k] for i,j,k in zip(list(map(len,corpus)),corpus, messages['message']) if i<1]
# Out:
# [[0, '', '645'], [0, '', ':) '], [0, '', ':-) :-)']]

# %%
corpus
# Out:
# ['go until jurong point crazy available only in bugis n great world la e buffet cine there got amore wat',
#  'ok lar joking wif u oni',
#  'free entry in a wkly comp to win fa cup final tkts st may text fa to to receive entry question std txt rate t c s apply over s',
#  'u dun say so early hor u c already then say',
#  'nah i don t think he go to usf he life around here though',
#  'freemsg hey there darling it s been week s now and no word back i d like some fun you up for it still tb ok xxx std chgs to send to rcv',
#  'even my brother is not like to speak with me they treat me like aid patent',
#  'a per your request melle melle oru minnaminunginte nurungu vettam ha been set a your callertune for all caller press to copy your friend callertune',
#  'winner a a valued network customer you have been selected to receivea prize reward to claim call claim code kl valid hour only',
#  'had your mobile month or more u r entitled to update to the latest colour mobile with camera for free call the mobile update co free on',
#  'i m gonna be home soon and i don t want to talk about this stuff anymore tonight k i ve cried enough today',
#  'six chance to win cash from to pound txt csh and send to cost p day day tsandcs apply reply hl info',
#  'urgent you have won a week free membership in our prize jackpot txt the word claim to no t c www dbuk net lccltd pobox ldnw a rw',
#  'i ve been searching for the right word to thank you for this breather i promise i wont take your help for granted and will fulfil my promise you have been wonderful and a blessing at all time',
#  'i have a date on sunday with will',
#  'xxxmobilemovieclub to use your credit click the wap link in the next txt message or click here http wap xxxmobilemovieclub com n qjkgighjjgcbl',
#  'oh k i m watching here',
#  'eh u remember how spell his name yes i did he v naughty make until i v wet',
#  'fine if that s the way u feel that s the way it gota b',
#  'england v macedonia dont miss the goal team news txt ur national team to eg england to try wale scotland txt poboxox w wq',
#  'is that seriously how you spell his name',
#  'i m going to try for month ha ha only joking',
#  'so pay first lar then when is da stock comin',
#  'aft i finish my lunch then i go str down lor ard smth lor u finish ur lunch already',
#  'ffffffffff alright no way i can meet up with you sooner',
#  'just forced myself to eat a slice i m really not hungry tho this suck mark is getting worried he know i m sick when i turn down pizza lol',
#  'lol your always so convincing',
#  'did you catch the bus are you frying an egg did you make a tea are you eating your mom s left over dinner do you feel my love',
#  'i m back amp we re packing the car now i ll let you know if there s room',
#  'ahhh work i vaguely remember that what doe it feel like lol',
#  'wait that s still not all that clear were you not sure about me being sarcastic or that that s why x doesn t want to live with u',
#  'yeah he got in at and wa v apologetic n had fallen out and she wa actin like spoilt child and he got caught up in that till but we won t go there not doing too badly cheer you',
#  'k tell me anything about you',
#  'for fear of fainting with the of all that housework you just did quick have a cuppa',
#  'thanks for your subscription to ringtone uk your mobile will be charged month please confirm by replying yes or no if you reply no you will not be charged',
#  'yup ok i go home look at the timing then i msg again xuhui going to learn on nd may too but her lesson is at am',
#  'oops i ll let you know when my roommate s done',
#  'i see the letter b on my car',
#  'anything lor u decide',
#  'hello how s you and how did saturday go i wa just texting to see if you d decided to do anything tomo not that i m trying to invite myself or anything',
#  'pls go ahead with watt i just wanted to be sure do have a great weekend abiola',
#  'did i forget to tell you i want you i need you i crave you but most of all i love you my sweet arabian steed mmmmmm yummy',
#  'rodger burn msg we tried to call you re your reply to our sm for a free nokia mobile free camcorder please call now for delivery tomorrow',
#  'who are you seeing',
#  'great i hope you like your man well endowed i am lt gt inch',
#  'no call message missed call',
#  'didn t you get hep b immunisation in nigeria',
#  'fair enough anything going on',
#  'yeah hopefully if tyler can t do it i could maybe ask around a bit',
#  'u don t know how stubborn i am i didn t even want to go to the hospital i kept telling mark i m not a weak sucker hospital are for weak sucker',
#  'what you thinked about me first time you saw me in class',
#  'a gram usually run like lt gt a half eighth is smarter though and get you almost a whole second gram for lt gt',
#  'k fyi x ha a ride early tomorrow morning but he s crashing at our place tonight',
#  'wow i never realized that you were so embarassed by your accomodations i thought you liked it since i wa doing the best i could and you always seemed so happy about the cave i m sorry i didn t and don t have more to give i m sorry i offered i m sorry your room wa so embarassing',
#  'sm ac sptv the new jersey devil and the detroit red wing play ice hockey correct or incorrect end reply end sptv',
#  'do you know what mallika sherawat did yesterday find out now lt url gt',
#  'congrats year special cinema pas for is yours call now c suprman v matrix starwars etc all free bx ip we pm dont miss out',
#  'sorry i ll call later in meeting',
#  'tell where you reached',
#  'yes gauti and sehwag out of odi series',
#  'your gonna have to pick up a burger for yourself on your way home i can t even move pain is killing me',
#  'ha ha ha good joke girl are situation seeker',
#  'it a part of checking iq',
#  'sorry my roommate took forever it ok if i come by now',
#  'ok lar i double check wif da hair dresser already he said wun cut v short he said will cut until i look nice',
#  'a a valued customer i am pleased to advise you that following recent review of your mob no you are awarded with a bonus prize call',
#  'today is song dedicated day which song will u dedicate for me send this to all ur valuable frnds but first rply me',
#  'urgent ur awarded a complimentary trip to eurodisinc trav aco entry or to claim txt dis to morefrmmob shracomorsglsuplt l aj',
#  'did you hear about the new divorce barbie it come with all of ken s stuff',
#  'i plane to give on this month end',
#  'wah lucky man then can save money hee',
#  'finished class where are you',
#  'hi babe im at home now wanna do something xx',
#  'k k where are you how did you performed',
#  'u can call me now',
#  'i am waiting machan call me once you free',
#  'thats cool i am a gentleman and will treat you with dignity and respect',
#  'i like you people very much but am very shy pa',
#  'doe not operate after lt gt or what',
#  'it not the same here still looking for a job how much do ta s earn there',
#  'sorry i ll call later',
#  'k did you call me just now ah',
#  'ok i am on the way to home hi hi',
#  'you will be in the place of that man',
#  'yup next stop',
#  'i call you later don t have network if urgnt sm me',
#  'for real when u getting on yo i only need more ticket and one more jacket and i m done i already used all my multis',
#  'yes i started to send request to make it but pain came back so i m back in bed double coin at the factory too i gotta cash in all my nitros',
#  'i m really not up to it still tonight babe',
#  'ela kano il download come wen ur free',
#  'yeah do don t stand to close tho you ll catch something',
#  'sorry to be a pain is it ok if we meet another night i spent late afternoon in casualty and that mean i haven t done any of y stuff moro and that includes all my time sheet and that sorry',
#  'smile in pleasure smile in pain smile when trouble pours like rain smile when sum hurt u smile becoz someone still love to see u smiling',
#  'please call our customer service representative on between am pm a you have won a guaranteed cash or prize',
#  'havent planning to buy later i check already lido only got show in e afternoon u finish work already',
#  'your free ringtone is waiting to be collected simply text the password mix to to verify get usher and britney fml po box mk h ppw',
#  'watching telugu movie wat abt u',
#  'i see when we finish we have load of loan to pay',
#  'hi wk been ok on hols now yes on for a bit of a run forgot that i have hairdresser appointment at four so need to get home n shower beforehand doe that cause prob for u',
#  'i see a cup of coffee animation',
#  'please don t text me anymore i have nothing else to say',
#  'okay name ur price a long a it legal wen can i pick them up y u ave x am xx',
#  'i m still looking for a car to buy and have not gone the driving test yet',
#  'a per your request melle melle oru minnaminunginte nurungu vettam ha been set a your callertune for all caller press to copy your friend callertune',
#  'wow you re right i didn t mean to do that i guess once i gave up on boston men and changed my search location to nyc something changed cuz on my signin page it still say boston',
#  'umma my life and vava umma love you lot dear',
#  'thanks a lot for your wish on my birthday thanks you for making my birthday truly memorable',
#  'aight i ll hit you up when i get some cash',
#  'how would my ip address test that considering my computer isn t a minecraft server',
#  'i know grumpy old people my mom wa like you better not be lying then again i am always the one to play joke',
#  'dont worry i guess he s busy',
#  'what is the plural of the noun research',
#  'going for dinner msg you after',
#  'i m ok wif it co i like try new thing but i scared u dun like mah co u said not too loud',
#  'gent we are trying to contact you last weekend draw show that you won a prize guaranteed call claim code k valid hr only ppm',
#  'wa ur openin sentence very formal anyway i m fine too juz tt i m eatin too much n puttin on weight haha so anythin special happened',
#  'a i entered my cabin my pa said happy b day bos i felt special she askd me lunch after lunch she invited me to her apartment we went there',
#  'you are a winner u have been specially selected receive or a holiday flight inc speak to a live operator claim p min',
#  'goodo yes we must speak friday egg potato ratio for tortilla needed',
#  'hmm my uncle just informed me that he s paying the school directly so pls buy food',
#  'private your account statement for show unredeemed bonus point to claim call identifier code expires',
#  'urgent your mobile no wa awarded bonus caller prize on this is our final try to contact u call from landline box wr c ppm',
#  'here is my new address apple pair all that malarky',
#  'today voda number ending are selected to receive a award if you have a match please call quoting claim code standard rate app',
#  'i am going to sao mu today will be done only at',
#  'predict wat time ll finish buying',
#  'good stuff will do',
#  'just so that you know yetunde hasn t sent money yet i just sent her a text not to bother sending so it over you dont have to involve yourself in anything i shouldn t have imposed anything on you in the first place so for that i apologise',
#  'are you there in room',
#  'hey girl how r u hope u r well me an del r bak again long time no c give me a call sum time from lucyxx',
#  'k k how much doe it cost',
#  'i m home',
#  'dear will call tmorrow pls accomodate',
#  'first answer my question',
#  'sunshine quiz wkly q win a top sony dvd player if u know which country the algarve is in txt ansr to sp tyrone',
#  'want get laid tonight want real dogging location sent direct ur mob join the uk s largest dogging network bt txting gravel to nt ec a p msg p',
#  'i only haf msn it s yijue hotmail com',
#  'he is there you call and meet him',
#  'no no i will check all room befor activity',
#  'you ll not rcv any more msg from the chat svc for free hardcore service text go to if u get nothing u must age verify with yr network try again',
#  'got c i lazy to type i forgot in lect i saw a pouch but like not v nice',
#  'k text me when you re on the way',
#  'sir waiting for your mail',
#  'a swt thought nver get tired of doing little thing lovable person coz somtimes those little thing occupy d biggest part in their heart gud ni',
#  'i know you are can you pls open the back',
#  'yes see ya not on the dot',
#  'whats the staff name who is taking class for u',
#  'freemsg why haven t you replied to my text i m randy sexy female and live local luv to hear from u netcollex ltd p per msg reply stop to end',
#  'ummma will call after check in our life will begin from qatar so pls pray very hard',
#  'k i deleted my contact that why',
#  'sindu got job in birla soft',
#  'the wine is flowing and i m i have nevering',
#  'yup i thk cine is better co no need go down plaza mah',
#  'ok ur typical reply',
#  'a per your request melle melle oru minnaminunginte nurungu vettam ha been set a your callertune for all caller press to copy your friend callertune',
#  'you are everywhere dirt on the floor the window even on my shirt and sometimes when i open my mouth you are all that come flowing out i dream of my world without you then half my chore are out too a time of joy for me lot of tv show i ll see but i guess like all thing you just must exist like rain hail and mist and when my time here is done you and i become one',
#  'aaooooright are you at work',
#  'i m leaving my house now',
#  'hello my love what are you doing did you get to that interview today are you you happy are you being a good boy do you think of me are you missing me',
#  'customer service annoncement you have a new year delivery waiting for you please call now to arrange delivery',
#  'you are a winner u have been specially selected receive cash or a holiday flight inc speak to a live operator claim',
#  'keep yourself safe for me because i need you and i miss you already and i envy everyone that see s you in real life',
#  'new car and house for my parent i have only new job in hand',
#  'i m so in love with you i m excited each day i spend with you you make me so happy',
#  'pls stop bootydelious f is inviting you to be her friend reply yes or no see her www sm ac u bootydelious stop send stop frnd to',
#  'bangbabes ur order is on the way u should receive a service msg download ur content if u do not goto wap bangb tv on ur mobile internet service menu',
#  'i place all ur point on e culture module already',
#  'urgent we are trying to contact you last weekend draw show that you have won a prize guaranteed call claim code s valid hr only',
#  'hi frnd which is best way to avoid missunderstding wit our beloved one s',
#  'great escape i fancy the bridge but need her lager see you tomo',
#  'yes it completely in out of form clark also utter waste',
#  'sir i need axis bank account no and bank address',
#  'hmmm thk sure got time to hop ard ya can go free abt muz call u to discus liao',
#  'what time you coming down later',
#  'bloody hell cant believe you forgot my surname mr ill give u a clue it spanish and begin with m',
#  'well i m gonna finish my bath now have a good fine night',
#  'let me know when you ve got the money so carlos can make the call',
#  'u still going to the mall',
#  'turn out my friend are staying for the whole show and won t be back til lt gt so feel free to go ahead and smoke that lt gt worth',
#  'text her if she doesnt reply let me know so i can have her log in',
#  'hi you just spoke to maneesha v we d like to know if you were satisfied with the experience reply toll free with yes or no',
#  'you lifted my hope with the offer of money i am in need especially when the end of the month approach and it hurt my studying anyways have a gr weekend',
#  'lol no u can trust me',
#  'ok i am a gentleman and will treat you with dignity and respect',
#  'he will you guy close',
#  'going on nothing great bye',
#  'hello handsome are you finding that job not being lazy working towards getting back that net for mummy where s my boytoy now doe he miss me',
#  'haha awesome be there in a minute',
#  'please call our customer service representative on freephone between am pm a you have won a guaranteed cash or prize',
#  'have you got xmas radio time if not i will get it now',
#  'i jus reached home i go bathe first but my si using net tell u when she finish k',
#  'are you unique enough find out from th august www areyouunique co uk',
#  'i m sorry i ve joined the league of people that dont keep in touch you mean a great deal to me you have been a friend at all time even at great personal cost do have a great week',
#  'hi finally i completed the course',
#  'it will stop on itself i however suggest she stay with someone that will be able to give or for every stool',
#  'how are you doing hope you ve settled in for the new school year just wishin you a gr day',
#  'gud mrng dear hav a nice day',
#  'did u got that person story',
#  'is your hamster dead hey so tmr i meet you at pm orchard mrt',
#  'hi it kate how is your evening i hope i can see you tomorrow for a bit but i have to bloody babyjontet txt back if u can xxx',
#  'found it enc lt gt where you at',
#  'i sent you lt gt buck',
#  'hello darlin ive finished college now so txt me when u finish if u can love kate xxx',
#  'your account ha been refilled successfully by inr lt decimal gt your keralacircle prepaid account balance is r lt decimal gt your transaction id is kr lt gt',
#  'goodmorning sleeping ga',
#  'u call me alter at ok',
#  'say until like dat i dun buy ericsson oso cannot oredi lar',
#  'a i entered my cabin my pa said happy b day bos i felt special she askd me lunch after lunch she invited me to her apartment we went there',
#  'aight yo dat straight dogg',
#  'you please give u connection today itself before lt decimal gt or refund the bill',
#  'both i shoot big load so get ready',
#  'what s up bruv hope you had a great break do have a rewarding semester',
#  'home so we can always chat',
#  'k k good study well',
#  'yup how noe leh',
#  'sound great are you home now',
#  'finally the match heading towards draw a your prediction',
#  'tired i haven t slept well the past few night',
#  'easy ah sen got selected mean it good',
#  'i have to take exam with march',
#  'yeah you should i think you can use your gt atm now to register not sure but if there s anyway i can help let me know but when you do be sure you are ready',
#  'ok no prob take ur time',
#  'there is o called ubandu which will run without installing in hard disk you can use that o to copy the important file in system and give it to repair shop',
#  'sorry i ll call later',
#  'u say leh of course nothing happen lar not say v romantic jus a bit only lor i thk e nite scenery not so nice leh',
#  'new mobile from must go txt nokia to no collect yours today from only www tc biz optout gbp mtmsg',
#  'would really appreciate if you call me just need someone to talk to',
#  'will u meet ur dream partner soon is ur career off a flyng start find out free txt horo followed by ur star sign e g horo aries',
#  'hey company elama po mudyadhu',
#  'life is more strict than teacher bcoz teacher teach lesson amp then conduct exam but life first conduct exam amp then teach lesson happy morning',
#  'dear good morning now only i am up',
#  'get down in gandhipuram and walk to cross cut road right side lt gt street road and turn at first right',
#  'dear we are going to our rubber place',
#  'sorry battery died yeah i m here',
#  'yes here tv is always available in work place',
#  'text meet someone sexy today u can find a date or even flirt it up to u join just p reply with name age eg sam msg recd thirtyeight penny',
#  'i have printed it oh so lt gt come upstairs',
#  'or ill be a little closer like at the bus stop on the same street',
#  'where are you when wil you reach here',
#  'new theory argument win d situation but loses the person so dont argue with ur friend just kick them amp say i m always correct',
#  'u have a secret admirer who is looking make contact with u find out who they r reveal who think ur so special call on',
#  'tomarrow final hearing on my laptop case so i cant',
#  'pleassssssseeeeee tel me v avent done sportsx',
#  'okay no no just shining on that wa meant to be signing but that sound better',
#  'although i told u dat i m into baig face watch now but i really like e watch u gave co it s fr u thanx everything dat u ve done today i m touched',
#  'u don t remember that old commercial',
#  'too late i said i have the website i didn t i have or dont have the slipper',
#  'i asked you to call him now ok',
#  'kallis wont bat in nd inning',
#  'it didnt work again oh ok goodnight then i ll fix and have it ready by the time you wake up you are very dearly missed have a good night sleep',
#  'congratulation ur awarded of cd voucher or gift guaranteed free entry wkly draw txt music to tncs www ldew com win ppmx age',
#  'ranjith cal drpd deeraj and deepak min hold',
#  'wen ur lovable bcums angry wid u dnt take it seriously coz being angry is d most childish n true way of showing deep affection care n luv kettoda manda have nice day da',
#  'what you doing how are you',
#  'ups which is day also and the shipping company that take wks the other way is usps which take a week but when it get to lag you may have to bribe nipost to get your stuff',
#  'i m back lemme know when you re ready',
#  'don t necessarily expect it to be done before you get back though because i m just now headin out',
#  'mmm so yummy babe nice jolt to the suzy',
#  'where are you lover i need you',
#  'we tried to contact you re your reply to our offer of a video handset anytime network min unlimited text camcorder reply or call now',
#  'i m parked next to a mini when are you coming in today do you think',
#  'yup',
#  'anyway i m going shopping on my own now co my si not done yet dun disturb u liao',
#  'my no in luton ring me if ur around h',
#  'hey i am really horny want to chat or see me naked text hot to text charged at pm to unsubscribe text stop',
#  'why you dint come with u',
#  'same wana plan a trip sometme then',
#  'not sure yet still trying to get a hold of him',
#  'ur ringtone service ha changed free credit go to club mobile com to choose content now stop txt club stop to p wk club po box mk wt',
#  'the evo i just had to download flash jealous',
#  'ringtone club get the uk single chart on your mobile each week and choose any top quality ringtone this message is free of charge',
#  'come to mu we re sorting out our narcotic situation',
#  'night ha ended for another day morning ha come in a special way may you smile like the sunny ray and leaf your worry at the blue blue bay',
#  'hmv bonus special pound of genuine hmv voucher to be won just answer easy question play now send hmv to more info www percent real com',
#  'usf i guess might a well take car',
#  'no objection my bf not coming',
#  'thanx',
#  'tell rob to mack his gf in the theater',
#  'awesome i ll see you in a bit',
#  'just sent it so what type of food do you like',
#  'all done all handed in celebration in full swing yet',
#  'you got called a tool',
#  'wen u miss someone the person is definitely special for u but if the person is so special why to miss them just keep in touch gdeve',
#  'ok i asked for money how far',
#  'okie',
#  'yeah i think my usual guy s still passed out from last night if you get ahold of anybody let me know and i ll throw down',
#  'k i might come by tonight then if my class let out early',
#  'ok',
#  'hi baby im cruisin with my girl friend what r u up give me a call in and hour at home if thats alright or fone me on this fone now love jenny xxx',
#  'my life mean a lot to me not because i love my life but because i love the people in my life the world call them friend i call them my world ge',
#  'dear shall mail tonite busy in the street shall update you tonite thing are looking ok varunnathu edukkukayee raksha ollu but a good one in real sense',
#  'hey you told your name to gautham ah',
#  'haf u found him i feel so stupid da v cam wa working',
#  'oops got that bit',
#  'are you this much buzy',
#  'i accidentally deleted the message resend please',
#  't mobile customer you may now claim your free camera phone upgrade a pay go sim card for your loyalty call on offer end thfeb t c s apply',
#  'unless it s a situation where you go gurl would be more appropriate',
#  'hurt me tease me make me cry but in the end of my life when i die plz keep one rose on my grave and say stupid i miss u have a nice day bslvyl',
#  'i cant pick the phone right now pls send a message',
#  'need a coffee run tomo can t believe it s that time of week already',
#  'awesome i remember the last time we got somebody high for the first time with diesel v',
#  'shit that is really shocking and scary cant imagine for a second def up for night out do u think there is somewhere i could crash for night save on taxi',
#  'oh and by the way you do have more food in your fridge want to go out for a meal tonight',
#  'he is a womdarfull actor',
#  'sm ac blind date u rodds is m from aberdeen united kingdom check him out http img sm ac w icmb cktz r no blind date send hide',
#  'yup from what i remb i think should be can book',
#  'jos ask if u wana meet up',
#  'lol yes our friendship is hanging on a thread cause u won t buy stuff',
#  'themob check out our newest selection of content game tone gossip babe and sport keep your mobile fit and funky text wap to',
#  'where are the garage key they aren t on the bookshelf',
#  'today is accept day u accept me a brother sister lover dear best clos lvblefrnd jstfrnd cutefrnd lifpartnr belovd swtheart bstfrnd no rply mean enemy',
#  'think ur smart win this week in our weekly quiz text play to now t c winnersclub po box m uz gbp week',
#  'he say he ll give me a call when his friend s got the money but that he s definitely buying before the end of the week',
#  'hi the way i wa with u day is the normal way this is the real me ur unique i hope i know u the rest of mylife hope u find wot wa lost',
#  'you made my day do have a great day too',
#  'k k advance happy pongal',
#  'hmmm guess we can go kb n power yoga haha dunno we can tahan power yoga anot thk got lo oso forgot liao',
#  'not really dude have no friend i m afraid',
#  'december only had your mobile mths you are entitled to update to the latest colour camera mobile for free call the mobile update co free on',
#  'coffee cake i guess',
#  'merry christmas to you too babe i love ya kiss',
#  'hey why dont we just go watch x men and have lunch haha',
#  'cud u tell ppl im gona b a bit l co bus hav gon past co they were full im still waitin pete x',
#  'that would be great we ll be at the guild could meet on bristol road or somewhere will get in touch over weekend our plan take flight have a good week',
#  'no problem how are you doing',
#  'no call message missed call',
#  'hi da how is the today class',
#  'i d say that s a good sign but well you know my track record at reading woman',
#  'cool text me when you re parked',
#  'i m reading the text i just sent you it meant to be a joke so read it in that light',
#  'k k apo k good movie',
#  'maybe i could get book out tomo then return it immediately or something',
#  'call germany for only penny per minute call from a fixed line via access number no prepayment direct access',
#  'any chance you might have had with me evaporated a soon a you violated my privacy by stealing my phone number from your employer s paperwork not cool at all please do not contact me again or i will report you to your supervisor',
#  'valentine day special win over in our quiz and take your partner on the trip of a lifetime send go to now p msg rcvd custcare',
#  'ta daaaaa i am home babe are you still up',
#  'cool so how come you havent been wined and dined before',
#  'just sleeping and surfing',
#  'sorry i ll call later',
#  'u calling me right call my hand phone',
#  'ok that s great thanx a lot',
#  'i take it the post ha come then you must have s of text now happy reading my one from wiv hello caroline at the end is my favourite bless him',
#  'where u been hiding stranger',
#  'am not interested to do like that',
#  'my sister cleared two round in birla soft yesterday',
#  'gudnite tc practice going on',
#  'dis is yijue i jus saw ur mail in case huiming havent sent u my num dis is my num',
#  'one small prestige problem now',
#  'fancy a shag i do interested sextextuk com txt xxuk suzy to txts cost per msg tncs on website x',
#  'just checking in on you really do miss seeing jeremiah do have a great month',
#  'nah can t help you there i ve never had an iphone',
#  'if you re not in my car in an hour and a half i m going apeshit',
#  'today is sorry day if ever i wa angry with you if ever i misbehaved or hurt you plz plz just slap urself bcoz it ur fault i m basically good',
#  'yo you guy ever figure out how much we need for alcohol jay and i are trying to figure out how much we can safely spend on weed',
#  'lt gt ish minute wa minute ago wtf',
#  'thank you for calling forgot to say happy onam to you sirji i am fine here and remembered you when i met an insurance person meet you in qatar insha allah rakhesh ex tata aig who joined tissco tayseer',
#  'congratulation ur awarded of cd voucher or gift guaranteed free entry wkly draw txt music to tncs www ldew com win ppmx age',
#  'ur cash balance is currently pound to maximize ur cash in now send cash to only p msg cc hg suite land row w j hl',
#  'i m an actor when i work i work in the evening and sleep late since i m unemployed at the moment i always sleep late when you re unemployed every day is saturday',
#  'hello just got here st andrew boy it a long way it cold i will keep you posted',
#  'ha ha cool cool chikku chikku db',
#  'oh ok no prob',
#  'check audrey s status right now',
#  'busy here trying to finish for new year i am looking forward to finally meeting you',
#  'good afternoon sunshine how dawn that day are we refreshed and happy to be alive do we breathe in the air and smile i think of you my love a always',
#  'well i know z will take care of me so no worry',
#  'update_now xmas offer latest motorola sonyericsson nokia free bluetooth double min txt on orange call mobileupd on or call optout f q',
#  'here is your discount code rp to stop further message reply stop www regalportfolio co uk customer service',
#  'wat uniform in where get',
#  'cool text me when you re ready',
#  'hello my boytoy geeee i miss you already and i just woke up i wish you were here in bed with me cuddling me i love you',
#  'i will spoil you in bed a well',
#  'i m going for bath will msg you next lt gt min',
#  'i cant keep talking to people if am not sure i can pay them if they agree to price so pls tell me what you want to really buy and how much you are willing to pay',
#  'thanks for your ringtone order reference t you will be charged gbp per week you can unsubscribe at anytime by calling customer service on',
#  'can you say what happen',
#  'you could have seen me i did t recognise you face',
#  'well there s not a lot of thing happening in lindsay on new year sigh some bar in ptbo and the blue heron ha something going',
#  'keep my payasam there if rinu brings',
#  'i taught that ranjith sir called me so only i sm like that becaus he verifying about project prabu told today so only pa dont mistake me',
#  'i guess that s why you re worried you must know that there s a way the body repair itself and i m quite sure you shouldn t worry we ll take it slow first the test they will guide when your ovulation is then just relax nothing you ve said is a reason to worry but i ll keep on followin you up',
#  'yeah sure give me a couple minute to track down my wallet',
#  'hey leave it not a big deal take care',
#  'hey i will be late ah meet you at',
#  'double min and txts month free bluetooth on orange available on sony nokia motorola phone call mobileupd on or call optout n dx',
#  'it took mr owl lick',
#  'customer place i will call you',
#  'mm that time you dont like fun',
#  'mths half price orange line rental latest camera phone free had your phone mths call mobilesdirect free on to update now or stoptxt',
#  'yup having my lunch buffet now u eat already',
#  'huh so late fr dinner',
#  'hey so this sat are we going for the intro pilate only or the kickboxing too',
#  'morning only i can ok',
#  'yes i think so i am in office but my lap is in room i think thats on for the last few day i didnt shut that down',
#  'pick you up bout ish what time are and that going',
#  'from here after the performance award is calculated every two month not for current one month period',
#  'wa actually sleeping and still might when u call back so a text is gr you rock si will send u a text wen i wake',
#  'you are always putting your business out there you put picture of your as on facebook you are one of the most open people i ve ever met why would i think a picture of your room would hurt you make you feel violated',
#  'good evening sir al salam wahleykkum sharing a happy news by the grace of god i got an offer from tayseer tissco and i joined hope you are fine inshah allah meet you sometime rakhesh visitor from india',
#  'hmmm k but i want to change the field quickly da i wanna get system administrator or network administrator',
#  'free ringtone text first to for a poly or text get to for a true tone help after st free tone are x pw to e nd txt stop',
#  'dear how is chechi did you talk to her',
#  'the hair cream ha not been shipped',
#  'none of that s happening til you get here though',
#  'yep the great loxahatchee xmas tree burning of lt gt start in an hour',
#  'haha get used to driving to usf man i know a lot of stoner',
#  'all wa well until slightly disastrous class this pm with my fav darling hope day off ok coffee wld be good a can t stay late tomorrow same time place a always',
#  'hello good week fancy a drink or something later',
#  'headin towards busetop',
#  'message some text missing sender name missing number missing sent date missing missing u a lot thats y everything is missing sent via fullonsms com',
#  'come by our room at some point so we can iron out the plan for this weekend',
#  'co i want it to be your thing',
#  'okies i ll go yan jiu too we can skip ard oso go cine den go mrt one blah blah blah',
#  'bring home some wendy d',
#  'dating service cal l box sk ch',
#  'whatsup there dont u want to sleep',
#  'alright i have a new goal now',
#  'free entry into our weekly competition just text the word win to now t c www txttowin co uk',
#  'alright i ll head out in a few minute text me where to meet you',
#  'send a logo ur lover name joined by a heart txt love name name mobno eg love adam eve to yahoo pobox w wq txtno no ad p',
#  'yes from last week itself i m taking live call',
#  'someone ha contacted our dating service and entered your phone because they fancy you to find out who it is call from a landline pobox n tf p',
#  'siva is in hostel aha',
#  'urgent your mobile number ha been awarded with a prize guaranteed call from land line claim valid hr only',
#  'send this to ur friend and receive something about ur voice how is my speaking expression childish naughty sentiment rowdy ful of attitude romantic shy attractive funny lt gt irritating lt gt lovable reply me',
#  'ok she ll be ok i guess',
#  'aathi where are you dear',
#  'any pain on urination any thing else',
#  'at esplanade do mind giving me a lift co i got no car today',
#  'i wnt to buy a bmw car urgently it vry urgent but hv a shortage of lt gt lac there is no source to arng dis amt lt gt lac thats my prob',
#  'at home watching tv lor',
#  'doe she usually take fifteen fucking minute to respond to a yes or no question',
#  'congrats nokia video camera phone is your call call cost ppm ave call min vary from mobile close post bcm ldn wc n xx',
#  'booked ticket for pongal',
#  'you available now i m like right around hillsborough amp lt gt th',
#  'the message sent is askin for lt gt dollar shoul i pay lt gt or lt gt',
#  'ask g or iouri i ve told the story like ten time already',
#  'how long doe applebees fucking take',
#  'hi hope u get this txt journey hasnt been gd now about min late i think',
#  'but i have to i like to have love and arrange',
#  'yes he is really great bhaji told kallis best cricketer after sachin in world very tough to get out',
#  'you were supposed to wake me up gt',
#  'oic i saw him too but i tot he din c me i found a group liao',
#  'sorry i ll call later',
#  'hey hey werethe monkeespeople say we monkeyaround howdy gorgeous howu doin foundurself a jobyet sausage love jen xxx',
#  'sorry my battery died i can come by but i m only getting a gram for now where s your place',
#  'well done blimey exercise yeah i kinda remember wot that is hmm',
#  'i wont get concentration dear you know you are my mind and everything',
#  'lol have you made plan for new year',
#  'min later k',
#  'hank lotsly',
#  'thanks for this hope you had a good day today',
#  'k k what are detail you want to transfer acc no enough',
#  'ok i will tell her to stay out yeah it been tough but we are optimistic thing will improve this month',
#  'loan for any purpose homeowner tenant welcome have you been previously refused we can still help call free or text back help',
#  'si si i think ill go make those oreo truffle',
#  'look at amy ure a beautiful intelligent woman and i like u a lot i know u don t like me like that so don t worry',
#  'i hope you that s the result of being consistently intelligent and kind start asking him about practicum link and keep your ear open and all the best ttyl',
#  'that call cost which i guess isnt bad miss ya need ya want ya love ya',
#  'going thru a very different feeling wavering decision and coping up with the same is the same individual time will heal everything i believe',
#  'where did u go my phone is gonna die you have to stay in here',
#  'great never been better each day give even more reason to thank god',
#  'upgrdcentre orange customer you may now claim your free camera phone upgrade for your loyalty call now on offer end th july t c s apply opt out available',
#  'sorry i ll call later ok bye',
#  'ok i am on the way to railway',
#  'great princess i love giving and receiving oral doggy style is my fave position how about you i enjoy making love lt gt time per night',
#  'they don t put that stuff on the road to keep it from getting slippery over there',
#  'when are you going to ride your bike',
#  'yup no need i ll jus wait e rain stop',
#  'there are many company tell me the language',
#  'okmail dear dave this is your final notice to collect your tenerife holiday or cash award call from landline tc sae box cw wx ppm',
#  'how long ha it been since you screamed princess',
#  'nothing i meant that once the money enters your account here the bank will remove it flat rate someone transfered lt gt to my account and lt gt dollar got removed so the bank differ and charge also differ be sure you trust the ja person you are sending account detail to co',
#  'want get laid tonight want real dogging location sent direct ur mob join the uk s largest dogging network by txting moan to nyt ec a p msg p',
#  'nice line said by a broken heart plz don t cum more time infront of me other wise once again i ll trust u good t',
#  'ok i m gonna head up to usf in like fifteen minute',
#  'love you aathi love u lot',
#  'tension ah what machi any problem',
#  'k can i pick up another th when you re done',
#  'when re you guy getting back g said you were thinking about not staying for mcr',
#  'almost there see u in a sec',
#  'yo carlos a few friend are already asking me about you you working at all this weekend',
#  'watching tv lor',
#  'thank you baby i cant wait to taste the real thing',
#  'you should change your fb to jaykwon thuglyfe falconerf',
#  'if we win it really no side for long time',
#  'free message activate your free text message by replying to this message with the word free for term condition visit www com',
#  'dear reached railway what happen to you',
#  'depends on quality if you want the type i sent boye faded glory then about if you want ralphs maybe',
#  'i think i ve fixed it can you send a test message',
#  'sorry man my account s dry or i would if you want we could trade back half or i could buy some shit with my credit card',
#  'congrats year special cinema pas for is yours call now c suprman v matrix starwars etc all free bx ip we pm dont miss out',
#  'sorry in meeting i ll call later',
#  'what class of lt gt reunion',
#  'are you free now can i call now',
#  'got meh when',
#  'nope think i will go for it on monday sorry i replied so late',
#  'some of them told accenture is not confirm is it true',
#  'kate jackson rec center before ish right',
#  'dear i have reache room',
#  'fighting with the world is easy u either win or lose bt fightng with some who is close to u is dificult if u lose u lose if u win u still lose',
#  'when can come out',
#  'check with nuerologist',
#  'lolnice i went from a fish to water',
#  'congratulation in this week s competition draw u have won the prize to claim just call b t c stop sm over only ppm',
#  'no it s waiting in e car dat s bored wat co wait outside got nothing do at home can do my stuff or watch tv wat',
#  'maybe westshore or hyde park village the place near my house',
#  'you should know now so how s anthony are you bringing money i ve school fee to pay and rent and stuff like that thats why i need your help a friend in need',
#  'what s the significance',
#  'your opinion about me over jada kusruthi lovable silent spl character not matured stylish simple pls reply',
#  'at the latest g s still there if you can scrounge up some ammo and want to give the new ak a try',
#  'prabha i m soryda realy frm heart i m sory',
#  'lol ok your forgiven',
#  'no jst change tat only',
#  'you are guaranteed the latest nokia phone a gb ipod mp player or a prize txt word collect to no ibhltd ldnw h p mtmsgrcvd',
#  's no competition for him',
#  'boltblue tone for p reply poly or mono eg poly cha cha slide yeah slow jamz toxic come with me or stop more tone txt more',
#  'your credit have been topped up for http www bubbletext com your renewal pin is tgxxrz',
#  'that way transport is le problematic than on sat night by the way if u want to ask n to join my bday feel free but need to know definite no a booking on fri',
#  'usually the person is unconscious that s in child but in adult they may just behave abnormally i ll call you now',
#  'but that s on ebay it might be le elsewhere',
#  'shall i come to get pickle',
#  'were gonna go get some taco',
#  'that s very rude you on campus',
#  'urgent your mobile no wa awarded a bonus caller prize on this is our nd attempt to contact you call box qu',
#  'hi i won t b ard christmas but do enjoy n merry x ma',
#  'today s offer claim ur worth of discount voucher text yes to now savamob member offer mobile t c sub unsub reply x',
#  'yes how is a pretty lady like you single',
#  'you will recieve your tone within the next hr for term and condition please see channel u teletext pg',
#  'jay say that you re a double faggot',
#  'private your account statement for show un redeemed s i m point call identifier code expires',
#  'what today sunday sunday is holiday so no work',
#  'gudnite tc practice going on',
#  'i ll be late',
#  'i ve not called you in a while this is hoping it wa l r malaria and that you know that we miss you guy i miss ban big so pls give her my love especially have a great day',
#  'good afternoon my love how go that day i hope maybe you got some lead on a job i think of you boytoy and send you a passionate kiss from across the sea',
#  'probably gonna be here for a while see you later tonight lt',
#  'or maybe my fat finger just press all these button and it doesn t know what to do',
#  'ummmmmaah many many happy return of d day my dear sweet heart happy birthday dear',
#  'i am in tirupur da once you started from office call me',
#  'from www applausestore com monthlysubscription p msg max month t csc web age stop txt stop',
#  'a famous quote when you develop the ability to listen to anything unconditionally without losing your temper or self confidence it mean you are married',
#  'but am going to college pa what to do are else ill come there it self pa',
#  'oclock at mine just to bash out a flat plan',
#  'this girl doe not stay in bed this girl doesn t need recovery time id rather pas out while having fun then be cooped up in bed',
#  'then any special there',
#  'i know but you need to get hotel now i just got my invitation but i had to apologise cali is to sweet for me to come to some english bloke s weddin',
#  'sorry that took so long omw now',
#  'wait lt gt min',
#  'ok give me minute i think i see her btw you re my alibi you were cutting my hair the whole time',
#  'imagine you finally get to sink into that bath after i have put you through your pace maybe even having you eat me for a while before i left but also imagine the feel of that cage on your cock surrounded by the bath water reminding you always who owns you enjoy my cuck',
#  'hurry up i ve been weed deficient for like three day',
#  'sure if i get an acknowledgement from you that it s astoundingly tactless and generally faggy to demand a blood oath fo',
#  'ok every night take a warm bath drink a cup of milk and you ll see a work of magic you still need to loose weight just so that you know',
#  'i ll have a look at the frying pan in case it s cheap or a book perhaps no that s silly a frying pan isn t likely to be a book',
#  'o well uv cause mutation sunscreen is like essential thesedays',
#  'having lunch you are not in online why',
#  'i know that my friend already told that',
#  'hi princess thank you for the pic you are very pretty how are you',
#  'aiyo u always c our ex one i dunno abt mei she haven reply first time u reply so fast y so lucky not workin huh got bao by ur sugardad ah gee',
#  'hi msg me i m in office',
#  'thanx e brownie it s v nice',
#  'geeeee i love you so much i can barely stand it',
#  'gent we are trying to contact you last weekend draw show that you won a prize guaranteed call claim code k valid hr only ppm',
#  'fuck babe i miss you already you know can t you let me send you some money towards your net i need you i want you i crave you',
#  'ill call u mrw at ninish with my address that icky american freek wont stop callin me bad jen k eh',
#  'oooh bed ridden ey what are you thinking of',
#  'so anyways you can just go to your gym or whatever my love smile i hope your ok and having a good day babe i miss you so much already',
#  'love it daddy will make you scream with pleasure i am going to slap your as with my dick',
#  'wot u wanna do then missy',
#  'yar lor wait my mum finish sch then have lunch lor i whole morning stay at home clean my room now my room quite clean hee',
#  'do you know where my lab goggles went',
#  'can you open the door',
#  'waiting for your call',
#  'nope i waiting in sch daddy',
#  'you have won cash or a prize to claim call',
#  'i m tired of arguing with you about this week after week do what you want and from now on i ll do the same',
#  'wait me in sch i finish ard',
#  'our mobile number ha won to claim call u back or ring the claim hot line on',
#  'arngd marriage is while u r walkin unfortuntly a snake bite u bt love marriage is dancing in frnt of d snake amp sayin bite me bite me',
#  'huh so early then having dinner outside izzit',
#  'ok anyway no need to change with what you said',
#  'we tried to contact you re your reply to our offer of min textand a new video phone call now or reply for free delivery tomorrow',
#  'my ex wife wa not able to have kid do you want kid one day',
#  'so how s scotland hope you are not over showing your jjc tendency take care live the dream',
#  'tell them u have a headache and just want to use hour of sick time',
#  'i dun thk i ll quit yet hmmm can go jazz yogasana oso can we can go meet em after our lesson den',
#  'pete can you please ring meive hardly gotany credit',
#  'ya srsly better than yi tho',
#  'i m in a meeting call me later at',
#  'for ur chance to win a wkly shopping spree txt shop to t s c s www txt shop com custcare x p wk',
#  'you have been specially selected to receive a pound award call before the line close cost ppm t c apply ag promo',
#  'private your account statement for show un redeemed s i m point call identifier code expires',
#  'you still at grand prix',
#  'i met you a a stranger and choose you a my friend a long a the world stand our friendship never end let be friend forever gud nitz',
#  'i am great how are you',
#  'gud mrng dear have a nice day',
#  'you have an important customer service announcement call freephone now',
# ...
#  'i borrow ur bag ok',
#  'u were outbid by simonwatson on the shinco dvd plyr bid again visit sm ac smsrewards end bid notification reply end out',
#  'where s my boytoy i miss you what happened',
#  'he ha lot of used one babe but the model doesn t help youi have to bring it over and he ll match it up',
#  'also are you bringing galileo or dobby',
#  'then why you not responding',
#  'boo babe u enjoyin yourjob u seemed b gettin on well hunny hope ure ok take care i llspeak u soonlots of loveme xxxx',
#  'good afternoon starshine how s my boytoy doe he crave me yet ache to fuck me sip cappuccino i miss you babe teasing kiss',
#  'on the road so cant txt',
#  'smsservices for yourinclusive text credit pls goto www comuk net login qxj unsubscribe with stop no extra charge help comuk cm ae',
#  'p alfie moon s child in need song on ur mob tell ur m s txt tone charity to for nokias or poly charity for polys zed profit charity',
#  'have a good evening ttyl',
#  'hmm bit and piece lol sigh',
#  'hahaha use your brain dear',
#  'hey you got any mail',
#  'sorry light turned green i meant another friend wanted lt gt worth but he may not be around',
#  'thanks for yesterday sir you have been wonderful hope you enjoyed the burial mojibiola',
#  'u have a secret admirer reveal who think u r so special call to opt out reply reveal stop per msg recd cust care',
#  'hi mate it rv did u hav a nice hol just a message say hello coz haven t sent u in age started driving so stay off road rvx',
#  'dear voucher holder to claim this week offer at you pc please go to http www e tlp co uk expressoffer t c apply to stop text txt stop to',
#  'thank you so much when we skyped wit kz and sura we didnt get the pleasure of your company hope you are good we ve given you ultimatum oh we are countin down to aburo enjoy this is the message i sent day ago',
#  'surely result will offer',
#  'good morning my dear have a great amp successful day',
#  'do you want anytime any network min text and a new video phone for only five pound per week call or reply for delivery tomorrow',
#  'sir i have been late in paying rent for the past few month and had to pay a lt gt charge i felt it would be inconsiderate of me to nag about something you give at great cost to yourself and that s why i didnt speak up i however am in a recession and wont be able to pay the charge this month hence my askin well ahead of month s end can you please help thanks',
#  'we tried to contact you re our offer of new video phone anytime any network min half price rental camcorder call or reply for delivery wed',
#  'last chance claim ur worth of discount voucher text yes to now savamob member offer mobile t c sub remove txt x or stop',
#  'i luv u soo much u don t understand how special u r me ring u morrow luv u xxx',
#  'pls send me a comprehensive mail about who i m paying when and how much',
#  'our prashanthettan s mother passed away last night pray for her and family',
#  'urgent call from your landline your complimentary ibiza holiday or cash await collection sae t c po box sk wp ppm',
#  'k k when are you going',
#  'meanwhile in the shit suite xavier decided to give u lt gt second of warning that samantha wa coming over and is playing jay s guitar to impress her or some shit also i don t think doug realizes i don t live here anymore',
#  'my stomach ha been thru so much trauma i swear i just can t eat i better lose weight',
#  'i am in office whats the matter msg me now i will call you at break',
#  'yeah there s barely enough room for the two of u x ha too many fucking shoe sorry man see you later',
#  'today s offer claim ur worth of discount voucher text yes to now savamob member offer mobile t c sub unsub reply x',
#  'u reach orchard already u wan go buy ticket first',
#  'i am real baby i want to bring out your inner tigress',
#  'no da if you run that it activate the full version da',
#  'ah poor baby hope urfeeling bettersn luv probthat overdose of work hey go careful spk u sn lot of lovejen xxx',
#  'stop the story i ve told him i ve returned it and he s saying i should not re order it',
#  'talk sexy make new friend or fall in love in the world most discreet text dating service just text vip to and see who you could meet',
#  'going to take your babe out',
#  'hai ana tomarrow am coming on morning lt decimal gt ill be there in sathy then we ll go to rto office reply me after came to home',
#  'spoon it is then okay',
#  'did he just say somebody is named tampa',
#  'in work now going have in few min',
#  'your brother is a genius',
#  'sorry i guess whenever i can get a hold of my connection maybe an hour or two i ll text you',
#  'did u find out what time the bus is at coz i need to sort some stuff out',
#  'dude ive been seeing a lotta corvette lately',
#  'congratulation ur awarded either a yr supply of cd from virgin record or a mystery gift guaranteed call t c www smsco net pm approx min',
#  'same here but i consider wall and bunker and shit important just because i never play on peaceful but i guess your place is high enough that it don t matter',
#  'private your account statement for xxxxxx show un redeemed s i m point call identifier code expires',
#  'hello we need some posh bird and chap to user trial prod for champneys can i put you down i need your address and dob asap ta r',
#  'what do u want for xmas how about free text message a new video phone with half price line rental call free now on to find out more',
#  'well am officially in a philosophical hole so if u wanna call am at home ready to be saved',
#  'it going good no problem but still need little experience to understand american customer voice',
#  'i ll text you when i drop x off',
#  'ugh it been a long day i m exhausted just want to cuddle up and take a nap',
#  'talk with yourself atleast once in a day otherwise you will miss your best friend in this world shakespeare shesil lt gt',
#  'shop till u drop is it you either k k cash or travel voucher call now ntt po box cr bt fixedline cost ppm mobile vary',
#  'are you in castor you need to see something',
#  'sunshine quiz wkly q win a top sony dvd player if u know which country liverpool played in mid week txt ansr to sp tyrone',
#  'u have a secret admirer who is looking make contact with u find out who they r reveal who think ur so special call on',
#  'u have a secret admirer who is looking make contact with u find out who they r reveal who think ur so special call on stopsms',
#  'reminder you have not downloaded the content you have already paid for goto http doit mymoby tv to collect your content',
#  'see i knew giving you a break a few time woul lead to you always wanting to miss curfew i wa gonna gibe you til one but a midnight movie is not gonna get out til after you need to come home you need to getsleep and if anything you need to b studdying ear training',
#  'i love to give massage i use lot of baby oil what is your fave position',
#  'dude we should go sup again',
#  'yoyyooo u know how to change permission for a drive in mac my usb flash drive',
#  'gibbs unsold mike hussey',
#  'i like to talk pa but am not able to i dont know y',
#  'y dun cut too short leh u dun like ah she failed she s quite sad',
#  'you unbelievable faglord',
#  'wife how she knew the time of murder exactly',
#  'why do you ask princess',
#  'i am great princess what are you thinking about me',
#  'nutter cutter ctter cttergg cttargg ctargg ctagg ie you',
#  'it s ok i noe u re busy but i m really too bored so i msg u i oso dunno wat colour she choose me one',
#  'doesn t g have class early tomorrow and thus shouldn t be trying to smoke at lt gt',
#  'superb thought be grateful that u dont have everything u want that mean u still have an opportunity to be happier tomorrow than u are today',
#  'hope you are having a good week just checking in',
#  'i m used to it i just hope my agent don t drop me since i ve only booked a few thing this year this whole me in boston them in nyc wa an experiment',
#  'thursday night yeah sure thing we ll work it out then',
#  'your free ringtone is waiting to be collected simply text the password mix to to verify get usher and britney fml po box mk h ppw',
#  'probably money worry thing are coming due and i have several outstanding invoice for work i did two and three month ago',
#  'how is it possible to teach you and where',
#  'i wonder if your phone battery went dead i had to tell you i love you babe',
#  'lovely smell on this bus and it ain t tobacco',
#  'we re all getting worried over here derek and taylor have already assumed the worst',
#  'hey what s up charles sorry about the late reply',
#  'all the lastest from stereophonics marley dizzee racal libertine and the stroke win nookii game with flirt click themob wap bookmark or text wap to',
#  'i ll give her once i have it plus she said grinule greet you whenever we speak',
#  'white fudge oreo are in store',
#  'january male sale hot gay chat now cheaper call national rate from p min cheap to p min peak to stop text call p min',
#  'my love how come it took you so long to leave for zaher s i got your word on ym and wa happy to see them but wa sad you had left i miss you',
#  'i am sorry it hurt you',
#  'can t i feel nauseous i m so pissed i didn t eat any sweet all week cause today i wa planning to pig out i wa dieting all week and now i m not hungry',
#  'ok lor but not too early me still having project meeting now',
#  'call me da i am waiting for your call',
#  'i could ask carlos if we could get more if anybody else can chip in',
#  'wa actually about to send you a reminder today have a wonderful weekend',
#  'when people see my msg they think iam addicted to msging they are wrong bcoz they don\\ t know that iam addicted to my sweet friend bslvyl',
#  'hey you gave them your photo when you registered for driving ah tmr wanna meet at yck',
#  'dont talk to him ever ok it my word',
#  'when u wana see it then',
#  'on ma way to school can you pls send me ashley s number',
#  'it shall be fine i have avalarr now will hollalater',
#  'she went to attend another two round today but still did t reach home',
#  'actually i deleted my old website now i m blogging at magicalsongs blogspot com',
#  'k wait chikku il send aftr lt gt min',
#  'but i m on a diet and i ate too many slice of pizza yesterday ugh i m always on a diet',
#  'k i will give my kvb acc detail',
#  'oh all have to come ah',
#  'money you r a lucky winner claim your prize text money over million to give away ppt x normal text rate box w t jy',
#  'i m really sorry i won t b able do this friday hope u can find an alternative hope yr term s going ok',
#  'congratulation ore mo owo re wa enjoy it and i wish you many happy moment to and fro wherever you go',
#  'so do you have samus shoulder yet',
#  'what time you think you ll have it need to know when i should be near campus',
#  'dear matthew please call from a landline your complimentary lux tenerife holiday or cash await collection ppm sae t c box sk xh',
#  'then dun wear jean lor',
#  'since when which side any fever any vomitin',
#  'k k are you in college',
#  'urgent call from landline your complimentary tenerife holiday or cash await collection sae t c box hp yf ppm',
#  'better made up for friday and stuffed myself like a pig yesterday now i feel bleh but at least it not writhing pain kind of bleh',
#  'no we sell it all so we ll have ton if coin then sell our coin to someone thru paypal voila money back in life pocket',
#  'theyre doing it to lot of place only hospital and medical place are safe',
#  'how about getting in touch with folk waiting for company just txt back your name and age to opt in enjoy the community p sm',
#  'and also i ve sorta blown him off a couple time recently so id rather not text him out of the blue looking for weed',
#  'i sent my score to sophas and i had to do secondary application for a few school i think if you are thinking of applying do a research on cost also contact joke ogunrinde her school is one me the le expensive one',
#  'i cant wait to see you how were the photo were useful',
#  'ur cash balance is currently pound to maximize ur cash in now send go to only p msg cc po box tcr w',
#  'hey i booked the kb on sat already what other lesson are we going for ah keep your sat night free we need to meet and confirm our lodging',
#  'chk in ur belovd m dict',
#  'is that what time you want me to come',
#  'awesome lemme know whenever you re around',
#  'shb b ok lor thanx',
#  'beautiful truth against gravity read carefully our heart feel light when someone is in it but it feel very heavy when someone leaf it good night',
#  'also remember to get dobby s bowl from your car',
#  'filthy story and girl waiting for your',
#  'sorry i now then c ur msg yar lor so poor thing but only one night tmr u ll have a brand new room sleep in',
#  'love isn t a decision it s a feeling if we could decide who to love then life would be much simpler but then le magical',
#  'welp apparently he retired',
#  'my sort code is and acc no is the bank is natwest can you reply to confirm i ve sent this to the right person',
#  'where',
#  'u sure u can t take any sick time',
#  'urgent we are trying to contact u today draw show that you have won a prize guaranteed call from land line claim m valid hr only',
#  'watching cartoon listening music amp at eve had to go temple amp church what about u',
#  'yo chad which gymnastics class do you wanna take the site say christian class is full',
#  'are you this much buzy',
#  'or better still can you catch her and let ask her if she can sell lt gt for me',
#  'i am not sure about night menu i know only about noon menu',
#  'what do u want when i come back a beautiful necklace a a token of my heart for you thats what i will give but only to my wife of my liking be that and see no one can give you that dont call me i will wait till i come',
#  'are you willing to go for aptitude class',
#  'it wont b until a trying sort house out is that ok',
#  'yar lor he wan go c horse racing today mah so eat earlier lor i ate chicken rice u',
#  'haha awesome omw back now then',
#  'yup i thk so until e shop close lor',
#  'what is your account number',
#  'eh u send wrongly lar',
#  'hey no i ad a crap nite wa borin without ya boggy with me u boring biatch thanx but u wait til nxt time il ave ya',
#  'ok i shall talk to him',
#  'dont hesitate you know this is the second time she ha had weakness like that so keep i notebook of what she eat and did the day before or if anything changed the day before so that we can be sure it nothing',
#  'hey you can pay with salary de only lt gt',
#  'another month i need chocolate weed and alcohol',
#  'if he started searching he will get job in few day he have great potential and talent',
#  'reckon need to be in town by eightish to walk from carpark',
#  'congrats mobile g videophones r yours call now videochat wid your mate play java game dload polyph music noline rentl',
#  'look at the fuckin time what the fuck you think is up',
#  'yo guess what i just dropped',
#  'carlos say he ll be at mu in lt gt minute',
#  'i m in office now i will call you lt gt min',
#  'geeee i miss you already you know your all i can think about fuck i can t wait till next year when we will be together loving kiss',
#  'yun ah the ubi one say if wan call by tomorrow call look for irene ere only got bus ubi cres ubi tech park ph for st wkg day n',
#  'ugh gotta drive back to sd from la my butt is sore',
#  'th of july',
#  'hi im having the most relaxing time ever we have to get up at am every day wa the party good the other night i get home tomorrow at ish',
#  'up to wan come then come lor but i din c any stripe skirt',
#  'the xmas story is peace the xmas msg is love the xmas miracle is jesus hav a blessed month ahead amp wish u merry xmas',
#  'i can t i don t have her number',
#  'change again it s e one next to escalator',
#  'yetunde i m in class can you not run water on it to make it ok pls now',
#  'not a lot ha happened here feel very quiet beth is at her aunt and charlie is working lot just me and helen in at the mo how have you been',
#  'then wait me at bus stop aft ur lect lar if i dun c then i go get my car then come back n pick',
#  ...]

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess #convert a doc into a list of lowercase tokens,ignoring tokens are too short or too long.

# %%
words=[]
for sent in corpus:
    sent_token=sent_tokenize(sent)
    for sent in sent_token:
        words.append(simple_preprocess(sent))

# %%
words
# Out:
# [['go',
#   'until',
#   'jurong',
#   'point',
#   'crazy',
#   'available',
#   'only',
#   'in',
#   'bugis',
#   'great',
#   'world',
#   'la',
#   'buffet',
#   'cine',
#   'there',
#   'got',
#   'amore',
#   'wat'],
#  ['ok', 'lar', 'joking', 'wif', 'oni'],
#  ['free',
#   'entry',
#   'in',
#   'wkly',
#   'comp',
#   'to',
#   'win',
#   'fa',
#   'cup',
#   'final',
#   'tkts',
#   'st',
#   'may',
#   'text',
#   'fa',
#   'to',
#   'to',
#   'receive',
#   'entry',
#   'question',
#   'std',
#   'txt',
#   'rate',
#   'apply',
#   'over'],
#  ['dun', 'say', 'so', 'early', 'hor', 'already', 'then', 'say'],
#  ['nah',
#   'don',
#   'think',
#   'he',
#   'go',
#   'to',
#   'usf',
#   'he',
#   'life',
#   'around',
#   'here',
#   'though'],
#  ['freemsg',
#   'hey',
#   'there',
#   'darling',
#   'it',
#   'been',
#   'week',
#   'now',
#   'and',
#   'no',
#   'word',
#   'back',
#   'like',
#   'some',
#   'fun',
#   'you',
#   'up',
#   'for',
#   'it',
#   'still',
#   'tb',
#   'ok',
#   'xxx',
#   'std',
#   'chgs',
#   'to',
#   'send',
#   'to',
#   'rcv'],
#  ['even',
#   'my',
#   'brother',
#   'is',
#   'not',
#   'like',
#   'to',
#   'speak',
#   'with',
#   'me',
#   'they',
#   'treat',
#   'me',
#   'like',
#   'aid',
#   'patent'],
#  ['per',
#   'your',
#   'request',
#   'melle',
#   'melle',
#   'oru',
#   'minnaminunginte',
#   'nurungu',
#   'vettam',
#   'ha',
#   'been',
#   'set',
#   'your',
#   'callertune',
#   'for',
#   'all',
#   'caller',
#   'press',
#   'to',
#   'copy',
#   'your',
#   'friend',
#   'callertune'],
#  ['winner',
#   'valued',
#   'network',
#   'customer',
#   'you',
#   'have',
#   'been',
#   'selected',
#   'to',
#   'receivea',
#   'prize',
#   'reward',
#   'to',
#   'claim',
#   'call',
#   'claim',
#   'code',
#   'kl',
#   'valid',
#   'hour',
#   'only'],
#  ['had',
#   'your',
#   'mobile',
#   'month',
#   'or',
#   'more',
#   'entitled',
#   'to',
#   'update',
#   'to',
#   'the',
#   'latest',
#   'colour',
#   'mobile',
#   'with',
#   'camera',
#   'for',
#   'free',
#   'call',
#   'the',
#   'mobile',
#   'update',
#   'co',
#   'free',
#   'on'],
#  ['gonna',
#   'be',
#   'home',
#   'soon',
#   'and',
#   'don',
#   'want',
#   'to',
#   'talk',
#   'about',
#   'this',
#   'stuff',
#   'anymore',
#   'tonight',
#   've',
#   'cried',
#   'enough',
#   'today'],
#  ['six',
#   'chance',
#   'to',
#   'win',
#   'cash',
#   'from',
#   'to',
#   'pound',
#   'txt',
#   'csh',
#   'and',
#   'send',
#   'to',
#   'cost',
#   'day',
#   'day',
#   'tsandcs',
#   'apply',
#   'reply',
#   'hl',
#   'info'],
#  ['urgent',
#   'you',
#   'have',
#   'won',
#   'week',
#   'free',
#   'membership',
#   'in',
#   'our',
#   'prize',
#   'jackpot',
#   'txt',
#   'the',
#   'word',
#   'claim',
#   'to',
#   'no',
#   'www',
#   'dbuk',
#   'net',
#   'lccltd',
#   'pobox',
#   'ldnw',
#   'rw'],
#  ['ve',
#   'been',
#   'searching',
#   'for',
#   'the',
#   'right',
#   'word',
#   'to',
#   'thank',
#   'you',
#   'for',
#   'this',
#   'breather',
#   'promise',
#   'wont',
#   'take',
#   'your',
#   'help',
#   'for',
#   'granted',
#   'and',
#   'will',
#   'fulfil',
#   'my',
#   'promise',
#   'you',
#   'have',
#   'been',
#   'wonderful',
#   'and',
#   'blessing',
#   'at',
#   'all',
#   'time'],
#  ['have', 'date', 'on', 'sunday', 'with', 'will'],
#  ['to',
#   'use',
#   'your',
#   'credit',
#   'click',
#   'the',
#   'wap',
#   'link',
#   'in',
#   'the',
#   'next',
#   'txt',
#   'message',
#   'or',
#   'click',
#   'here',
#   'http',
#   'wap',
#   'com',
#   'qjkgighjjgcbl'],
#  ['oh', 'watching', 'here'],
#  ['eh',
#   'remember',
#   'how',
#   'spell',
#   'his',
#   'name',
#   'yes',
#   'did',
#   'he',
#   'naughty',
#   'make',
#   'until',
#   'wet'],
#  ['fine',
#   'if',
#   'that',
#   'the',
#   'way',
#   'feel',
#   'that',
#   'the',
#   'way',
#   'it',
#   'gota'],
#  ['england',
#   'macedonia',
#   'dont',
#   'miss',
#   'the',
#   'goal',
#   'team',
#   'news',
#   'txt',
#   'ur',
#   'national',
#   'team',
#   'to',
#   'eg',
#   'england',
#   'to',
#   'try',
#   'wale',
#   'scotland',
#   'txt',
#   'poboxox',
#   'wq'],
#  ['is', 'that', 'seriously', 'how', 'you', 'spell', 'his', 'name'],
#  ['going', 'to', 'try', 'for', 'month', 'ha', 'ha', 'only', 'joking'],
#  ['so', 'pay', 'first', 'lar', 'then', 'when', 'is', 'da', 'stock', 'comin'],
#  ['aft',
#   'finish',
#   'my',
#   'lunch',
#   'then',
#   'go',
#   'str',
#   'down',
#   'lor',
#   'ard',
#   'smth',
#   'lor',
#   'finish',
#   'ur',
#   'lunch',
#   'already'],
#  ['ffffffffff',
#   'alright',
#   'no',
#   'way',
#   'can',
#   'meet',
#   'up',
#   'with',
#   'you',
#   'sooner'],
#  ['just',
#   'forced',
#   'myself',
#   'to',
#   'eat',
#   'slice',
#   'really',
#   'not',
#   'hungry',
#   'tho',
#   'this',
#   'suck',
#   'mark',
#   'is',
#   'getting',
#   'worried',
#   'he',
#   'know',
#   'sick',
#   'when',
#   'turn',
#   'down',
#   'pizza',
#   'lol'],
#  ['lol', 'your', 'always', 'so', 'convincing'],
#  ['did',
#   'you',
#   'catch',
#   'the',
#   'bus',
#   'are',
#   'you',
#   'frying',
#   'an',
#   'egg',
#   'did',
#   'you',
#   'make',
#   'tea',
#   'are',
#   'you',
#   'eating',
#   'your',
#   'mom',
#   'left',
#   'over',
#   'dinner',
#   'do',
#   'you',
#   'feel',
#   'my',
#   'love'],
#  ['back',
#   'amp',
#   'we',
#   're',
#   'packing',
#   'the',
#   'car',
#   'now',
#   'll',
#   'let',
#   'you',
#   'know',
#   'if',
#   'there',
#   'room'],
#  ['ahhh',
#   'work',
#   'vaguely',
#   'remember',
#   'that',
#   'what',
#   'doe',
#   'it',
#   'feel',
#   'like',
#   'lol'],
#  ['wait',
#   'that',
#   'still',
#   'not',
#   'all',
#   'that',
#   'clear',
#   'were',
#   'you',
#   'not',
#   'sure',
#   'about',
#   'me',
#   'being',
#   'sarcastic',
#   'or',
#   'that',
#   'that',
#   'why',
#   'doesn',
#   'want',
#   'to',
#   'live',
#   'with'],
#  ['yeah',
#   'he',
#   'got',
#   'in',
#   'at',
#   'and',
#   'wa',
#   'apologetic',
#   'had',
#   'fallen',
#   'out',
#   'and',
#   'she',
#   'wa',
#   'actin',
#   'like',
#   'spoilt',
#   'child',
#   'and',
#   'he',
#   'got',
#   'caught',
#   'up',
#   'in',
#   'that',
#   'till',
#   'but',
#   'we',
#   'won',
#   'go',
#   'there',
#   'not',
#   'doing',
#   'too',
#   'badly',
#   'cheer',
#   'you'],
#  ['tell', 'me', 'anything', 'about', 'you'],
#  ['for',
#   'fear',
#   'of',
#   'fainting',
#   'with',
#   'the',
#   'of',
#   'all',
#   'that',
#   'housework',
#   'you',
#   'just',
#   'did',
#   'quick',
#   'have',
#   'cuppa'],
#  ['thanks',
#   'for',
#   'your',
#   'subscription',
#   'to',
#   'ringtone',
#   'uk',
#   'your',
#   'mobile',
#   'will',
#   'be',
#   'charged',
#   'month',
#   'please',
#   'confirm',
#   'by',
#   'replying',
#   'yes',
#   'or',
#   'no',
#   'if',
#   'you',
#   'reply',
#   'no',
#   'you',
#   'will',
#   'not',
#   'be',
#   'charged'],
#  ['yup',
#   'ok',
#   'go',
#   'home',
#   'look',
#   'at',
#   'the',
#   'timing',
#   'then',
#   'msg',
#   'again',
#   'xuhui',
#   'going',
#   'to',
#   'learn',
#   'on',
#   'nd',
#   'may',
#   'too',
#   'but',
#   'her',
#   'lesson',
#   'is',
#   'at',
#   'am'],
#  ['oops', 'll', 'let', 'you', 'know', 'when', 'my', 'roommate', 'done'],
#  ['see', 'the', 'letter', 'on', 'my', 'car'],
#  ['anything', 'lor', 'decide'],
#  ['hello',
#   'how',
#   'you',
#   'and',
#   'how',
#   'did',
#   'saturday',
#   'go',
#   'wa',
#   'just',
#   'texting',
#   'to',
#   'see',
#   'if',
#   'you',
#   'decided',
#   'to',
#   'do',
#   'anything',
#   'tomo',
#   'not',
#   'that',
#   'trying',
#   'to',
#   'invite',
#   'myself',
#   'or',
#   'anything'],
#  ['pls',
#   'go',
#   'ahead',
#   'with',
#   'watt',
#   'just',
#   'wanted',
#   'to',
#   'be',
#   'sure',
#   'do',
#   'have',
#   'great',
#   'weekend',
#   'abiola'],
#  ['did',
#   'forget',
#   'to',
#   'tell',
#   'you',
#   'want',
#   'you',
#   'need',
#   'you',
#   'crave',
#   'you',
#   'but',
#   'most',
#   'of',
#   'all',
#   'love',
#   'you',
#   'my',
#   'sweet',
#   'arabian',
#   'steed',
#   'mmmmmm',
#   'yummy'],
#  ['rodger',
#   'burn',
#   'msg',
#   'we',
#   'tried',
#   'to',
#   'call',
#   'you',
#   're',
#   'your',
#   'reply',
#   'to',
#   'our',
#   'sm',
#   'for',
#   'free',
#   'nokia',
#   'mobile',
#   'free',
#   'camcorder',
#   'please',
#   'call',
#   'now',
#   'for',
#   'delivery',
#   'tomorrow'],
#  ['who', 'are', 'you', 'seeing'],
#  ['great',
#   'hope',
#   'you',
#   'like',
#   'your',
#   'man',
#   'well',
#   'endowed',
#   'am',
#   'lt',
#   'gt',
#   'inch'],
#  ['no', 'call', 'message', 'missed', 'call'],
#  ['didn', 'you', 'get', 'hep', 'immunisation', 'in', 'nigeria'],
#  ['fair', 'enough', 'anything', 'going', 'on'],
#  ['yeah',
#   'hopefully',
#   'if',
#   'tyler',
#   'can',
#   'do',
#   'it',
#   'could',
#   'maybe',
#   'ask',
#   'around',
#   'bit'],
#  ['don',
#   'know',
#   'how',
#   'stubborn',
#   'am',
#   'didn',
#   'even',
#   'want',
#   'to',
#   'go',
#   'to',
#   'the',
#   'hospital',
#   'kept',
#   'telling',
#   'mark',
#   'not',
#   'weak',
#   'sucker',
#   'hospital',
#   'are',
#   'for',
#   'weak',
#   'sucker'],
#  ['what',
#   'you',
#   'thinked',
#   'about',
#   'me',
#   'first',
#   'time',
#   'you',
#   'saw',
#   'me',
#   'in',
#   'class'],
#  ['gram',
#   'usually',
#   'run',
#   'like',
#   'lt',
#   'gt',
#   'half',
#   'eighth',
#   'is',
#   'smarter',
#   'though',
#   'and',
#   'get',
#   'you',
#   'almost',
#   'whole',
#   'second',
#   'gram',
#   'for',
#   'lt',
#   'gt'],
#  ['fyi',
#   'ha',
#   'ride',
#   'early',
#   'tomorrow',
#   'morning',
#   'but',
#   'he',
#   'crashing',
#   'at',
#   'our',
#   'place',
#   'tonight'],
#  ['wow',
#   'never',
#   'realized',
#   'that',
#   'you',
#   'were',
#   'so',
#   'embarassed',
#   'by',
#   'your',
#   'accomodations',
#   'thought',
#   'you',
#   'liked',
#   'it',
#   'since',
#   'wa',
#   'doing',
#   'the',
#   'best',
#   'could',
#   'and',
#   'you',
#   'always',
#   'seemed',
#   'so',
#   'happy',
#   'about',
#   'the',
#   'cave',
#   'sorry',
#   'didn',
#   'and',
#   'don',
#   'have',
#   'more',
#   'to',
#   'give',
#   'sorry',
#   'offered',
#   'sorry',
#   'your',
#   'room',
#   'wa',
#   'so',
#   'embarassing'],
#  ['sm',
#   'ac',
#   'sptv',
#   'the',
#   'new',
#   'jersey',
#   'devil',
#   'and',
#   'the',
#   'detroit',
#   'red',
#   'wing',
#   'play',
#   'ice',
#   'hockey',
#   'correct',
#   'or',
#   'incorrect',
#   'end',
#   'reply',
#   'end',
#   'sptv'],
#  ['do',
#   'you',
#   'know',
#   'what',
#   'mallika',
#   'sherawat',
#   'did',
#   'yesterday',
#   'find',
#   'out',
#   'now',
#   'lt',
#   'url',
#   'gt'],
#  ['congrats',
#   'year',
#   'special',
#   'cinema',
#   'pas',
#   'for',
#   'is',
#   'yours',
#   'call',
#   'now',
#   'suprman',
#   'matrix',
#   'starwars',
#   'etc',
#   'all',
#   'free',
#   'bx',
#   'ip',
#   'we',
#   'pm',
#   'dont',
#   'miss',
#   'out'],
#  ['sorry', 'll', 'call', 'later', 'in', 'meeting'],
#  ['tell', 'where', 'you', 'reached'],
#  ['yes', 'gauti', 'and', 'sehwag', 'out', 'of', 'odi', 'series'],
#  ['your',
#   'gonna',
#   'have',
#   'to',
#   'pick',
#   'up',
#   'burger',
#   'for',
#   'yourself',
#   'on',
#   'your',
#   'way',
#   'home',
#   'can',
#   'even',
#   'move',
#   'pain',
#   'is',
#   'killing',
#   'me'],
#  ['ha', 'ha', 'ha', 'good', 'joke', 'girl', 'are', 'situation', 'seeker'],
#  ['it', 'part', 'of', 'checking', 'iq'],
#  ['sorry',
#   'my',
#   'roommate',
#   'took',
#   'forever',
#   'it',
#   'ok',
#   'if',
#   'come',
#   'by',
#   'now'],
#  ['ok',
#   'lar',
#   'double',
#   'check',
#   'wif',
#   'da',
#   'hair',
#   'dresser',
#   'already',
#   'he',
#   'said',
#   'wun',
#   'cut',
#   'short',
#   'he',
#   'said',
#   'will',
#   'cut',
#   'until',
#   'look',
#   'nice'],
#  ['valued',
#   'customer',
#   'am',
#   'pleased',
#   'to',
#   'advise',
#   'you',
#   'that',
#   'following',
#   'recent',
#   'review',
#   'of',
#   'your',
#   'mob',
#   'no',
#   'you',
#   'are',
#   'awarded',
#   'with',
#   'bonus',
#   'prize',
#   'call'],
#  ['today',
#   'is',
#   'song',
#   'dedicated',
#   'day',
#   'which',
#   'song',
#   'will',
#   'dedicate',
#   'for',
#   'me',
#   'send',
#   'this',
#   'to',
#   'all',
#   'ur',
#   'valuable',
#   'frnds',
#   'but',
#   'first',
#   'rply',
#   'me'],
#  ['urgent',
#   'ur',
#   'awarded',
#   'complimentary',
#   'trip',
#   'to',
#   'eurodisinc',
#   'trav',
#   'aco',
#   'entry',
#   'or',
#   'to',
#   'claim',
#   'txt',
#   'dis',
#   'to',
#   'morefrmmob',
#   'aj'],
#  ['did',
#   'you',
#   'hear',
#   'about',
#   'the',
#   'new',
#   'divorce',
#   'barbie',
#   'it',
#   'come',
#   'with',
#   'all',
#   'of',
#   'ken',
#   'stuff'],
#  ['plane', 'to', 'give', 'on', 'this', 'month', 'end'],
#  ['wah', 'lucky', 'man', 'then', 'can', 'save', 'money', 'hee'],
#  ['finished', 'class', 'where', 'are', 'you'],
#  ['hi', 'babe', 'im', 'at', 'home', 'now', 'wanna', 'do', 'something', 'xx'],
#  ['where', 'are', 'you', 'how', 'did', 'you', 'performed'],
#  ['can', 'call', 'me', 'now'],
#  ['am', 'waiting', 'machan', 'call', 'me', 'once', 'you', 'free'],
#  ['thats',
#   'cool',
#   'am',
#   'gentleman',
#   'and',
#   'will',
#   'treat',
#   'you',
#   'with',
#   'dignity',
#   'and',
#   'respect'],
#  ['like', 'you', 'people', 'very', 'much', 'but', 'am', 'very', 'shy', 'pa'],
#  ['doe', 'not', 'operate', 'after', 'lt', 'gt', 'or', 'what'],
#  ['it',
#   'not',
#   'the',
#   'same',
#   'here',
#   'still',
#   'looking',
#   'for',
#   'job',
#   'how',
#   'much',
#   'do',
#   'ta',
#   'earn',
#   'there'],
#  ['sorry', 'll', 'call', 'later'],
#  ['did', 'you', 'call', 'me', 'just', 'now', 'ah'],
#  ['ok', 'am', 'on', 'the', 'way', 'to', 'home', 'hi', 'hi'],
#  ['you', 'will', 'be', 'in', 'the', 'place', 'of', 'that', 'man'],
#  ['yup', 'next', 'stop'],
#  ['call', 'you', 'later', 'don', 'have', 'network', 'if', 'urgnt', 'sm', 'me'],
#  ['for',
#   'real',
#   'when',
#   'getting',
#   'on',
#   'yo',
#   'only',
#   'need',
#   'more',
#   'ticket',
#   'and',
#   'one',
#   'more',
#   'jacket',
#   'and',
#   'done',
#   'already',
#   'used',
#   'all',
#   'my',
#   'multis'],
#  ['yes',
#   'started',
#   'to',
#   'send',
#   'request',
#   'to',
#   'make',
#   'it',
#   'but',
#   'pain',
#   'came',
#   'back',
#   'so',
#   'back',
#   'in',
#   'bed',
#   'double',
#   'coin',
#   'at',
#   'the',
#   'factory',
#   'too',
#   'gotta',
#   'cash',
#   'in',
#   'all',
#   'my',
#   'nitros'],
#  ['really', 'not', 'up', 'to', 'it', 'still', 'tonight', 'babe'],
#  ['ela', 'kano', 'il', 'download', 'come', 'wen', 'ur', 'free'],
#  ['yeah',
#   'do',
#   'don',
#   'stand',
#   'to',
#   'close',
#   'tho',
#   'you',
#   'll',
#   'catch',
#   'something'],
#  ['sorry',
#   'to',
#   'be',
#   'pain',
#   'is',
#   'it',
#   'ok',
#   'if',
#   'we',
#   'meet',
#   'another',
#   'night',
#   'spent',
#   'late',
#   'afternoon',
#   'in',
#   'casualty',
#   'and',
#   'that',
#   'mean',
#   'haven',
#   'done',
#   'any',
#   'of',
#   'stuff',
#   'moro',
#   'and',
#   'that',
#   'includes',
#   'all',
#   'my',
#   'time',
#   'sheet',
#   'and',
#   'that',
#   'sorry'],
#  ['smile',
#   'in',
#   'pleasure',
#   'smile',
#   'in',
#   'pain',
#   'smile',
#   'when',
#   'trouble',
#   'pours',
#   'like',
#   'rain',
#   'smile',
#   'when',
#   'sum',
#   'hurt',
#   'smile',
#   'becoz',
#   'someone',
#   'still',
#   'love',
#   'to',
#   'see',
#   'smiling'],
#  ['please',
#   'call',
#   'our',
#   'customer',
#   'service',
#   'representative',
#   'on',
#   'between',
#   'am',
#   'pm',
#   'you',
#   'have',
#   'won',
#   'guaranteed',
#   'cash',
#   'or',
#   'prize'],
#  ['havent',
#   'planning',
#   'to',
#   'buy',
#   'later',
#   'check',
#   'already',
#   'lido',
#   'only',
#   'got',
#   'show',
#   'in',
#   'afternoon',
#   'finish',
#   'work',
#   'already'],
#  ['your',
#   'free',
#   'ringtone',
#   'is',
#   'waiting',
#   'to',
#   'be',
#   'collected',
#   'simply',
#   'text',
#   'the',
#   'password',
#   'mix',
#   'to',
#   'to',
#   'verify',
#   'get',
#   'usher',
#   'and',
#   'britney',
#   'fml',
#   'po',
#   'box',
#   'mk',
#   'ppw'],
#  ['watching', 'telugu', 'movie', 'wat', 'abt'],
#  ['see',
#   'when',
#   'we',
#   'finish',
#   'we',
#   'have',
#   'load',
#   'of',
#   'loan',
#   'to',
#   'pay'],
#  ['hi',
#   'wk',
#   'been',
#   'ok',
#   'on',
#   'hols',
#   'now',
#   'yes',
#   'on',
#   'for',
#   'bit',
#   'of',
#   'run',
#   'forgot',
#   'that',
#   'have',
#   'hairdresser',
#   'appointment',
#   'at',
#   'four',
#   'so',
#   'need',
#   'to',
#   'get',
#   'home',
#   'shower',
#   'beforehand',
#   'doe',
#   'that',
#   'cause',
#   'prob',
#   'for'],
#  ['see', 'cup', 'of', 'coffee', 'animation'],
#  ['please',
#   'don',
#   'text',
#   'me',
#   'anymore',
#   'have',
#   'nothing',
#   'else',
#   'to',
#   'say'],
#  ['okay',
#   'name',
#   'ur',
#   'price',
#   'long',
#   'it',
#   'legal',
#   'wen',
#   'can',
#   'pick',
#   'them',
#   'up',
#   'ave',
#   'am',
#   'xx'],
#  ['still',
#   'looking',
#   'for',
#   'car',
#   'to',
#   'buy',
#   'and',
#   'have',
#   'not',
#   'gone',
#   'the',
#   'driving',
#   'test',
#   'yet'],
#  ['per',
#   'your',
#   'request',
#   'melle',
#   'melle',
#   'oru',
#   'minnaminunginte',
#   'nurungu',
#   'vettam',
#   'ha',
#   'been',
#   'set',
#   'your',
#   'callertune',
#   'for',
#   'all',
#   'caller',
#   'press',
#   'to',
#   'copy',
#   'your',
#   'friend',
#   'callertune'],
#  ['wow',
#   'you',
#   're',
#   'right',
#   'didn',
#   'mean',
#   'to',
#   'do',
#   'that',
#   'guess',
#   'once',
#   'gave',
#   'up',
#   'on',
#   'boston',
#   'men',
#   'and',
#   'changed',
#   'my',
#   'search',
#   'location',
#   'to',
#   'nyc',
#   'something',
#   'changed',
#   'cuz',
#   'on',
#   'my',
#   'signin',
#   'page',
#   'it',
#   'still',
#   'say',
#   'boston'],
#  ['umma', 'my', 'life', 'and', 'vava', 'umma', 'love', 'you', 'lot', 'dear'],
#  ['thanks',
#   'lot',
#   'for',
#   'your',
#   'wish',
#   'on',
#   'my',
#   'birthday',
#   'thanks',
#   'you',
#   'for',
#   'making',
#   'my',
#   'birthday',
#   'truly',
#   'memorable'],
#  ['aight', 'll', 'hit', 'you', 'up', 'when', 'get', 'some', 'cash'],
#  ['how',
#   'would',
#   'my',
#   'ip',
#   'address',
#   'test',
#   'that',
#   'considering',
#   'my',
#   'computer',
#   'isn',
#   'minecraft',
#   'server'],
#  ['know',
#   'grumpy',
#   'old',
#   'people',
#   'my',
#   'mom',
#   'wa',
#   'like',
#   'you',
#   'better',
#   'not',
#   'be',
#   'lying',
#   'then',
#   'again',
#   'am',
#   'always',
#   'the',
#   'one',
#   'to',
#   'play',
#   'joke'],
#  ['dont', 'worry', 'guess', 'he', 'busy'],
#  ['what', 'is', 'the', 'plural', 'of', 'the', 'noun', 'research'],
#  ['going', 'for', 'dinner', 'msg', 'you', 'after'],
#  ['ok',
#   'wif',
#   'it',
#   'co',
#   'like',
#   'try',
#   'new',
#   'thing',
#   'but',
#   'scared',
#   'dun',
#   'like',
#   'mah',
#   'co',
#   'said',
#   'not',
#   'too',
#   'loud'],
#  ['gent',
#   'we',
#   'are',
#   'trying',
#   'to',
#   'contact',
#   'you',
#   'last',
#   'weekend',
#   'draw',
#   'show',
#   'that',
#   'you',
#   'won',
#   'prize',
#   'guaranteed',
#   'call',
#   'claim',
#   'code',
#   'valid',
#   'hr',
#   'only',
#   'ppm'],
#  ['wa',
#   'ur',
#   'openin',
#   'sentence',
#   'very',
#   'formal',
#   'anyway',
#   'fine',
#   'too',
#   'juz',
#   'tt',
#   'eatin',
#   'too',
#   'much',
#   'puttin',
#   'on',
#   'weight',
#   'haha',
#   'so',
#   'anythin',
#   'special',
#   'happened'],
#  ['entered',
#   'my',
#   'cabin',
#   'my',
#   'pa',
#   'said',
#   'happy',
#   'day',
#   'bos',
#   'felt',
#   'special',
#   'she',
#   'askd',
#   'me',
#   'lunch',
#   'after',
#   'lunch',
#   'she',
#   'invited',
#   'me',
#   'to',
#   'her',
#   'apartment',
#   'we',
#   'went',
#   'there'],
#  ['you',
#   'are',
#   'winner',
#   'have',
#   'been',
#   'specially',
#   'selected',
#   'receive',
#   'or',
#   'holiday',
#   'flight',
#   'inc',
#   'speak',
#   'to',
#   'live',
#   'operator',
#   'claim',
#   'min'],
#  ['goodo',
#   'yes',
#   'we',
#   'must',
#   'speak',
#   'friday',
#   'egg',
#   'potato',
#   'ratio',
#   'for',
#   'tortilla',
#   'needed'],
#  ['hmm',
#   'my',
#   'uncle',
#   'just',
#   'informed',
#   'me',
#   'that',
#   'he',
#   'paying',
#   'the',
#   'school',
#   'directly',
#   'so',
#   'pls',
#   'buy',
#   'food'],
#  ['private',
#   'your',
#   'account',
#   'statement',
#   'for',
#   'show',
#   'unredeemed',
#   'bonus',
#   'point',
#   'to',
#   'claim',
#   'call',
#   'identifier',
#   'code',
#   'expires'],
#  ['urgent',
#   'your',
#   'mobile',
#   'no',
#   'wa',
#   'awarded',
#   'bonus',
#   'caller',
#   'prize',
#   'on',
#   'this',
#   'is',
#   'our',
#   'final',
#   'try',
#   'to',
#   'contact',
#   'call',
#   'from',
#   'landline',
#   'box',
#   'wr',
#   'ppm'],
#  ['here',
#   'is',
#   'my',
#   'new',
#   'address',
#   'apple',
#   'pair',
#   'all',
#   'that',
#   'malarky'],
#  ['today',
#   'voda',
#   'number',
#   'ending',
#   'are',
#   'selected',
#   'to',
#   'receive',
#   'award',
#   'if',
#   'you',
#   'have',
#   'match',
#   'please',
#   'call',
#   'quoting',
#   'claim',
#   'code',
#   'standard',
#   'rate',
#   'app'],
#  ['am',
#   'going',
#   'to',
#   'sao',
#   'mu',
#   'today',
#   'will',
#   'be',
#   'done',
#   'only',
#   'at'],
#  ['predict', 'wat', 'time', 'll', 'finish', 'buying'],
#  ['good', 'stuff', 'will', 'do'],
#  ['just',
#   'so',
#   'that',
#   'you',
#   'know',
#   'yetunde',
#   'hasn',
#   'sent',
#   'money',
#   'yet',
#   'just',
#   'sent',
#   'her',
#   'text',
#   'not',
#   'to',
#   'bother',
#   'sending',
#   'so',
#   'it',
#   'over',
#   'you',
#   'dont',
#   'have',
#   'to',
#   'involve',
#   'yourself',
#   'in',
#   'anything',
#   'shouldn',
#   'have',
#   'imposed',
#   'anything',
#   'on',
#   'you',
#   'in',
#   'the',
#   'first',
#   'place',
#   'so',
#   'for',
#   'that',
#   'apologise'],
#  ['are', 'you', 'there', 'in', 'room'],
#  ['hey',
#   'girl',
#   'how',
#   'hope',
#   'well',
#   'me',
#   'an',
#   'del',
#   'bak',
#   'again',
#   'long',
#   'time',
#   'no',
#   'give',
#   'me',
#   'call',
#   'sum',
#   'time',
#   'from',
#   'lucyxx'],
#  ['how', 'much', 'doe', 'it', 'cost'],
#  ['home'],
#  ['dear', 'will', 'call', 'tmorrow', 'pls', 'accomodate'],
#  ['first', 'answer', 'my', 'question'],
#  ['sunshine',
#   'quiz',
#   'wkly',
#   'win',
#   'top',
#   'sony',
#   'dvd',
#   'player',
#   'if',
#   'know',
#   'which',
#   'country',
#   'the',
#   'algarve',
#   'is',
#   'in',
#   'txt',
#   'ansr',
#   'to',
#   'sp',
#   'tyrone'],
#  ['want',
#   'get',
#   'laid',
#   'tonight',
#   'want',
#   'real',
#   'dogging',
#   'location',
#   'sent',
#   'direct',
#   'ur',
#   'mob',
#   'join',
#   'the',
#   'uk',
#   'largest',
#   'dogging',
#   'network',
#   'bt',
#   'txting',
#   'gravel',
#   'to',
#   'nt',
#   'ec',
#   'msg'],
#  ['only', 'haf', 'msn', 'it', 'yijue', 'hotmail', 'com'],
#  ['he', 'is', 'there', 'you', 'call', 'and', 'meet', 'him'],
#  ['no', 'no', 'will', 'check', 'all', 'room', 'befor', 'activity'],
#  ['you',
#   'll',
#   'not',
#   'rcv',
#   'any',
#   'more',
#   'msg',
#   'from',
#   'the',
#   'chat',
#   'svc',
#   'for',
#   'free',
#   'hardcore',
#   'service',
#   'text',
#   'go',
#   'to',
#   'if',
#   'get',
#   'nothing',
#   'must',
#   'age',
#   'verify',
#   'with',
#   'yr',
#   'network',
#   'try',
#   'again'],
#  ['got',
#   'lazy',
#   'to',
#   'type',
#   'forgot',
#   'in',
#   'lect',
#   'saw',
#   'pouch',
#   'but',
#   'like',
#   'not',
#   'nice'],
#  ['text', 'me', 'when', 'you', 're', 'on', 'the', 'way'],
#  ['sir', 'waiting', 'for', 'your', 'mail'],
#  ['swt',
#   'thought',
#   'nver',
#   'get',
#   'tired',
#   'of',
#   'doing',
#   'little',
#   'thing',
#   'lovable',
#   'person',
#   'coz',
#   'somtimes',
#   'those',
#   'little',
#   'thing',
#   'occupy',
#   'biggest',
#   'part',
#   'in',
#   'their',
#   'heart',
#   'gud',
#   'ni'],
#  ['know', 'you', 'are', 'can', 'you', 'pls', 'open', 'the', 'back'],
#  ['yes', 'see', 'ya', 'not', 'on', 'the', 'dot'],
#  ['whats', 'the', 'staff', 'name', 'who', 'is', 'taking', 'class', 'for'],
#  ['freemsg',
#   'why',
#   'haven',
#   'you',
#   'replied',
#   'to',
#   'my',
#   'text',
#   'randy',
#   'sexy',
#   'female',
#   'and',
#   'live',
#   'local',
#   'luv',
#   'to',
#   'hear',
#   'from',
#   'netcollex',
#   'ltd',
#   'per',
#   'msg',
#   'reply',
#   'stop',
#   'to',
#   'end'],
#  ['ummma',
#   'will',
#   'call',
#   'after',
#   'check',
#   'in',
#   'our',
#   'life',
#   'will',
#   'begin',
#   'from',
#   'qatar',
#   'so',
#   'pls',
#   'pray',
#   'very',
#   'hard'],
#  ['deleted', 'my', 'contact', 'that', 'why'],
#  ['sindu', 'got', 'job', 'in', 'birla', 'soft'],
#  ['the', 'wine', 'is', 'flowing', 'and', 'have', 'nevering'],
#  ['yup',
#   'thk',
#   'cine',
#   'is',
#   'better',
#   'co',
#   'no',
#   'need',
#   'go',
#   'down',
#   'plaza',
#   'mah'],
#  ['ok', 'ur', 'typical', 'reply'],
#  ['per',
#   'your',
#   'request',
#   'melle',
#   'melle',
#   'oru',
#   'minnaminunginte',
#   'nurungu',
#   'vettam',
#   'ha',
#   'been',
#   'set',
#   'your',
#   'callertune',
#   'for',
#   'all',
#   'caller',
#   'press',
#   'to',
#   'copy',
#   'your',
#   'friend',
#   'callertune'],
#  ['you',
#   'are',
#   'everywhere',
#   'dirt',
#   'on',
#   'the',
#   'floor',
#   'the',
#   'window',
#   'even',
#   'on',
#   'my',
#   'shirt',
#   'and',
#   'sometimes',
#   'when',
#   'open',
#   'my',
#   'mouth',
#   'you',
#   'are',
#   'all',
#   'that',
#   'come',
#   'flowing',
#   'out',
#   'dream',
#   'of',
#   'my',
#   'world',
#   'without',
#   'you',
#   'then',
#   'half',
#   'my',
#   'chore',
#   'are',
#   'out',
#   'too',
#   'time',
#   'of',
#   'joy',
#   'for',
#   'me',
#   'lot',
#   'of',
#   'tv',
#   'show',
#   'll',
#   'see',
#   'but',
#   'guess',
#   'like',
#   'all',
#   'thing',
#   'you',
#   'just',
#   'must',
#   'exist',
#   'like',
#   'rain',
#   'hail',
#   'and',
#   'mist',
#   'and',
#   'when',
#   'my',
#   'time',
#   'here',
#   'is',
#   'done',
#   'you',
#   'and',
#   'become',
#   'one'],
#  ['aaooooright', 'are', 'you', 'at', 'work'],
#  ['leaving', 'my', 'house', 'now'],
#  ['hello',
#   'my',
#   'love',
#   'what',
#   'are',
#   'you',
#   'doing',
#   'did',
#   'you',
#   'get',
#   'to',
#   'that',
#   'interview',
#   'today',
#   'are',
#   'you',
#   'you',
#   'happy',
#   'are',
#   'you',
#   'being',
#   'good',
#   'boy',
#   'do',
#   'you',
#   'think',
#   'of',
#   'me',
#   'are',
#   'you',
#   'missing',
#   'me'],
#  ['customer',
#   'service',
#   'annoncement',
#   'you',
#   'have',
#   'new',
#   'year',
#   'delivery',
#   'waiting',
#   'for',
#   'you',
#   'please',
#   'call',
#   'now',
#   'to',
#   'arrange',
#   'delivery'],
#  ['you',
#   'are',
#   'winner',
#   'have',
#   'been',
#   'specially',
#   'selected',
#   'receive',
#   'cash',
#   'or',
#   'holiday',
#   'flight',
#   'inc',
#   'speak',
#   'to',
#   'live',
#   'operator',
#   'claim'],
#  ['keep',
#   'yourself',
#   'safe',
#   'for',
#   'me',
#   'because',
#   'need',
#   'you',
#   'and',
#   'miss',
#   'you',
#   'already',
#   'and',
#   'envy',
#   'everyone',
#   'that',
#   'see',
#   'you',
#   'in',
#   'real',
#   'life'],
#  ['new',
#   'car',
#   'and',
#   'house',
#   'for',
#   'my',
#   'parent',
#   'have',
#   'only',
#   'new',
#   'job',
#   'in',
#   'hand'],
#  ['so',
#   'in',
#   'love',
#   'with',
#   'you',
#   'excited',
#   'each',
#   'day',
#   'spend',
#   'with',
#   'you',
#   'you',
#   'make',
#   'me',
#   'so',
#   'happy'],
#  ['pls',
#   'stop',
#   'bootydelious',
#   'is',
#   'inviting',
#   'you',
#   'to',
#   'be',
#   'her',
#   'friend',
#   'reply',
#   'yes',
#   'or',
#   'no',
#   'see',
#   'her',
#   'www',
#   'sm',
#   'ac',
#   'bootydelious',
#   'stop',
#   'send',
#   'stop',
#   'frnd',
#   'to'],
#  ['bangbabes',
#   'ur',
#   'order',
#   'is',
#   'on',
#   'the',
#   'way',
#   'should',
#   'receive',
#   'service',
#   'msg',
#   'download',
#   'ur',
#   'content',
#   'if',
#   'do',
#   'not',
#   'goto',
#   'wap',
#   'bangb',
#   'tv',
#   'on',
#   'ur',
#   'mobile',
#   'internet',
#   'service',
#   'menu'],
#  ['place', 'all', 'ur', 'point', 'on', 'culture', 'module', 'already'],
#  ['urgent',
#   'we',
#   'are',
#   'trying',
#   'to',
#   'contact',
#   'you',
#   'last',
#   'weekend',
#   'draw',
#   'show',
#   'that',
#   'you',
#   'have',
#   'won',
#   'prize',
#   'guaranteed',
#   'call',
#   'claim',
#   'code',
#   'valid',
#   'hr',
#   'only'],
#  ['hi',
#   'frnd',
#   'which',
#   'is',
#   'best',
#   'way',
#   'to',
#   'avoid',
#   'missunderstding',
#   'wit',
#   'our',
#   'beloved',
#   'one'],
#  ['great',
#   'escape',
#   'fancy',
#   'the',
#   'bridge',
#   'but',
#   'need',
#   'her',
#   'lager',
#   'see',
#   'you',
#   'tomo'],
#  ['yes',
#   'it',
#   'completely',
#   'in',
#   'out',
#   'of',
#   'form',
#   'clark',
#   'also',
#   'utter',
#   'waste'],
#  ['sir', 'need', 'axis', 'bank', 'account', 'no', 'and', 'bank', 'address'],
#  ['hmmm',
#   'thk',
#   'sure',
#   'got',
#   'time',
#   'to',
#   'hop',
#   'ard',
#   'ya',
#   'can',
#   'go',
#   'free',
#   'abt',
#   'muz',
#   'call',
#   'to',
#   'discus',
#   'liao'],
#  ['what', 'time', 'you', 'coming', 'down', 'later'],
#  ['bloody',
#   'hell',
#   'cant',
#   'believe',
#   'you',
#   'forgot',
#   'my',
#   'surname',
#   'mr',
#   'ill',
#   'give',
#   'clue',
#   'it',
#   'spanish',
#   'and',
#   'begin',
#   'with'],
#  ['well',
#   'gonna',
#   'finish',
#   'my',
#   'bath',
#   'now',
#   'have',
#   'good',
#   'fine',
#   'night'],
#  ['let',
#   'me',
#   'know',
#   'when',
#   'you',
#   've',
#   'got',
#   'the',
#   'money',
#   'so',
#   'carlos',
#   'can',
#   'make',
#   'the',
#   'call'],
#  ['still', 'going', 'to', 'the', 'mall'],
#  ['turn',
#   'out',
#   'my',
#   'friend',
#   'are',
#   'staying',
#   'for',
#   'the',
#   'whole',
#   'show',
#   'and',
#   'won',
#   'be',
#   'back',
#   'til',
#   'lt',
#   'gt',
#   'so',
#   'feel',
#   'free',
#   'to',
#   'go',
#   'ahead',
#   'and',
#   'smoke',
#   'that',
#   'lt',
#   'gt',
#   'worth'],
#  ['text',
#   'her',
#   'if',
#   'she',
#   'doesnt',
#   'reply',
#   'let',
#   'me',
#   'know',
#   'so',
#   'can',
#   'have',
#   'her',
#   'log',
#   'in'],
#  ['hi',
#   'you',
#   'just',
#   'spoke',
#   'to',
#   'maneesha',
#   'we',
#   'like',
#   'to',
#   'know',
#   'if',
#   'you',
#   'were',
#   'satisfied',
#   'with',
#   'the',
#   'experience',
#   'reply',
#   'toll',
#   'free',
#   'with',
#   'yes',
#   'or',
#   'no'],
#  ['you',
#   'lifted',
#   'my',
#   'hope',
#   'with',
#   'the',
#   'offer',
#   'of',
#   'money',
#   'am',
#   'in',
#   'need',
#   'especially',
#   'when',
#   'the',
#   'end',
#   'of',
#   'the',
#   'month',
#   'approach',
#   'and',
#   'it',
#   'hurt',
#   'my',
#   'studying',
#   'anyways',
#   'have',
#   'gr',
#   'weekend'],
#  ['lol', 'no', 'can', 'trust', 'me'],
#  ['ok',
#   'am',
#   'gentleman',
#   'and',
#   'will',
#   'treat',
#   'you',
#   'with',
#   'dignity',
#   'and',
#   'respect'],
#  ['he', 'will', 'you', 'guy', 'close'],
#  ['going', 'on', 'nothing', 'great', 'bye'],
#  ['hello',
#   'handsome',
#   'are',
#   'you',
#   'finding',
#   'that',
#   'job',
#   'not',
#   'being',
#   'lazy',
#   'working',
#   'towards',
#   'getting',
#   'back',
#   'that',
#   'net',
#   'for',
#   'mummy',
#   'where',
#   'my',
#   'boytoy',
#   'now',
#   'doe',
#   'he',
#   'miss',
#   'me'],
#  ['haha', 'awesome', 'be', 'there', 'in', 'minute'],
#  ['please',
#   'call',
#   'our',
#   'customer',
#   'service',
#   'representative',
#   'on',
#   'freephone',
#   'between',
#   'am',
#   'pm',
#   'you',
#   'have',
#   'won',
#   'guaranteed',
#   'cash',
#   'or',
#   'prize'],
#  ['have',
#   'you',
#   'got',
#   'xmas',
#   'radio',
#   'time',
#   'if',
#   'not',
#   'will',
#   'get',
#   'it',
#   'now'],
#  ['jus',
#   'reached',
#   'home',
#   'go',
#   'bathe',
#   'first',
#   'but',
#   'my',
#   'si',
#   'using',
#   'net',
#   'tell',
#   'when',
#   'she',
#   'finish'],
#  ['are',
#   'you',
#   'unique',
#   'enough',
#   'find',
#   'out',
#   'from',
#   'th',
#   'august',
#   'www',
#   'areyouunique',
#   'co',
#   'uk'],
#  ['sorry',
#   've',
#   'joined',
#   'the',
#   'league',
#   'of',
#   'people',
#   'that',
#   'dont',
#   'keep',
#   'in',
#   'touch',
#   'you',
#   'mean',
#   'great',
#   'deal',
#   'to',
#   'me',
#   'you',
#   'have',
#   'been',
#   'friend',
#   'at',
#   'all',
#   'time',
#   'even',
#   'at',
#   'great',
#   'personal',
#   'cost',
#   'do',
#   'have',
#   'great',
#   'week'],
#  ['hi', 'finally', 'completed', 'the', 'course'],
#  ['it',
#   'will',
#   'stop',
#   'on',
#   'itself',
#   'however',
#   'suggest',
#   'she',
#   'stay',
#   'with',
#   'someone',
#   'that',
#   'will',
#   'be',
#   'able',
#   'to',
#   'give',
#   'or',
#   'for',
#   'every',
#   'stool'],
#  ['how',
#   'are',
#   'you',
#   'doing',
#   'hope',
#   'you',
#   've',
#   'settled',
#   'in',
#   'for',
#   'the',
#   'new',
#   'school',
#   'year',
#   'just',
#   'wishin',
#   'you',
#   'gr',
#   'day'],
#  ['gud', 'mrng', 'dear', 'hav', 'nice', 'day'],
#  ['did', 'got', 'that', 'person', 'story'],
#  ['is',
#   'your',
#   'hamster',
#   'dead',
#   'hey',
#   'so',
#   'tmr',
#   'meet',
#   'you',
#   'at',
#   'pm',
#   'orchard',
#   'mrt'],
#  ['hi',
#   'it',
#   'kate',
#   'how',
#   'is',
#   'your',
#   'evening',
#   'hope',
#   'can',
#   'see',
#   'you',
#   'tomorrow',
#   'for',
#   'bit',
#   'but',
#   'have',
#   'to',
#   'bloody',
#   'babyjontet',
#   'txt',
#   'back',
#   'if',
#   'can',
#   'xxx'],
#  ['found', 'it', 'enc', 'lt', 'gt', 'where', 'you', 'at'],
#  ['sent', 'you', 'lt', 'gt', 'buck'],
#  ['hello',
#   'darlin',
#   'ive',
#   'finished',
#   'college',
#   'now',
#   'so',
#   'txt',
#   'me',
#   'when',
#   'finish',
#   'if',
#   'can',
#   'love',
#   'kate',
#   'xxx'],
#  ['your',
#   'account',
#   'ha',
#   'been',
#   'refilled',
#   'successfully',
#   'by',
#   'inr',
#   'lt',
#   'decimal',
#   'gt',
#   'your',
#   'keralacircle',
#   'prepaid',
#   'account',
#   'balance',
#   'is',
#   'lt',
#   'decimal',
#   'gt',
#   'your',
#   'transaction',
#   'id',
#   'is',
#   'kr',
#   'lt',
#   'gt'],
#  ['goodmorning', 'sleeping', 'ga'],
#  ['call', 'me', 'alter', 'at', 'ok'],
#  ['say',
#   'until',
#   'like',
#   'dat',
#   'dun',
#   'buy',
#   'ericsson',
#   'oso',
#   'cannot',
#   'oredi',
#   'lar'],
#  ['entered',
#   'my',
#   'cabin',
#   'my',
#   'pa',
#   'said',
#   'happy',
#   'day',
#   'bos',
#   'felt',
#   'special',
#   'she',
#   'askd',
#   'me',
#   'lunch',
#   'after',
#   'lunch',
#   'she',
#   'invited',
#   'me',
#   'to',
#   'her',
#   'apartment',
#   'we',
#   'went',
#   'there'],
#  ['aight', 'yo', 'dat', 'straight', 'dogg'],
#  ['you',
#   'please',
#   'give',
#   'connection',
#   'today',
#   'itself',
#   'before',
#   'lt',
#   'decimal',
#   'gt',
#   'or',
#   'refund',
#   'the',
#   'bill'],
#  ['both', 'shoot', 'big', 'load', 'so', 'get', 'ready'],
#  ['what',
#   'up',
#   'bruv',
#   'hope',
#   'you',
#   'had',
#   'great',
#   'break',
#   'do',
#   'have',
#   'rewarding',
#   'semester'],
#  ['home', 'so', 'we', 'can', 'always', 'chat'],
#  ['good', 'study', 'well'],
#  ['yup', 'how', 'noe', 'leh'],
#  ['sound', 'great', 'are', 'you', 'home', 'now'],
#  ['finally',
#   'the',
#   'match',
#   'heading',
#   'towards',
#   'draw',
#   'your',
#   'prediction'],
#  ['tired', 'haven', 'slept', 'well', 'the', 'past', 'few', 'night'],
#  ['easy', 'ah', 'sen', 'got', 'selected', 'mean', 'it', 'good'],
#  ['have', 'to', 'take', 'exam', 'with', 'march'],
#  ['yeah',
#   'you',
#   'should',
#   'think',
#   'you',
#   'can',
#   'use',
#   'your',
#   'gt',
#   'atm',
#   'now',
#   'to',
#   'register',
#   'not',
#   'sure',
#   'but',
#   'if',
#   'there',
#   'anyway',
#   'can',
#   'help',
#   'let',
#   'me',
#   'know',
#   'but',
#   'when',
#   'you',
#   'do',
#   'be',
#   'sure',
#   'you',
#   'are',
#   'ready'],
#  ['ok', 'no', 'prob', 'take', 'ur', 'time'],
#  ['there',
#   'is',
#   'called',
#   'ubandu',
#   'which',
#   'will',
#   'run',
#   'without',
#   'installing',
#   'in',
#   'hard',
#   'disk',
#   'you',
#   'can',
#   'use',
#   'that',
#   'to',
#   'copy',
#   'the',
#   'important',
#   'file',
#   'in',
#   'system',
#   'and',
#   'give',
#   'it',
#   'to',
#   'repair',
#   'shop'],
#  ['sorry', 'll', 'call', 'later'],
#  ['say',
#   'leh',
#   'of',
#   'course',
#   'nothing',
#   'happen',
#   'lar',
#   'not',
#   'say',
#   'romantic',
#   'jus',
#   'bit',
#   'only',
#   'lor',
#   'thk',
#   'nite',
#   'scenery',
#   'not',
#   'so',
#   'nice',
#   'leh'],
#  ['new',
#   'mobile',
#   'from',
#   'must',
#   'go',
#   'txt',
#   'nokia',
#   'to',
#   'no',
#   'collect',
#   'yours',
#   'today',
#   'from',
#   'only',
#   'www',
#   'tc',
#   'biz',
#   'optout',
#   'gbp',
#   'mtmsg'],
#  ['would',
#   'really',
#   'appreciate',
#   'if',
#   'you',
#   'call',
#   'me',
#   'just',
#   'need',
#   'someone',
#   'to',
#   'talk',
#   'to'],
#  ['will',
#   'meet',
#   'ur',
#   'dream',
#   'partner',
#   'soon',
#   'is',
#   'ur',
#   'career',
#   'off',
#   'flyng',
#   'start',
#   'find',
#   'out',
#   'free',
#   'txt',
#   'horo',
#   'followed',
#   'by',
#   'ur',
#   'star',
#   'sign',
#   'horo',
#   'aries'],
#  ['hey', 'company', 'elama', 'po', 'mudyadhu'],
#  ['life',
#   'is',
#   'more',
#   'strict',
#   'than',
#   'teacher',
#   'bcoz',
#   'teacher',
#   'teach',
#   'lesson',
#   'amp',
#   'then',
#   'conduct',
#   'exam',
#   'but',
#   'life',
#   'first',
#   'conduct',
#   'exam',
#   'amp',
#   'then',
#   'teach',
#   'lesson',
#   'happy',
#   'morning'],
#  ['dear', 'good', 'morning', 'now', 'only', 'am', 'up'],
#  ['get',
#   'down',
#   'in',
#   'gandhipuram',
#   'and',
#   'walk',
#   'to',
#   'cross',
#   'cut',
#   'road',
#   'right',
#   'side',
#   'lt',
#   'gt',
#   'street',
#   'road',
#   'and',
#   'turn',
#   'at',
#   'first',
#   'right'],
#  ['dear', 'we', 'are', 'going', 'to', 'our', 'rubber', 'place'],
#  ['sorry', 'battery', 'died', 'yeah', 'here'],
#  ['yes', 'here', 'tv', 'is', 'always', 'available', 'in', 'work', 'place'],
#  ['text',
#   'meet',
#   'someone',
#   'sexy',
#   'today',
#   'can',
#   'find',
#   'date',
#   'or',
#   'even',
#   'flirt',
#   'it',
#   'up',
#   'to',
#   'join',
#   'just',
#   'reply',
#   'with',
#   'name',
#   'age',
#   'eg',
#   'sam',
#   'msg',
#   'recd',
#   'thirtyeight',
#   'penny'],
#  ['have', 'printed', 'it', 'oh', 'so', 'lt', 'gt', 'come', 'upstairs'],
#  ['or',
#   'ill',
#   'be',
#   'little',
#   'closer',
#   'like',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'on',
#   'the',
#   'same',
#   'street'],
#  ['where', 'are', 'you', 'when', 'wil', 'you', 'reach', 'here'],
#  ['new',
#   'theory',
#   'argument',
#   'win',
#   'situation',
#   'but',
#   'loses',
#   'the',
#   'person',
#   'so',
#   'dont',
#   'argue',
#   'with',
#   'ur',
#   'friend',
#   'just',
#   'kick',
#   'them',
#   'amp',
#   'say',
#   'always',
#   'correct'],
#  ['have',
#   'secret',
#   'admirer',
#   'who',
#   'is',
#   'looking',
#   'make',
#   'contact',
#   'with',
#   'find',
#   'out',
#   'who',
#   'they',
#   'reveal',
#   'who',
#   'think',
#   'ur',
#   'so',
#   'special',
#   'call',
#   'on'],
#  ['tomarrow', 'final', 'hearing', 'on', 'my', 'laptop', 'case', 'so', 'cant'],
#  ['tel', 'me', 'avent', 'done', 'sportsx'],
#  ['okay',
#   'no',
#   'no',
#   'just',
#   'shining',
#   'on',
#   'that',
#   'wa',
#   'meant',
#   'to',
#   'be',
#   'signing',
#   'but',
#   'that',
#   'sound',
#   'better'],
#  ['although',
#   'told',
#   'dat',
#   'into',
#   'baig',
#   'face',
#   'watch',
#   'now',
#   'but',
#   'really',
#   'like',
#   'watch',
#   'gave',
#   'co',
#   'it',
#   'fr',
#   'thanx',
#   'everything',
#   'dat',
#   've',
#   'done',
#   'today',
#   'touched'],
#  ['don', 'remember', 'that', 'old', 'commercial'],
#  ['too',
#   'late',
#   'said',
#   'have',
#   'the',
#   'website',
#   'didn',
#   'have',
#   'or',
#   'dont',
#   'have',
#   'the',
#   'slipper'],
#  ['asked', 'you', 'to', 'call', 'him', 'now', 'ok'],
#  ['kallis', 'wont', 'bat', 'in', 'nd', 'inning'],
#  ['it',
#   'didnt',
#   'work',
#   'again',
#   'oh',
#   'ok',
#   'goodnight',
#   'then',
#   'll',
#   'fix',
#   'and',
#   'have',
#   'it',
#   'ready',
#   'by',
#   'the',
#   'time',
#   'you',
#   'wake',
#   'up',
#   'you',
#   'are',
#   'very',
#   'dearly',
#   'missed',
#   'have',
#   'good',
#   'night',
#   'sleep'],
#  ['congratulation',
#   'ur',
#   'awarded',
#   'of',
#   'cd',
#   'voucher',
#   'or',
#   'gift',
#   'guaranteed',
#   'free',
#   'entry',
#   'wkly',
#   'draw',
#   'txt',
#   'music',
#   'to',
#   'tncs',
#   'www',
#   'ldew',
#   'com',
#   'win',
#   'ppmx',
#   'age'],
#  ['ranjith', 'cal', 'drpd', 'deeraj', 'and', 'deepak', 'min', 'hold'],
#  ['wen',
#   'ur',
#   'lovable',
#   'bcums',
#   'angry',
#   'wid',
#   'dnt',
#   'take',
#   'it',
#   'seriously',
#   'coz',
#   'being',
#   'angry',
#   'is',
#   'most',
#   'childish',
#   'true',
#   'way',
#   'of',
#   'showing',
#   'deep',
#   'affection',
#   'care',
#   'luv',
#   'kettoda',
#   'manda',
#   'have',
#   'nice',
#   'day',
#   'da'],
#  ['what', 'you', 'doing', 'how', 'are', 'you'],
#  ['ups',
#   'which',
#   'is',
#   'day',
#   'also',
#   'and',
#   'the',
#   'shipping',
#   'company',
#   'that',
#   'take',
#   'wks',
#   'the',
#   'other',
#   'way',
#   'is',
#   'usps',
#   'which',
#   'take',
#   'week',
#   'but',
#   'when',
#   'it',
#   'get',
#   'to',
#   'lag',
#   'you',
#   'may',
#   'have',
#   'to',
#   'bribe',
#   'nipost',
#   'to',
#   'get',
#   'your',
#   'stuff'],
#  ['back', 'lemme', 'know', 'when', 'you', 're', 'ready'],
#  ['don',
#   'necessarily',
#   'expect',
#   'it',
#   'to',
#   'be',
#   'done',
#   'before',
#   'you',
#   'get',
#   'back',
#   'though',
#   'because',
#   'just',
#   'now',
#   'headin',
#   'out'],
#  ['mmm', 'so', 'yummy', 'babe', 'nice', 'jolt', 'to', 'the', 'suzy'],
#  ['where', 'are', 'you', 'lover', 'need', 'you'],
#  ['we',
#   'tried',
#   'to',
#   'contact',
#   'you',
#   're',
#   'your',
#   'reply',
#   'to',
#   'our',
#   'offer',
#   'of',
#   'video',
#   'handset',
#   'anytime',
#   'network',
#   'min',
#   'unlimited',
#   'text',
#   'camcorder',
#   'reply',
#   'or',
#   'call',
#   'now'],
#  ['parked',
#   'next',
#   'to',
#   'mini',
#   'when',
#   'are',
#   'you',
#   'coming',
#   'in',
#   'today',
#   'do',
#   'you',
#   'think'],
#  ['yup'],
#  ['anyway',
#   'going',
#   'shopping',
#   'on',
#   'my',
#   'own',
#   'now',
#   'co',
#   'my',
#   'si',
#   'not',
#   'done',
#   'yet',
#   'dun',
#   'disturb',
#   'liao'],
#  ['my', 'no', 'in', 'luton', 'ring', 'me', 'if', 'ur', 'around'],
#  ['hey',
#   'am',
#   'really',
#   'horny',
#   'want',
#   'to',
#   'chat',
#   'or',
#   'see',
#   'me',
#   'naked',
#   'text',
#   'hot',
#   'to',
#   'text',
#   'charged',
#   'at',
#   'pm',
#   'to',
#   'unsubscribe',
#   'text',
#   'stop'],
#  ['why', 'you', 'dint', 'come', 'with'],
#  ['same', 'wana', 'plan', 'trip', 'sometme', 'then'],
#  ['not', 'sure', 'yet', 'still', 'trying', 'to', 'get', 'hold', 'of', 'him'],
#  ['ur',
#   'ringtone',
#   'service',
#   'ha',
#   'changed',
#   'free',
#   'credit',
#   'go',
#   'to',
#   'club',
#   'mobile',
#   'com',
#   'to',
#   'choose',
#   'content',
#   'now',
#   'stop',
#   'txt',
#   'club',
#   'stop',
#   'to',
#   'wk',
#   'club',
#   'po',
#   'box',
#   'mk',
#   'wt'],
#  ['the', 'evo', 'just', 'had', 'to', 'download', 'flash', 'jealous'],
#  ['ringtone',
#   'club',
#   'get',
#   'the',
#   'uk',
#   'single',
#   'chart',
#   'on',
#   'your',
#   'mobile',
#   'each',
#   'week',
#   'and',
#   'choose',
#   'any',
#   'top',
#   'quality',
#   'ringtone',
#   'this',
#   'message',
#   'is',
#   'free',
#   'of',
#   'charge'],
#  ['come',
#   'to',
#   'mu',
#   'we',
#   're',
#   'sorting',
#   'out',
#   'our',
#   'narcotic',
#   'situation'],
#  ['night',
#   'ha',
#   'ended',
#   'for',
#   'another',
#   'day',
#   'morning',
#   'ha',
#   'come',
#   'in',
#   'special',
#   'way',
#   'may',
#   'you',
#   'smile',
#   'like',
#   'the',
#   'sunny',
#   'ray',
#   'and',
#   'leaf',
#   'your',
#   'worry',
#   'at',
#   'the',
#   'blue',
#   'blue',
#   'bay'],
#  ['hmv',
#   'bonus',
#   'special',
#   'pound',
#   'of',
#   'genuine',
#   'hmv',
#   'voucher',
#   'to',
#   'be',
#   'won',
#   'just',
#   'answer',
#   'easy',
#   'question',
#   'play',
#   'now',
#   'send',
#   'hmv',
#   'to',
#   'more',
#   'info',
#   'www',
#   'percent',
#   'real',
#   'com'],
#  ['usf', 'guess', 'might', 'well', 'take', 'car'],
#  ['no', 'objection', 'my', 'bf', 'not', 'coming'],
#  ['thanx'],
#  ['tell', 'rob', 'to', 'mack', 'his', 'gf', 'in', 'the', 'theater'],
#  ['awesome', 'll', 'see', 'you', 'in', 'bit'],
#  ['just',
#   'sent',
#   'it',
#   'so',
#   'what',
#   'type',
#   'of',
#   'food',
#   'do',
#   'you',
#   'like'],
#  ['all',
#   'done',
#   'all',
#   'handed',
#   'in',
#   'celebration',
#   'in',
#   'full',
#   'swing',
#   'yet'],
#  ['you', 'got', 'called', 'tool'],
#  ['wen',
#   'miss',
#   'someone',
#   'the',
#   'person',
#   'is',
#   'definitely',
#   'special',
#   'for',
#   'but',
#   'if',
#   'the',
#   'person',
#   'is',
#   'so',
#   'special',
#   'why',
#   'to',
#   'miss',
#   'them',
#   'just',
#   'keep',
#   'in',
#   'touch',
#   'gdeve'],
#  ['ok', 'asked', 'for', 'money', 'how', 'far'],
#  ['okie'],
#  ['yeah',
#   'think',
#   'my',
#   'usual',
#   'guy',
#   'still',
#   'passed',
#   'out',
#   'from',
#   'last',
#   'night',
#   'if',
#   'you',
#   'get',
#   'ahold',
#   'of',
#   'anybody',
#   'let',
#   'me',
#   'know',
#   'and',
#   'll',
#   'throw',
#   'down'],
#  ['might',
#   'come',
#   'by',
#   'tonight',
#   'then',
#   'if',
#   'my',
#   'class',
#   'let',
#   'out',
#   'early'],
#  ['ok'],
#  ['hi',
#   'baby',
#   'im',
#   'cruisin',
#   'with',
#   'my',
#   'girl',
#   'friend',
#   'what',
#   'up',
#   'give',
#   'me',
#   'call',
#   'in',
#   'and',
#   'hour',
#   'at',
#   'home',
#   'if',
#   'thats',
#   'alright',
#   'or',
#   'fone',
#   'me',
#   'on',
#   'this',
#   'fone',
#   'now',
#   'love',
#   'jenny',
#   'xxx'],
#  ['my',
#   'life',
#   'mean',
#   'lot',
#   'to',
#   'me',
#   'not',
#   'because',
#   'love',
#   'my',
#   'life',
#   'but',
#   'because',
#   'love',
#   'the',
#   'people',
#   'in',
#   'my',
#   'life',
#   'the',
#   'world',
#   'call',
#   'them',
#   'friend',
#   'call',
#   'them',
#   'my',
#   'world',
#   'ge'],
#  ['dear',
#   'shall',
#   'mail',
#   'tonite',
#   'busy',
#   'in',
#   'the',
#   'street',
#   'shall',
#   'update',
#   'you',
#   'tonite',
#   'thing',
#   'are',
#   'looking',
#   'ok',
#   'varunnathu',
#   'edukkukayee',
#   'raksha',
#   'ollu',
#   'but',
#   'good',
#   'one',
#   'in',
#   'real',
#   'sense'],
#  ['hey', 'you', 'told', 'your', 'name', 'to', 'gautham', 'ah'],
#  ['haf', 'found', 'him', 'feel', 'so', 'stupid', 'da', 'cam', 'wa', 'working'],
#  ['oops', 'got', 'that', 'bit'],
#  ['are', 'you', 'this', 'much', 'buzy'],
#  ['accidentally', 'deleted', 'the', 'message', 'resend', 'please'],
#  ['mobile',
#   'customer',
#   'you',
#   'may',
#   'now',
#   'claim',
#   'your',
#   'free',
#   'camera',
#   'phone',
#   'upgrade',
#   'pay',
#   'go',
#   'sim',
#   'card',
#   'for',
#   'your',
#   'loyalty',
#   'call',
#   'on',
#   'offer',
#   'end',
#   'thfeb',
#   'apply'],
#  ['unless',
#   'it',
#   'situation',
#   'where',
#   'you',
#   'go',
#   'gurl',
#   'would',
#   'be',
#   'more',
#   'appropriate'],
#  ['hurt',
#   'me',
#   'tease',
#   'me',
#   'make',
#   'me',
#   'cry',
#   'but',
#   'in',
#   'the',
#   'end',
#   'of',
#   'my',
#   'life',
#   'when',
#   'die',
#   'plz',
#   'keep',
#   'one',
#   'rose',
#   'on',
#   'my',
#   'grave',
#   'and',
#   'say',
#   'stupid',
#   'miss',
#   'have',
#   'nice',
#   'day',
#   'bslvyl'],
#  ['cant', 'pick', 'the', 'phone', 'right', 'now', 'pls', 'send', 'message'],
#  ['need',
#   'coffee',
#   'run',
#   'tomo',
#   'can',
#   'believe',
#   'it',
#   'that',
#   'time',
#   'of',
#   'week',
#   'already'],
#  ['awesome',
#   'remember',
#   'the',
#   'last',
#   'time',
#   'we',
#   'got',
#   'somebody',
#   'high',
#   'for',
#   'the',
#   'first',
#   'time',
#   'with',
#   'diesel'],
#  ['shit',
#   'that',
#   'is',
#   'really',
#   'shocking',
#   'and',
#   'scary',
#   'cant',
#   'imagine',
#   'for',
#   'second',
#   'def',
#   'up',
#   'for',
#   'night',
#   'out',
#   'do',
#   'think',
#   'there',
#   'is',
#   'somewhere',
#   'could',
#   'crash',
#   'for',
#   'night',
#   'save',
#   'on',
#   'taxi'],
#  ['oh',
#   'and',
#   'by',
#   'the',
#   'way',
#   'you',
#   'do',
#   'have',
#   'more',
#   'food',
#   'in',
#   'your',
#   'fridge',
#   'want',
#   'to',
#   'go',
#   'out',
#   'for',
#   'meal',
#   'tonight'],
#  ['he', 'is', 'womdarfull', 'actor'],
#  ['sm',
#   'ac',
#   'blind',
#   'date',
#   'rodds',
#   'is',
#   'from',
#   'aberdeen',
#   'united',
#   'kingdom',
#   'check',
#   'him',
#   'out',
#   'http',
#   'img',
#   'sm',
#   'ac',
#   'icmb',
#   'cktz',
#   'no',
#   'blind',
#   'date',
#   'send',
#   'hide'],
#  ['yup', 'from', 'what', 'remb', 'think', 'should', 'be', 'can', 'book'],
#  ['jos', 'ask', 'if', 'wana', 'meet', 'up'],
#  ['lol',
#   'yes',
#   'our',
#   'friendship',
#   'is',
#   'hanging',
#   'on',
#   'thread',
#   'cause',
#   'won',
#   'buy',
#   'stuff'],
#  ['themob',
#   'check',
#   'out',
#   'our',
#   'newest',
#   'selection',
#   'of',
#   'content',
#   'game',
#   'tone',
#   'gossip',
#   'babe',
#   'and',
#   'sport',
#   'keep',
#   'your',
#   'mobile',
#   'fit',
#   'and',
#   'funky',
#   'text',
#   'wap',
#   'to'],
#  ['where',
#   'are',
#   'the',
#   'garage',
#   'key',
#   'they',
#   'aren',
#   'on',
#   'the',
#   'bookshelf'],
#  ['today',
#   'is',
#   'accept',
#   'day',
#   'accept',
#   'me',
#   'brother',
#   'sister',
#   'lover',
#   'dear',
#   'best',
#   'clos',
#   'lvblefrnd',
#   'jstfrnd',
#   'cutefrnd',
#   'lifpartnr',
#   'belovd',
#   'swtheart',
#   'bstfrnd',
#   'no',
#   'rply',
#   'mean',
#   'enemy'],
#  ['think',
#   'ur',
#   'smart',
#   'win',
#   'this',
#   'week',
#   'in',
#   'our',
#   'weekly',
#   'quiz',
#   'text',
#   'play',
#   'to',
#   'now',
#   'winnersclub',
#   'po',
#   'box',
#   'uz',
#   'gbp',
#   'week'],
#  ['he',
#   'say',
#   'he',
#   'll',
#   'give',
#   'me',
#   'call',
#   'when',
#   'his',
#   'friend',
#   'got',
#   'the',
#   'money',
#   'but',
#   'that',
#   'he',
#   'definitely',
#   'buying',
#   'before',
#   'the',
#   'end',
#   'of',
#   'the',
#   'week'],
#  ['hi',
#   'the',
#   'way',
#   'wa',
#   'with',
#   'day',
#   'is',
#   'the',
#   'normal',
#   'way',
#   'this',
#   'is',
#   'the',
#   'real',
#   'me',
#   'ur',
#   'unique',
#   'hope',
#   'know',
#   'the',
#   'rest',
#   'of',
#   'mylife',
#   'hope',
#   'find',
#   'wot',
#   'wa',
#   'lost'],
#  ['you', 'made', 'my', 'day', 'do', 'have', 'great', 'day', 'too'],
#  ['advance', 'happy', 'pongal'],
#  ['hmmm',
#   'guess',
#   'we',
#   'can',
#   'go',
#   'kb',
#   'power',
#   'yoga',
#   'haha',
#   'dunno',
#   'we',
#   'can',
#   'tahan',
#   'power',
#   'yoga',
#   'anot',
#   'thk',
#   'got',
#   'lo',
#   'oso',
#   'forgot',
#   'liao'],
#  ['not', 'really', 'dude', 'have', 'no', 'friend', 'afraid'],
#  ['december',
#   'only',
#   'had',
#   'your',
#   'mobile',
#   'mths',
#   'you',
#   'are',
#   'entitled',
#   'to',
#   'update',
#   'to',
#   'the',
#   'latest',
#   'colour',
#   'camera',
#   'mobile',
#   'for',
#   'free',
#   'call',
#   'the',
#   'mobile',
#   'update',
#   'co',
#   'free',
#   'on'],
#  ['coffee', 'cake', 'guess'],
#  ['merry', 'christmas', 'to', 'you', 'too', 'babe', 'love', 'ya', 'kiss'],
#  ['hey',
#   'why',
#   'dont',
#   'we',
#   'just',
#   'go',
#   'watch',
#   'men',
#   'and',
#   'have',
#   'lunch',
#   'haha'],
#  ['cud',
#   'tell',
#   'ppl',
#   'im',
#   'gona',
#   'bit',
#   'co',
#   'bus',
#   'hav',
#   'gon',
#   'past',
#   'co',
#   'they',
#   'were',
#   'full',
#   'im',
#   'still',
#   'waitin',
#   'pete'],
#  ['that',
#   'would',
#   'be',
#   'great',
#   'we',
#   'll',
#   'be',
#   'at',
#   'the',
#   'guild',
#   'could',
#   'meet',
#   'on',
#   'bristol',
#   'road',
#   'or',
#   'somewhere',
#   'will',
#   'get',
#   'in',
#   'touch',
#   'over',
#   'weekend',
#   'our',
#   'plan',
#   'take',
#   'flight',
#   'have',
#   'good',
#   'week'],
#  ['no', 'problem', 'how', 'are', 'you', 'doing'],
#  ['no', 'call', 'message', 'missed', 'call'],
#  ['hi', 'da', 'how', 'is', 'the', 'today', 'class'],
#  ['say',
#   'that',
#   'good',
#   'sign',
#   'but',
#   'well',
#   'you',
#   'know',
#   'my',
#   'track',
#   'record',
#   'at',
#   'reading',
#   'woman'],
#  ['cool', 'text', 'me', 'when', 'you', 're', 'parked'],
#  ['reading',
#   'the',
#   'text',
#   'just',
#   'sent',
#   'you',
#   'it',
#   'meant',
#   'to',
#   'be',
#   'joke',
#   'so',
#   'read',
#   'it',
#   'in',
#   'that',
#   'light'],
#  ['apo', 'good', 'movie'],
#  ['maybe',
#   'could',
#   'get',
#   'book',
#   'out',
#   'tomo',
#   'then',
#   'return',
#   'it',
#   'immediately',
#   'or',
#   'something'],
#  ['call',
#   'germany',
#   'for',
#   'only',
#   'penny',
#   'per',
#   'minute',
#   'call',
#   'from',
#   'fixed',
#   'line',
#   'via',
#   'access',
#   'number',
#   'no',
#   'prepayment',
#   'direct',
#   'access'],
#  ['any',
#   'chance',
#   'you',
#   'might',
#   'have',
#   'had',
#   'with',
#   'me',
#   'evaporated',
#   'soon',
#   'you',
#   'violated',
#   'my',
#   'privacy',
#   'by',
#   'stealing',
#   'my',
#   'phone',
#   'number',
#   'from',
#   'your',
#   'employer',
#   'paperwork',
#   'not',
#   'cool',
#   'at',
#   'all',
#   'please',
#   'do',
#   'not',
#   'contact',
#   'me',
#   'again',
#   'or',
#   'will',
#   'report',
#   'you',
#   'to',
#   'your',
#   'supervisor'],
#  ['valentine',
#   'day',
#   'special',
#   'win',
#   'over',
#   'in',
#   'our',
#   'quiz',
#   'and',
#   'take',
#   'your',
#   'partner',
#   'on',
#   'the',
#   'trip',
#   'of',
#   'lifetime',
#   'send',
#   'go',
#   'to',
#   'now',
#   'msg',
#   'rcvd',
#   'custcare'],
#  ['ta', 'daaaaa', 'am', 'home', 'babe', 'are', 'you', 'still', 'up'],
#  ['cool',
#   'so',
#   'how',
#   'come',
#   'you',
#   'havent',
#   'been',
#   'wined',
#   'and',
# ...
#   'usb',
#   'flash',
#   'drive'],
#  ['gibbs', 'unsold', 'mike', 'hussey'],
#  ['like',
#   'to',
#   'talk',
#   'pa',
#   'but',
#   'am',
#   'not',
#   'able',
#   'to',
#   'dont',
#   'know'],
#  ['dun',
#   'cut',
#   'too',
#   'short',
#   'leh',
#   'dun',
#   'like',
#   'ah',
#   'she',
#   'failed',
#   'she',
#   'quite',
#   'sad'],
#  ['you', 'unbelievable', 'faglord'],
#  ['wife', 'how', 'she', 'knew', 'the', 'time', 'of', 'murder', 'exactly'],
#  ['why', 'do', 'you', 'ask', 'princess'],
#  ['am', 'great', 'princess', 'what', 'are', 'you', 'thinking', 'about', 'me'],
#  ['nutter',
#   'cutter',
#   'ctter',
#   'cttergg',
#   'cttargg',
#   'ctargg',
#   'ctagg',
#   'ie',
#   'you'],
#  ['it',
#   'ok',
#   'noe',
#   're',
#   'busy',
#   'but',
#   'really',
#   'too',
#   'bored',
#   'so',
#   'msg',
#   'oso',
#   'dunno',
#   'wat',
#   'colour',
#   'she',
#   'choose',
#   'me',
#   'one'],
#  ['doesn',
#   'have',
#   'class',
#   'early',
#   'tomorrow',
#   'and',
#   'thus',
#   'shouldn',
#   'be',
#   'trying',
#   'to',
#   'smoke',
#   'at',
#   'lt',
#   'gt'],
#  ['superb',
#   'thought',
#   'be',
#   'grateful',
#   'that',
#   'dont',
#   'have',
#   'everything',
#   'want',
#   'that',
#   'mean',
#   'still',
#   'have',
#   'an',
#   'opportunity',
#   'to',
#   'be',
#   'happier',
#   'tomorrow',
#   'than',
#   'are',
#   'today'],
#  ['hope', 'you', 'are', 'having', 'good', 'week', 'just', 'checking', 'in'],
#  ['used',
#   'to',
#   'it',
#   'just',
#   'hope',
#   'my',
#   'agent',
#   'don',
#   'drop',
#   'me',
#   'since',
#   've',
#   'only',
#   'booked',
#   'few',
#   'thing',
#   'this',
#   'year',
#   'this',
#   'whole',
#   'me',
#   'in',
#   'boston',
#   'them',
#   'in',
#   'nyc',
#   'wa',
#   'an',
#   'experiment'],
#  ['thursday',
#   'night',
#   'yeah',
#   'sure',
#   'thing',
#   'we',
#   'll',
#   'work',
#   'it',
#   'out',
#   'then'],
#  ['your',
#   'free',
#   'ringtone',
#   'is',
#   'waiting',
#   'to',
#   'be',
#   'collected',
#   'simply',
#   'text',
#   'the',
#   'password',
#   'mix',
#   'to',
#   'to',
#   'verify',
#   'get',
#   'usher',
#   'and',
#   'britney',
#   'fml',
#   'po',
#   'box',
#   'mk',
#   'ppw'],
#  ['probably',
#   'money',
#   'worry',
#   'thing',
#   'are',
#   'coming',
#   'due',
#   'and',
#   'have',
#   'several',
#   'outstanding',
#   'invoice',
#   'for',
#   'work',
#   'did',
#   'two',
#   'and',
#   'three',
#   'month',
#   'ago'],
#  ['how', 'is', 'it', 'possible', 'to', 'teach', 'you', 'and', 'where'],
#  ['wonder',
#   'if',
#   'your',
#   'phone',
#   'battery',
#   'went',
#   'dead',
#   'had',
#   'to',
#   'tell',
#   'you',
#   'love',
#   'you',
#   'babe'],
#  ['lovely', 'smell', 'on', 'this', 'bus', 'and', 'it', 'ain', 'tobacco'],
#  ['we',
#   're',
#   'all',
#   'getting',
#   'worried',
#   'over',
#   'here',
#   'derek',
#   'and',
#   'taylor',
#   'have',
#   'already',
#   'assumed',
#   'the',
#   'worst'],
#  ['hey', 'what', 'up', 'charles', 'sorry', 'about', 'the', 'late', 'reply'],
#  ['all',
#   'the',
#   'lastest',
#   'from',
#   'stereophonics',
#   'marley',
#   'dizzee',
#   'racal',
#   'libertine',
#   'and',
#   'the',
#   'stroke',
#   'win',
#   'nookii',
#   'game',
#   'with',
#   'flirt',
#   'click',
#   'themob',
#   'wap',
#   'bookmark',
#   'or',
#   'text',
#   'wap',
#   'to'],
#  ['ll',
#   'give',
#   'her',
#   'once',
#   'have',
#   'it',
#   'plus',
#   'she',
#   'said',
#   'grinule',
#   'greet',
#   'you',
#   'whenever',
#   'we',
#   'speak'],
#  ['white', 'fudge', 'oreo', 'are', 'in', 'store'],
#  ['january',
#   'male',
#   'sale',
#   'hot',
#   'gay',
#   'chat',
#   'now',
#   'cheaper',
#   'call',
#   'national',
#   'rate',
#   'from',
#   'min',
#   'cheap',
#   'to',
#   'min',
#   'peak',
#   'to',
#   'stop',
#   'text',
#   'call',
#   'min'],
#  ['my',
#   'love',
#   'how',
#   'come',
#   'it',
#   'took',
#   'you',
#   'so',
#   'long',
#   'to',
#   'leave',
#   'for',
#   'zaher',
#   'got',
#   'your',
#   'word',
#   'on',
#   'ym',
#   'and',
#   'wa',
#   'happy',
#   'to',
#   'see',
#   'them',
#   'but',
#   'wa',
#   'sad',
#   'you',
#   'had',
#   'left',
#   'miss',
#   'you'],
#  ['am', 'sorry', 'it', 'hurt', 'you'],
#  ['can',
#   'feel',
#   'nauseous',
#   'so',
#   'pissed',
#   'didn',
#   'eat',
#   'any',
#   'sweet',
#   'all',
#   'week',
#   'cause',
#   'today',
#   'wa',
#   'planning',
#   'to',
#   'pig',
#   'out',
#   'wa',
#   'dieting',
#   'all',
#   'week',
#   'and',
#   'now',
#   'not',
#   'hungry'],
#  ['ok',
#   'lor',
#   'but',
#   'not',
#   'too',
#   'early',
#   'me',
#   'still',
#   'having',
#   'project',
#   'meeting',
#   'now'],
#  ['call', 'me', 'da', 'am', 'waiting', 'for', 'your', 'call'],
#  ['could',
#   'ask',
#   'carlos',
#   'if',
#   'we',
#   'could',
#   'get',
#   'more',
#   'if',
#   'anybody',
#   'else',
#   'can',
#   'chip',
#   'in'],
#  ['wa',
#   'actually',
#   'about',
#   'to',
#   'send',
#   'you',
#   'reminder',
#   'today',
#   'have',
#   'wonderful',
#   'weekend'],
#  ['when',
#   'people',
#   'see',
#   'my',
#   'msg',
#   'they',
#   'think',
#   'iam',
#   'addicted',
#   'to',
#   'msging',
#   'they',
#   'are',
#   'wrong',
#   'bcoz',
#   'they',
#   'don',
#   'know',
#   'that',
#   'iam',
#   'addicted',
#   'to',
#   'my',
#   'sweet',
#   'friend',
#   'bslvyl'],
#  ['hey',
#   'you',
#   'gave',
#   'them',
#   'your',
#   'photo',
#   'when',
#   'you',
#   'registered',
#   'for',
#   'driving',
#   'ah',
#   'tmr',
#   'wanna',
#   'meet',
#   'at',
#   'yck'],
#  ['dont', 'talk', 'to', 'him', 'ever', 'ok', 'it', 'my', 'word'],
#  ['when', 'wana', 'see', 'it', 'then'],
#  ['on',
#   'ma',
#   'way',
#   'to',
#   'school',
#   'can',
#   'you',
#   'pls',
#   'send',
#   'me',
#   'ashley',
#   'number'],
#  ['it', 'shall', 'be', 'fine', 'have', 'avalarr', 'now', 'will', 'hollalater'],
#  ['she',
#   'went',
#   'to',
#   'attend',
#   'another',
#   'two',
#   'round',
#   'today',
#   'but',
#   'still',
#   'did',
#   'reach',
#   'home'],
#  ['actually',
#   'deleted',
#   'my',
#   'old',
#   'website',
#   'now',
#   'blogging',
#   'at',
#   'magicalsongs',
#   'blogspot',
#   'com'],
#  ['wait', 'chikku', 'il', 'send', 'aftr', 'lt', 'gt', 'min'],
#  ['but',
#   'on',
#   'diet',
#   'and',
#   'ate',
#   'too',
#   'many',
#   'slice',
#   'of',
#   'pizza',
#   'yesterday',
#   'ugh',
#   'always',
#   'on',
#   'diet'],
#  ['will', 'give', 'my', 'kvb', 'acc', 'detail'],
#  ['oh', 'all', 'have', 'to', 'come', 'ah'],
#  ['money',
#   'you',
#   'lucky',
#   'winner',
#   'claim',
#   'your',
#   'prize',
#   'text',
#   'money',
#   'over',
#   'million',
#   'to',
#   'give',
#   'away',
#   'ppt',
#   'normal',
#   'text',
#   'rate',
#   'box',
#   'jy'],
#  ['really',
#   'sorry',
#   'won',
#   'able',
#   'do',
#   'this',
#   'friday',
#   'hope',
#   'can',
#   'find',
#   'an',
#   'alternative',
#   'hope',
#   'yr',
#   'term',
#   'going',
#   'ok'],
#  ['congratulation',
#   'ore',
#   'mo',
#   'owo',
#   're',
#   'wa',
#   'enjoy',
#   'it',
#   'and',
#   'wish',
#   'you',
#   'many',
#   'happy',
#   'moment',
#   'to',
#   'and',
#   'fro',
#   'wherever',
#   'you',
#   'go'],
#  ['so', 'do', 'you', 'have', 'samus', 'shoulder', 'yet'],
#  ['what',
#   'time',
#   'you',
#   'think',
#   'you',
#   'll',
#   'have',
#   'it',
#   'need',
#   'to',
#   'know',
#   'when',
#   'should',
#   'be',
#   'near',
#   'campus'],
#  ['dear',
#   'matthew',
#   'please',
#   'call',
#   'from',
#   'landline',
#   'your',
#   'complimentary',
#   'lux',
#   'tenerife',
#   'holiday',
#   'or',
#   'cash',
#   'await',
#   'collection',
#   'ppm',
#   'sae',
#   'box',
#   'sk',
#   'xh'],
#  ['then', 'dun', 'wear', 'jean', 'lor'],
#  ['since', 'when', 'which', 'side', 'any', 'fever', 'any', 'vomitin'],
#  ['are', 'you', 'in', 'college'],
#  ['urgent',
#   'call',
#   'from',
#   'landline',
#   'your',
#   'complimentary',
#   'tenerife',
#   'holiday',
#   'or',
#   'cash',
#   'await',
#   'collection',
#   'sae',
#   'box',
#   'hp',
#   'yf',
#   'ppm'],
#  ['better',
#   'made',
#   'up',
#   'for',
#   'friday',
#   'and',
#   'stuffed',
#   'myself',
#   'like',
#   'pig',
#   'yesterday',
#   'now',
#   'feel',
#   'bleh',
#   'but',
#   'at',
#   'least',
#   'it',
#   'not',
#   'writhing',
#   'pain',
#   'kind',
#   'of',
#   'bleh'],
#  ['no',
#   'we',
#   'sell',
#   'it',
#   'all',
#   'so',
#   'we',
#   'll',
#   'have',
#   'ton',
#   'if',
#   'coin',
#   'then',
#   'sell',
#   'our',
#   'coin',
#   'to',
#   'someone',
#   'thru',
#   'paypal',
#   'voila',
#   'money',
#   'back',
#   'in',
#   'life',
#   'pocket'],
#  ['theyre',
#   'doing',
#   'it',
#   'to',
#   'lot',
#   'of',
#   'place',
#   'only',
#   'hospital',
#   'and',
#   'medical',
#   'place',
#   'are',
#   'safe'],
#  ['how',
#   'about',
#   'getting',
#   'in',
#   'touch',
#   'with',
#   'folk',
#   'waiting',
#   'for',
#   'company',
#   'just',
#   'txt',
#   'back',
#   'your',
#   'name',
#   'and',
#   'age',
#   'to',
#   'opt',
#   'in',
#   'enjoy',
#   'the',
#   'community',
#   'sm'],
#  ['and',
#   'also',
#   've',
#   'sorta',
#   'blown',
#   'him',
#   'off',
#   'couple',
#   'time',
#   'recently',
#   'so',
#   'id',
#   'rather',
#   'not',
#   'text',
#   'him',
#   'out',
#   'of',
#   'the',
#   'blue',
#   'looking',
#   'for',
#   'weed'],
#  ['sent',
#   'my',
#   'score',
#   'to',
#   'sophas',
#   'and',
#   'had',
#   'to',
#   'do',
#   'secondary',
#   'application',
#   'for',
#   'few',
#   'school',
#   'think',
#   'if',
#   'you',
#   'are',
#   'thinking',
#   'of',
#   'applying',
#   'do',
#   'research',
#   'on',
#   'cost',
#   'also',
#   'contact',
#   'joke',
#   'ogunrinde',
#   'her',
#   'school',
#   'is',
#   'one',
#   'me',
#   'the',
#   'le',
#   'expensive',
#   'one'],
#  ['cant',
#   'wait',
#   'to',
#   'see',
#   'you',
#   'how',
#   'were',
#   'the',
#   'photo',
#   'were',
#   'useful'],
#  ['ur',
#   'cash',
#   'balance',
#   'is',
#   'currently',
#   'pound',
#   'to',
#   'maximize',
#   'ur',
#   'cash',
#   'in',
#   'now',
#   'send',
#   'go',
#   'to',
#   'only',
#   'msg',
#   'cc',
#   'po',
#   'box',
#   'tcr'],
#  ['hey',
#   'booked',
#   'the',
#   'kb',
#   'on',
#   'sat',
#   'already',
#   'what',
#   'other',
#   'lesson',
#   'are',
#   'we',
#   'going',
#   'for',
#   'ah',
#   'keep',
#   'your',
#   'sat',
#   'night',
#   'free',
#   'we',
#   'need',
#   'to',
#   'meet',
#   'and',
#   'confirm',
#   'our',
#   'lodging'],
#  ['chk', 'in', 'ur', 'belovd', 'dict'],
#  ['is', 'that', 'what', 'time', 'you', 'want', 'me', 'to', 'come'],
#  ['awesome', 'lemme', 'know', 'whenever', 'you', 're', 'around'],
#  ['shb', 'ok', 'lor', 'thanx'],
#  ['beautiful',
#   'truth',
#   'against',
#   'gravity',
#   'read',
#   'carefully',
#   'our',
#   'heart',
#   'feel',
#   'light',
#   'when',
#   'someone',
#   'is',
#   'in',
#   'it',
#   'but',
#   'it',
#   'feel',
#   'very',
#   'heavy',
#   'when',
#   'someone',
#   'leaf',
#   'it',
#   'good',
#   'night'],
#  ['also', 'remember', 'to', 'get', 'dobby', 'bowl', 'from', 'your', 'car'],
#  ['filthy', 'story', 'and', 'girl', 'waiting', 'for', 'your'],
#  ['sorry',
#   'now',
#   'then',
#   'ur',
#   'msg',
#   'yar',
#   'lor',
#   'so',
#   'poor',
#   'thing',
#   'but',
#   'only',
#   'one',
#   'night',
#   'tmr',
#   'll',
#   'have',
#   'brand',
#   'new',
#   'room',
#   'sleep',
#   'in'],
#  ['love',
#   'isn',
#   'decision',
#   'it',
#   'feeling',
#   'if',
#   'we',
#   'could',
#   'decide',
#   'who',
#   'to',
#   'love',
#   'then',
#   'life',
#   'would',
#   'be',
#   'much',
#   'simpler',
#   'but',
#   'then',
#   'le',
#   'magical'],
#  ['welp', 'apparently', 'he', 'retired'],
#  ['my',
#   'sort',
#   'code',
#   'is',
#   'and',
#   'acc',
#   'no',
#   'is',
#   'the',
#   'bank',
#   'is',
#   'natwest',
#   'can',
#   'you',
#   'reply',
#   'to',
#   'confirm',
#   've',
#   'sent',
#   'this',
#   'to',
#   'the',
#   'right',
#   'person'],
#  ['where'],
#  ['sure', 'can', 'take', 'any', 'sick', 'time'],
#  ['urgent',
#   'we',
#   'are',
#   'trying',
#   'to',
#   'contact',
#   'today',
#   'draw',
#   'show',
#   'that',
#   'you',
#   'have',
#   'won',
#   'prize',
#   'guaranteed',
#   'call',
#   'from',
#   'land',
#   'line',
#   'claim',
#   'valid',
#   'hr',
#   'only'],
#  ['watching',
#   'cartoon',
#   'listening',
#   'music',
#   'amp',
#   'at',
#   'eve',
#   'had',
#   'to',
#   'go',
#   'temple',
#   'amp',
#   'church',
#   'what',
#   'about'],
#  ['yo',
#   'chad',
#   'which',
#   'gymnastics',
#   'class',
#   'do',
#   'you',
#   'wanna',
#   'take',
#   'the',
#   'site',
#   'say',
#   'christian',
#   'class',
#   'is',
#   'full'],
#  ['are', 'you', 'this', 'much', 'buzy'],
#  ['or',
#   'better',
#   'still',
#   'can',
#   'you',
#   'catch',
#   'her',
#   'and',
#   'let',
#   'ask',
#   'her',
#   'if',
#   'she',
#   'can',
#   'sell',
#   'lt',
#   'gt',
#   'for',
#   'me'],
#  ['am',
#   'not',
#   'sure',
#   'about',
#   'night',
#   'menu',
#   'know',
#   'only',
#   'about',
#   'noon',
#   'menu'],
#  ['what',
#   'do',
#   'want',
#   'when',
#   'come',
#   'back',
#   'beautiful',
#   'necklace',
#   'token',
#   'of',
#   'my',
#   'heart',
#   'for',
#   'you',
#   'thats',
#   'what',
#   'will',
#   'give',
#   'but',
#   'only',
#   'to',
#   'my',
#   'wife',
#   'of',
#   'my',
#   'liking',
#   'be',
#   'that',
#   'and',
#   'see',
#   'no',
#   'one',
#   'can',
#   'give',
#   'you',
#   'that',
#   'dont',
#   'call',
#   'me',
#   'will',
#   'wait',
#   'till',
#   'come'],
#  ['are', 'you', 'willing', 'to', 'go', 'for', 'aptitude', 'class'],
#  ['it', 'wont', 'until', 'trying', 'sort', 'house', 'out', 'is', 'that', 'ok'],
#  ['yar',
#   'lor',
#   'he',
#   'wan',
#   'go',
#   'horse',
#   'racing',
#   'today',
#   'mah',
#   'so',
#   'eat',
#   'earlier',
#   'lor',
#   'ate',
#   'chicken',
#   'rice'],
#  ['haha', 'awesome', 'omw', 'back', 'now', 'then'],
#  ['yup', 'thk', 'so', 'until', 'shop', 'close', 'lor'],
#  ['what', 'is', 'your', 'account', 'number'],
#  ['eh', 'send', 'wrongly', 'lar'],
#  ['hey',
#   'no',
#   'ad',
#   'crap',
#   'nite',
#   'wa',
#   'borin',
#   'without',
#   'ya',
#   'boggy',
#   'with',
#   'me',
#   'boring',
#   'biatch',
#   'thanx',
#   'but',
#   'wait',
#   'til',
#   'nxt',
#   'time',
#   'il',
#   'ave',
#   'ya'],
#  ['ok', 'shall', 'talk', 'to', 'him'],
#  ['dont',
#   'hesitate',
#   'you',
#   'know',
#   'this',
#   'is',
#   'the',
#   'second',
#   'time',
#   'she',
#   'ha',
#   'had',
#   'weakness',
#   'like',
#   'that',
#   'so',
#   'keep',
#   'notebook',
#   'of',
#   'what',
#   'she',
#   'eat',
#   'and',
#   'did',
#   'the',
#   'day',
#   'before',
#   'or',
#   'if',
#   'anything',
#   'changed',
#   'the',
#   'day',
#   'before',
#   'so',
#   'that',
#   'we',
#   'can',
#   'be',
#   'sure',
#   'it',
#   'nothing'],
#  ['hey', 'you', 'can', 'pay', 'with', 'salary', 'de', 'only', 'lt', 'gt'],
#  ['another', 'month', 'need', 'chocolate', 'weed', 'and', 'alcohol'],
#  ['if',
#   'he',
#   'started',
#   'searching',
#   'he',
#   'will',
#   'get',
#   'job',
#   'in',
#   'few',
#   'day',
#   'he',
#   'have',
#   'great',
#   'potential',
#   'and',
#   'talent'],
#  ['reckon',
#   'need',
#   'to',
#   'be',
#   'in',
#   'town',
#   'by',
#   'eightish',
#   'to',
#   'walk',
#   'from',
#   'carpark'],
#  ['congrats',
#   'mobile',
#   'videophones',
#   'yours',
#   'call',
#   'now',
#   'videochat',
#   'wid',
#   'your',
#   'mate',
#   'play',
#   'java',
#   'game',
#   'dload',
#   'polyph',
#   'music',
#   'noline',
#   'rentl'],
#  ['look',
#   'at',
#   'the',
#   'fuckin',
#   'time',
#   'what',
#   'the',
#   'fuck',
#   'you',
#   'think',
#   'is',
#   'up'],
#  ['yo', 'guess', 'what', 'just', 'dropped'],
#  ['carlos', 'say', 'he', 'll', 'be', 'at', 'mu', 'in', 'lt', 'gt', 'minute'],
#  ['in', 'office', 'now', 'will', 'call', 'you', 'lt', 'gt', 'min'],
#  ['geeee',
#   'miss',
#   'you',
#   'already',
#   'you',
#   'know',
#   'your',
#   'all',
#   'can',
#   'think',
#   'about',
#   'fuck',
#   'can',
#   'wait',
#   'till',
#   'next',
#   'year',
#   'when',
#   'we',
#   'will',
#   'be',
#   'together',
#   'loving',
#   'kiss'],
#  ['yun',
#   'ah',
#   'the',
#   'ubi',
#   'one',
#   'say',
#   'if',
#   'wan',
#   'call',
#   'by',
#   'tomorrow',
#   'call',
#   'look',
#   'for',
#   'irene',
#   'ere',
#   'only',
#   'got',
#   'bus',
#   'ubi',
#   'cres',
#   'ubi',
#   'tech',
#   'park',
#   'ph',
#   'for',
#   'st',
#   'wkg',
#   'day'],
#  ['ugh',
#   'gotta',
#   'drive',
#   'back',
#   'to',
#   'sd',
#   'from',
#   'la',
#   'my',
#   'butt',
#   'is',
#   'sore'],
#  ['th', 'of', 'july'],
#  ['hi',
#   'im',
#   'having',
#   'the',
#   'most',
#   'relaxing',
#   'time',
#   'ever',
#   'we',
#   'have',
#   'to',
#   'get',
#   'up',
#   'at',
#   'am',
#   'every',
#   'day',
#   'wa',
#   'the',
#   'party',
#   'good',
#   'the',
#   'other',
#   'night',
#   'get',
#   'home',
#   'tomorrow',
#   'at',
#   'ish'],
#  ['up',
#   'to',
#   'wan',
#   'come',
#   'then',
#   'come',
#   'lor',
#   'but',
#   'din',
#   'any',
#   'stripe',
#   'skirt'],
#  ['the',
#   'xmas',
#   'story',
#   'is',
#   'peace',
#   'the',
#   'xmas',
#   'msg',
#   'is',
#   'love',
#   'the',
#   'xmas',
#   'miracle',
#   'is',
#   'jesus',
#   'hav',
#   'blessed',
#   'month',
#   'ahead',
#   'amp',
#   'wish',
#   'merry',
#   'xmas'],
#  ['can', 'don', 'have', 'her', 'number'],
#  ['change', 'again', 'it', 'one', 'next', 'to', 'escalator'],
#  ['yetunde',
#   'in',
#   'class',
#   'can',
#   'you',
#   'not',
#   'run',
#   'water',
#   'on',
#   'it',
#   'to',
#   'make',
#   'it',
#   'ok',
#   'pls',
#   'now'],
#  ['not',
#   'lot',
#   'ha',
#   'happened',
#   'here',
#   'feel',
#   'very',
#   'quiet',
#   'beth',
#   'is',
#   'at',
#   'her',
#   'aunt',
#   'and',
#   'charlie',
#   'is',
#   'working',
#   'lot',
#   'just',
#   'me',
#   'and',
#   'helen',
#   'in',
#   'at',
#   'the',
#   'mo',
#   'how',
#   'have',
#   'you',
#   'been'],
#  ['then',
#   'wait',
#   'me',
#   'at',
#   'bus',
#   'stop',
#   'aft',
#   'ur',
#   'lect',
#   'lar',
#   'if',
#   'dun',
#   'then',
#   'go',
#   'get',
#   'my',
#   'car',
#   'then',
#   'come',
#   'back',
#   'pick'],
#  ...]

# %%
import gensim

# %% [markdown]
# # Lets train word2vec from scratch

# %%
model=gensim.models.Word2Vec(words)

# %%
#to get all the vocabulary
model.wv.index_to_key
# Out:
# ['to',
#  'you',
#  'the',
#  'it',
#  'and',
#  'in',
#  'is',
#  'me',
#  'my',
#  'for',
#  'your',
#  'call',
#  'of',
#  'that',
#  'have',
#  'on',
#  'now',
#  'are',
#  'can',
#  'so',
#  'but',
#  'not',
#  'or',
#  'we',
#  'do',
#  'get',
#  'at',
#  'ur',
#  'will',
#  'if',
#  'be',
#  'with',
#  'no',
#  'just',
#  'this',
#  'gt',
#  'lt',
#  'go',
#  'how',
#  'up',
#  'when',
#  'ok',
#  'day',
#  'what',
#  'free',
#  'from',
#  'all',
#  'out',
#  'know',
#  'll',
#  'come',
#  'like',
#  'good',
#  'time',
#  'am',
#  'then',
#  'got',
#  'wa',
#  'there',
#  'he',
#  'love',
#  'text',
#  'only',
#  'want',
#  'send',
#  'one',
#  'need',
#  'txt',
#  'today',
#  'by',
#  'going',
#  'don',
#  'stop',
#  'home',
#  'she',
#  'about',
#  'lor',
#  'sorry',
#  'see',
#  'still',
#  'mobile',
#  'take',
#  'back',
#  'da',
#  'reply',
#  'dont',
#  'our',
#  'think',
#  'tell',
#  'week',
#  'hi',
#  'phone',
#  'they',
#  'new',
#  'please',
#  'later',
#  'pls',
#  'any',
#  'her',
#  'ha',
#  'co',
#  'did',
#  'been',
#  'msg',
#  'min',
#  'some',
#  'an',
#  'night',
#  'make',
#  'dear',
#  'who',
#  'here',
#  'message',
#  'say',
#  'well',
#  'where',
#  're',
#  'thing',
#  'much',
#  'oh',
#  'great',
#  'claim',
#  'hope',
#  'hey',
#  'him',
#  'number',
#  'give',
#  'more',
#  'too',
#  'happy',
#  'work',
#  'wat',
#  'friend',
#  'had',
#  'yes',
#  'way',
#  'www',
#  've',
#  'let',
#  'should',
#  'prize',
#  'won',
#  'right',
#  'tomorrow',
#  'already',
#  'tone',
#  'after',
#  'ask',
#  'win',
#  'said',
#  'life',
#  'amp',
#  'cash',
#  'doing',
#  'im',
#  'yeah',
#  'really',
#  'meet',
#  'babe',
#  'why',
#  'find',
#  'them',
#  'miss',
#  'morning',
#  'very',
#  'last',
#  'year',
#  'service',
#  'thanks',
#  'uk',
#  'care',
#  'com',
#  'would',
#  'anything',
#  'lol',
#  'nokia',
#  'also',
#  'every',
#  'feel',
#  'keep',
#  'sure',
#  'pick',
#  'urgent',
#  'over',
#  'sent',
#  'contact',
#  'something',
#  'buy',
#  'gud',
#  'again',
#  'cant',
#  'wait',
#  'before',
#  'place',
#  'box',
#  'first',
#  'his',
#  'even',
#  'someone',
#  'guy',
#  'help',
#  'went',
#  'wish',
#  'next',
#  'tonight',
#  'were',
#  'nice',
#  'soon',
#  'show',
#  'which',
#  'off',
#  'around',
#  'word',
#  'could',
#  'customer',
#  'money',
#  'sleep',
#  'chat',
#  'per',
#  'many',
#  'late',
#  'always',
#  'ya',
#  'gonna',
#  'sm',
#  'down',
#  'leave',
#  'wan',
#  'name',
#  'lot',
#  'end',
#  'other',
#  'dun',
#  'pm',
#  'told',
#  'st',
#  'person',
#  'waiting',
#  'hello',
#  'special',
#  'try',
#  'month',
#  'girl',
#  'hour',
#  'may',
#  'fine',
#  'best',
#  'haha',
#  'minute',
#  'heart',
#  'people',
#  'coming',
#  'done',
#  'guaranteed',
#  'yet',
#  'thk',
#  'same',
#  'th',
#  'getting',
#  'smile',
#  'ppm',
#  'use',
#  'thought',
#  'god',
#  'didn',
#  'offer',
#  'stuff',
#  'holiday',
#  'talk',
#  'start',
#  'class',
#  'man',
#  'cost',
#  'live',
#  'mean',
#  'bit',
#  'line',
#  'car',
#  'lunch',
#  'few',
#  'draw',
#  'finish',
#  'job',
#  'being',
#  'problem',
#  'never',
#  'yup',
#  'ill',
#  'better',
#  'plan',
#  'trying',
#  'house',
#  'thats',
#  'cool',
#  'hr',
#  'meeting',
#  'account',
#  'rate',
#  'mind',
#  'pobox',
#  'ready',
#  'having',
#  'dat',
#  'long',
#  'weekend',
#  'game',
#  'chance',
#  'world',
#  'real',
#  'half',
#  'enjoy',
#  'latest',
#  'wk',
#  'po',
#  'room',
#  'yo',
#  'sir',
#  'check',
#  'because',
#  'than',
#  'bt',
#  'guess',
#  'play',
#  'awarded',
#  'wanna',
#  'nothing',
#  'lar',
#  'receive',
#  'boy',
#  'voucher',
#  'eat',
#  'sweet',
#  'luv',
#  'look',
#  'camera',
#  'pic',
#  'another',
#  'liao',
#  'big',
#  'shit',
#  'dinner',
#  'into',
#  'ah',
#  'landline',
#  'birthday',
#  'xxx',
#  'jus',
#  'might',
#  'ever',
#  'quite',
#  'video',
#  'kiss',
#  'age',
#  'watching',
#  'wont',
#  'question',
#  'land',
#  'watch',
#  'dream',
#  'orange',
#  'early',
#  'thanx',
#  'worry',
#  'baby',
#  'called',
#  'speak',
#  'two',
#  'tv',
#  'aight',
#  'once',
#  'hear',
#  'fun',
#  'probably',
#  'nd',
#  'point',
#  'bed',
#  'pa',
#  'pay',
#  'doe',
#  'actually',
#  'network',
#  'princess',
#  'nite',
#  'apply',
#  'maybe',
#  'shall',
#  'bus',
#  'part',
#  'sat',
#  'left',
#  'forgot',
#  'den',
#  'bad',
#  'ringtone',
#  'remember',
#  'office',
#  'hurt',
#  'easy',
#  'reach',
#  'code',
#  'shopping',
#  'between',
#  'dunno',
#  'made',
#  'xx',
#  'dis',
#  'little',
#  'evening',
#  'didnt',
#  'award',
#  'put',
#  'true',
#  'leh',
#  'fuck',
#  'everything',
#  'wife',
#  'anyway',
#  'face',
#  'dad',
#  'looking',
#  'town',
#  'thank',
#  'afternoon',
#  'gift',
#  'school',
#  'enough',
#  'sound',
#  'those',
#  'mail',
#  'working',
#  'mate',
#  'selected',
#  'yr',
#  'movie',
#  'most',
#  'collect',
#  'pound',
#  'detail',
#  'without',
#  'asked',
#  'entry',
#  'while',
#  'missing',
#  'tmr',
#  'hav',
#  'join',
#  'price',
#  'sexy',
#  'okay',
#  'though',
#  'pain',
#  'wif',
#  'important',
#  'must',
#  'xmas',
#  'wanted',
#  'until',
#  'since',
#  'valid',
#  'came',
#  'missed',
#  'mob',
#  'answer',
#  'wot',
#  'lesson',
#  'wake',
#  'book',
#  'abt',
#  'run',
#  'bring',
#  'collection',
#  'able',
#  'til',
#  'wen',
#  'haven',
#  'decimal',
#  'de',
#  'test',
#  'charge',
#  'juz',
#  'plus',
#  'change',
#  'stay',
#  'plz',
#  'date',
#  'colour',
#  'away',
#  'double',
#  'dude',
#  'havent',
#  'yesterday',
#  'saw',
#  'music',
#  'till',
#  'else',
#  'weekly',
#  'shop',
#  'bored',
#  'attempt',
#  'alright',
#  'update',
#  'hair',
#  'food',
#  'lei',
#  'credit',
#  'optout',
#  'friendship',
#  'making',
#  'trip',
#  'drink',
#  'net',
#  'these',
#  'online',
#  'id',
#  'haf',
#  'yours',
#  'top',
#  'oso',
#  'coz',
#  'goin',
#  'tried',
#  'gr',
#  'family',
#  'address',
#  'delivery',
#  'sch',
#  'hot',
#  'player',
#  'club',
#  'either',
#  'smoke',
#  'ard',
#  'driving',
#  'feeling',
#  'national',
#  'yourself',
#  'nt',
#  'sad',
#  'order',
#  'lose',
#  'together',
#  'calling',
#  'full',
#  'wid',
#  'second',
#  'story',
#  'mom',
#  'busy',
#  'ring',
#  'beautiful',
#  'head',
#  'bonus',
#  'walk',
#  'http',
#  'brother',
#  'tot',
#  'both',
#  'si',
#  'sae',
#  'post',
#  'believe',
#  'smiling',
#  'huh',
#  'close',
#  'poly',
#  'old',
#  'eve',
#  'row',
#  'chikku',
#  'happen',
#  'noe',
#  'drive',
#  'await',
#  'set',
#  'info',
#  'hand',
#  'saying',
#  'mum',
#  'sleeping',
#  'leaving',
#  'awesome',
#  'mths',
#  'took',
#  'congrats',
#  'pub',
#  'hl',
#  'email',
#  'drop',
#  'parent',
#  'wil',
#  'rite',
#  'tomo',
#  'match',
#  'thinking',
#  'suite',
#  'started',
#  'news',
#  'simple',
#  'aft',
#  'finished',
#  'private',
#  'cause',
#  'doesn',
#  'okie',
#  'tho',
#  'unsubscribe',
#  'auction',
#  'available',
#  'tc',
#  'forget',
#  'content',
#  'everyone',
#  'company',
#  'anyone',
#  'sister',
#  'touch',
#  'break',
#  'caller',
#  'valentine',
#  'reason',
#  'mine',
#  'final',
#  'card',
#  'angry',
#  'neva',
#  'taking',
#  'gd',
#  'statement',
#  'open',
#  'dating',
#  'loving',
#  'whats',
#  'alone',
#  'found',
#  'treat',
#  'whatever',
#  'lucky',
#  'fancy',
#  'carlos',
#  'gal',
#  'choose',
#  'worth',
#  'opt',
#  'each',
#  'ticket',
#  'search',
#  'sun',
#  'knw',
#  'type',
#  'bank',
#  'expires',
#  'wonderful',
#  'frnd',
#  'hows',
#  'mobileupd',
#  'hit',
#  'winner',
#  'hard',
#  'boytoy',
#  'gone',
#  'saturday',
#  'gbp',
#  'welcome',
#  'fast',
#  'happened',
#  'quiz',
#  'anytime',
#  'kind',
#  'congratulation',
#  'bout',
#  'secret',
#  'far',
#  'identifier',
#  'decided',
#  'sub',
#  'ni',
#  'exam',
#  'uncle',
#  'ltd',
#  'party',
#  'smth',
#  'friday',
#  'college',
#  'visit',
#  'nyt',
#  'prob',
#  'song',
#  'darlin',
#  'mu',
#  'hold',
#  'read',
#  'light',
#  'operator',
#  'oredi',
#  'goodmorning',
#  'finally',
#  'mrng',
#  'tel',
#  'sea',
#  'wit',
#  'used',
#  'camcorder',
#  'wrong',
#  'least',
#  'wonder',
#  'fucking',
#  'drug',
#  'chennai',
#  'project',
#  'lovely',
#  'crazy',
#  'fri',
#  'term',
#  'nope',
#  'outside',
#  'pretty',
#  'fone',
#  'meant',
#  'frm',
#  'hmm',
#  'seeing',
#  'savamob',
#  'telling',
#  'case',
#  'fr',
#  'ten',
#  'whole',
#  'cum',
#  'cd',
#  'their',
#  'unlimited',
#  'blue',
#  'frnds',
#  'listen',
#  'snow',
#  'le',
#  'freemsg',
#  'support',
#  'wkly',
#  'wq',
#  'earlier',
#  'isn',
#  'course',
#  'hungry',
#  'jay',
#  'wasn',
#  'sunday',
#  'log',
#  'john',
#  'understand',
#  'enter',
#  'eh',
#  'single',
#  'cut',
#  'gas',
#  'un',
#  'father',
#  'valued',
#  'within',
#  'stupid',
#  'press',
#  'mr',
#  'hee',
#  'die',
#  'hmmm',
#  'yar',
#  'happiness',
#  'move',
#  'almost',
#  'knew',
#  'child',
#  'store',
#  'tired',
#  'bslvyl',
#  'mayb',
#  'sell',
#  'gn',
#  'balance',
#  'na',
#  'dnt',
#  'film',
#  'sex',
#  'paper',
#  'luck',
#  'joy',
#  'pas',
#  'moment',
#  'etc',
#  'march',
#  'side',
#  'area',
#  'sk',
#  'currently',
#  'couple',
#  'txts',
#  'computer',
#  'rock',
#  'invited',
#  'felt',
#  'as',
#  'ago',
#  'download',
#  'india',
#  'talking',
#  'mah',
#  'christmas',
#  'lost',
#  'park',
#  'motorola',
#  'load',
#  'reading',
#  'shower',
#  'hospital',
#  'bill',
#  'picking',
#  'askd',
#  'ipod',
#  'darren',
#  'eye',
#  'direct',
#  'return',
#  'heard',
#  'rental',
#  'photo',
#  'extra',
#  'confirm',
#  'semester',
#  'correct',
#  'via',
#  'red',
#  'doin',
#  'ac',
#  'information',
#  'supposed',
#  'reveal',
#  'wow',
#  'sort',
#  'laptop',
#  'ugh',
#  'charged',
#  'xy',
#  'bcoz',
#  'sending',
#  'ish',
#  'swing',
#  'seen',
#  'redeemed',
#  'difficult',
#  'ge',
#  'through',
#  'promise',
#  'met',
#  'max',
#  'lady',
#  'gym',
#  'complimentary',
#  'kid',
#  'gotta',
#  'comp',
#  'grin',
#  'surprise',
#  'figure',
#  'police',
#  'whenever',
#  'discount',
#  'slowly',
#  'ex',
#  'yep',
#  'muz',
#  'lovable',
#  'request',
#  'bath',
#  'hg',
#  'std',
#  'abiola',
#  'crave',
#  'usf',
#  'eg',
#  'loan',
#  'reward',
#  'safe',
#  'small',
#  'road',
#  'wine',
#  'comin',
#  'slow',
#  'weed',
#  'nobody',
#  'truth',
#  'link',
#  'wap',
#  'study',
#  'fantasy',
#  'fact',
#  'loved',
#  'orchard',
#  'cheer',
#  'asap',
#  'kate',
#  'somebody',
#  'page',
#  'noon',
#  'remove',
#  'rply',
#  'hmv',
#  'leaf',
#  'entered',
#  'txting',
#  'blood',
#  'rest',
#  'wana',
#  'idea',
#  'clean',
#  'dogging',
#  'door',
#  'asking',
#  'checking',
#  'train',
#  'own',
#  'lover',
#  'laugh',
#  'joke',
#  'save',
#  'rent',
#  'member',
#  'monday',
#  'pete',
#  'copy',
#  'empty',
#  'deal',
#  'nah',
#  'near',
#  'del',
#  'forever',
#  'mistake',
#  'energy',
#  'cup',
#  'normal',
#  'somewhere',
#  'men',
#  'england',
#  'la',
#  'situation',
#  'opinion',
#  'cheap',
#  'warm',
#  'hoping',
#  'water',
#  'across',
#  'woke',
#  'hw',
#  'usual',
#  'rakhesh',
#  'callertune',
#  'spend',
#  'med',
#  'em',
#  'cover',
#  'write',
#  'short',
#  'gave',
#  'bb',
#  'ringtones',
#  'tonite',
#  'bathe',
#  'different',
#  'voice',
#  'teach',
#  'ho',
#  'otherwise',
#  'king',
#  'merry',
#  'gap',
#  'poor',
#  'fantastic',
#  'booked',
#  'oops',
#  'wc',
#  'gettin',
#  'bag',
#  'admirer',
#  'getzed',
#  'ldn',
#  'kick',
#  'glad',
#  'immediately',
#  'street',
#  'summer',
#  'wishing',
#  'representative',
#  'cr',
#  'ntt',
#  'sony',
#  'rd',
#  'deep',
#  'worried',
#  'turn',
#  'catch',
#  'reached',
#  'pray',
#  ...]

# %%
model.corpus_count #vocabulary size
# Out:
# 5569

# %%
model.epochs #the more number of epochs the more better it is
# Out:
# 5

# %%
model.wv.similar_by_word('good')
# Out:
# [('wa', 0.9986318349838257),
#  ('morning', 0.9985184669494629),
#  ('night', 0.9985044002532959),
#  ('my', 0.9984105229377747),
#  ('all', 0.9983375072479248),
#  ('well', 0.9983115196228027),
#  ('oh', 0.998240053653717),
#  ('very', 0.9981780052185059),
#  ('where', 0.9981730580329895),
#  ('in', 0.998111367225647)]

# %%
model.wv['good'].shape
# Out:
# (100,)

# %%
def avg_word2vec(doc):
    # remove out-of-vocabulary words
    #sent = [word for word in doc if word in model.wv.index_to_key]
    #print(sent)
    
    return np.mean([model.wv[word] for word in doc if word in model.wv.index_to_key],axis=0)
                #or [np.zeros(len(model.wv.index_to_key))], axis=0)

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.11/site-packages (4.65.0)

# %%
from tqdm import tqdm

# %%
#apply for the entire sentences
import numpy as np
X=[]
for i in tqdm(range(len(words))):
    X.append(avg_word2vec(words[i]))
# Out:
#   0%|                                                  | 0/5569 [00:00<?, ?it/s]/Users/udaykiran/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/udaykiran/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 100%|█████████████████████████████████████| 5569/5569 [00:00<00:00, 7657.81it/s]

# %%
X
# Out:
# [array([-0.14060956,  0.20871468,  0.12814039,  0.08314122,  0.05318748,
#         -0.5007684 ,  0.1377245 ,  0.51273125, -0.24079934, -0.20410125,
#         -0.15538608, -0.3772706 , -0.10435639,  0.06226194,  0.2001281 ,
#         -0.16225971,  0.08012947, -0.31682694,  0.04373332, -0.5964078 ,
#          0.24428019,  0.1004999 ,  0.18435654, -0.12485575,  0.01716075,
#          0.06073348, -0.1633884 , -0.16402715, -0.25235057,  0.06546549,
#          0.2292991 , -0.00215598,  0.10901217, -0.21133256, -0.12097628,
#          0.35382378,  0.03646931, -0.18345006, -0.1637565 , -0.49280998,
#          0.06094695, -0.2184024 , -0.2130229 ,  0.01228823,  0.1371698 ,
#         -0.05260075, -0.15739128, -0.08060031,  0.20941804,  0.11013731,
#          0.14941247, -0.200305  , -0.02434525,  0.0157613 , -0.1027488 ,
#          0.05154048,  0.18183343,  0.11069082, -0.39583862,  0.11729117,
#          0.00978097,  0.08516176, -0.05133264, -0.12164725, -0.25624558,
#          0.24967988,  0.05853388,  0.22447982, -0.30049747,  0.33182943,
#         -0.20397364,  0.24681969,  0.3605282 , -0.10374713,  0.34941366,
#          0.05395521,  0.0171762 , -0.12375099, -0.21394412,  0.14514254,
#         -0.18395358, -0.05755209, -0.19136968,  0.38711834, -0.13203447,
#         -0.07501323,  0.10940654,  0.19867638,  0.30817387,  0.06681213,
#          0.38021073,  0.16306604,  0.0575997 ,  0.03506038,  0.5123549 ,
#          0.2597761 ,  0.15046068, -0.2524535 ,  0.16881363,  0.01449003],
#        dtype=float32),
#  array([-0.13687924,  0.18749526,  0.1157494 ,  0.07532569,  0.05651935,
#         -0.45272484,  0.11271437,  0.46706313, -0.21953475, -0.17750534,
#         -0.1451893 , -0.33911788, -0.08812587,  0.06118176,  0.18886411,
#         -0.15462506,  0.07418865, -0.29103246,  0.02875004, -0.5428469 ,
#          0.22534415,  0.0895077 ,  0.16083592, -0.1083856 ,  0.01847616,
#          0.05458411, -0.14489359, -0.15559527, -0.22324836,  0.05632332,
#          0.20593062, -0.00168233,  0.09019192, -0.19126329, -0.10848117,
#          0.31709725,  0.0276139 , -0.16522454, -0.13986261, -0.45035338,
#          0.05454675, -0.18987074, -0.18700859,  0.00540405,  0.11673945,
#         -0.05264615, -0.14408344, -0.07102508,  0.18833306,  0.10427036,
#          0.13066922, -0.17261559, -0.01566228,  0.01299281, -0.08400328,
#          0.05281135,  0.16286914,  0.09743527, -0.35460114,  0.11754483,
#          0.01454829,  0.0777123 , -0.04293361, -0.09834395, -0.23772138,
#          0.22417274,  0.04948169,  0.1995093 , -0.26493555,  0.30509445,
#         -0.18142302,  0.21095319,  0.31840295, -0.1024675 ,  0.30675966,
#          0.04521205,  0.01308351, -0.11132788, -0.19899014,  0.11888218,
#         -0.15401557, -0.04750664, -0.18113485,  0.34042037, -0.12544668,
#         -0.0638166 ,  0.09394681,  0.18494174,  0.27206206,  0.05579596,
#          0.3502213 ,  0.13859998,  0.04636854,  0.02275318,  0.4484638 ,
#          0.22746131,  0.13604087, -0.23867047,  0.15619871,  0.00667561],
#        dtype=float32),
#  array([-0.14454502,  0.2265951 ,  0.14420049,  0.09985895,  0.04033237,
#         -0.54164267,  0.13809158,  0.506534  , -0.25302687, -0.23652539,
#         -0.16356407, -0.38227844, -0.12332263,  0.04577399,  0.19068156,
#         -0.17089488,  0.08594618, -0.35434112,  0.04165988, -0.61400217,
#          0.24006909,  0.1349275 ,  0.19365312, -0.1259373 ,  0.03826912,
#          0.07534068, -0.17541525, -0.14158617, -0.26466453,  0.06252522,
#          0.22628082,  0.00734347,  0.10281835, -0.21322395, -0.11132269,
#          0.36958477,  0.07486197, -0.20813812, -0.19499864, -0.5356275 ,
#          0.0566502 , -0.24835277, -0.24596734, -0.00195354,  0.12099211,
#         -0.04625547, -0.16790257, -0.06374729,  0.2120675 ,  0.10495669,
#          0.13536985, -0.23374487, -0.02931017,  0.04560157, -0.13960306,
#          0.03178873,  0.1785193 ,  0.08964947, -0.4295105 ,  0.13820918,
#          0.00389951,  0.08830541, -0.03227731, -0.13096546, -0.29016975,
#          0.285165  ,  0.04502862,  0.24836145, -0.3370854 ,  0.35943934,
#         -0.22133493,  0.3096829 ,  0.37340316, -0.12821993,  0.35946497,
#          0.04671089, -0.00142605, -0.1425204 , -0.21346897,  0.12851496,
#         -0.17568213, -0.06133259, -0.19906932,  0.38160804, -0.11252768,
#         -0.06212467,  0.08075453,  0.18249659,  0.30672637,  0.10554277,
#          0.3723221 ,  0.17046429,  0.03991121,  0.02903467,  0.5190398 ,
#          0.2538142 ,  0.09792776, -0.27823356,  0.19214772,  0.03654582],
#        dtype=float32),
#  array([-0.20221202,  0.28154573,  0.17130542,  0.11787061,  0.0763121 ,
#         -0.6851346 ,  0.17899613,  0.7090868 , -0.33666334, -0.26887408,
#         -0.21436825, -0.5112766 , -0.13037482,  0.09898589,  0.2906433 ,
#         -0.23437715,  0.11790682, -0.43591738,  0.05254669, -0.82769054,
#          0.34354028,  0.12724069,  0.2434601 , -0.16819355,  0.020042  ,
#          0.08933038, -0.22454421, -0.2351433 , -0.33602697,  0.09020425,
#          0.32541126, -0.00268182,  0.1479773 , -0.28395426, -0.17056943,
#          0.48098436,  0.03793517, -0.24143563, -0.20050038, -0.6733095 ,
#          0.09073611, -0.29156175, -0.28247115,  0.02218995,  0.1924242 ,
#         -0.08107351, -0.21232656, -0.1201626 ,  0.28692812,  0.15004821,
#          0.19285297, -0.26368567, -0.01555422,  0.01459315, -0.12204433,
#          0.08203466,  0.25094125,  0.1572526 , -0.53113747,  0.17126639,
#          0.02222621,  0.1186614 , -0.06969861, -0.15837179, -0.34887728,
#          0.34175244,  0.08255624,  0.31095496, -0.39431676,  0.46787813,
#         -0.2751914 ,  0.30930766,  0.4893651 , -0.1562042 ,  0.47170037,
#          0.07336068,  0.02574626, -0.15845004, -0.2955007 ,  0.18566284,
#         -0.2491152 , -0.076837  , -0.26016736,  0.5310541 , -0.18932196,
#         -0.10141017,  0.16450226,  0.28234476,  0.42475167,  0.06840614,
#          0.5275487 ,  0.2152586 ,  0.0766115 ,  0.04801971,  0.68845546,
#          0.35550037,  0.22328426, -0.35530666,  0.23038955,  0.01265581],
#        dtype=float32),
#  array([-0.17162453,  0.23227443,  0.1505838 ,  0.09549621,  0.06894744,
#         -0.56998926,  0.15054575,  0.59762794, -0.28329393, -0.2335953 ,
#         -0.1806304 , -0.43712425, -0.11325971,  0.07685313,  0.24548908,
#         -0.18672927,  0.10422161, -0.36965415,  0.04826084, -0.6961317 ,
#          0.28763118,  0.10255568,  0.2086972 , -0.14168447,  0.02671612,
#          0.07410204, -0.1833828 , -0.19069396, -0.28925678,  0.07483617,
#          0.27541578,  0.00222295,  0.136612  , -0.24816889, -0.14217795,
#          0.40514687,  0.03899129, -0.20532854, -0.17088665, -0.55426085,
#          0.075879  , -0.25105757, -0.24014068,  0.01986419,  0.166386  ,
#         -0.06127876, -0.18109377, -0.09875292,  0.23165725,  0.13007261,
#          0.1612068 , -0.22214298, -0.01636118,  0.02004563, -0.10161048,
#          0.0673956 ,  0.20394121,  0.1322956 , -0.44663373,  0.14797293,
#          0.017186  ,  0.09884793, -0.05986893, -0.13347538, -0.29154018,
#          0.28925723,  0.07705817,  0.2601146 , -0.32328287,  0.39089736,
#         -0.23075032,  0.26426774,  0.40749273, -0.12535627,  0.39795566,
#          0.05608678,  0.01379622, -0.13829418, -0.24285643,  0.16291499,
#         -0.20631723, -0.06045392, -0.21389012,  0.4518629 , -0.15212172,
#         -0.07121202,  0.14713815,  0.22995341,  0.35048273,  0.05833001,
#          0.4453124 ,  0.1787389 ,  0.07089304,  0.04262194,  0.5798828 ,
#          0.29908147,  0.18033005, -0.3025517 ,  0.18903787,  0.01056963],
#        dtype=float32),
#  array([-0.18182227,  0.25384697,  0.15882494,  0.10375568,  0.06856111,
#         -0.6209769 ,  0.16039762,  0.6278681 , -0.2997591 , -0.26116326,
#         -0.1920457 , -0.4630827 , -0.12561513,  0.0774897 ,  0.24801826,
#         -0.19750774,  0.10686758, -0.39450333,  0.05497603, -0.7341365 ,
#          0.30032766,  0.12025775,  0.22980131, -0.15076533,  0.03512658,
#          0.08012763, -0.1984533 , -0.19363439, -0.30898228,  0.07550257,
#          0.2910472 ,  0.00387963,  0.13919047, -0.2581401 , -0.14190255,
#          0.43457732,  0.05416595, -0.22667946, -0.19475628, -0.6018538 ,
#          0.07728369, -0.2793711 , -0.26626205,  0.01222641,  0.16578904,
#         -0.06124898, -0.19483083, -0.09561577,  0.25021037,  0.13370855,
#          0.17896274, -0.24567538, -0.02048337,  0.03040182, -0.12252757,
#          0.06339674,  0.21937892,  0.13128087, -0.4829748 ,  0.15566315,
#          0.01432703,  0.10344949, -0.05346692, -0.14019033, -0.31749442,
#          0.3167881 ,  0.07469945,  0.2821961 , -0.36079443,  0.4205377 ,
#         -0.24655849,  0.30436617,  0.43843728, -0.13160904,  0.42770922,
#          0.06032604,  0.01380094, -0.15259911, -0.2537108 ,  0.16737454,
#         -0.22005941, -0.0628178 , -0.23183492,  0.46834332, -0.15518032,
#         -0.0781988 ,  0.14162222,  0.2354206 ,  0.37438843,  0.08232889,
#          0.4649361 ,  0.19732316,  0.06940483,  0.04143022,  0.61566687,
#          0.31914178,  0.17103802, -0.31834623,  0.20702794,  0.01955105],
#        dtype=float32),
#  array([-0.19374657,  0.26377425,  0.17253934,  0.1111353 ,  0.07727094,
#         -0.6513916 ,  0.16557622,  0.6697517 , -0.32280546, -0.2673531 ,
#         -0.20251343, -0.4919    , -0.12219756,  0.08948518,  0.2730845 ,
#         -0.2136441 ,  0.11623255, -0.4145782 ,  0.05848259, -0.78753275,
#          0.32662836,  0.11956974,  0.24350095, -0.16528845,  0.03243792,
#          0.08253681, -0.21129122, -0.21474324, -0.3258042 ,  0.08576502,
#          0.31568792,  0.00777707,  0.15381204, -0.27311176, -0.15704933,
#          0.4612742 ,  0.04141534, -0.23896778, -0.19842859, -0.63600165,
#          0.08512348, -0.2916344 , -0.27538565,  0.01968956,  0.187433  ,
#         -0.07150801, -0.20971729, -0.10880131,  0.26423195,  0.14128791,
#          0.1901906 , -0.2500144 , -0.01845301,  0.02418455, -0.12099332,
#          0.07314783,  0.23299882,  0.14871955, -0.5061761 ,  0.16031797,
#          0.01724964,  0.11234098, -0.06543933, -0.14617875, -0.33238915,
#          0.3327557 ,  0.08583473,  0.30068207, -0.37341952,  0.44660974,
#         -0.2622132 ,  0.3032884 ,  0.46453732, -0.13600478,  0.45178604,
#          0.06347419,  0.01808415, -0.16046293, -0.27115646,  0.18723746,
#         -0.2381445 , -0.07301212, -0.24492577,  0.5102605 , -0.17327705,
#         -0.08705207,  0.15963575,  0.2552038 ,  0.40089893,  0.07516783,
#          0.5035961 ,  0.20948593,  0.07411271,  0.04547405,  0.6614632 ,
#          0.34330827,  0.20227547, -0.337267  ,  0.21479568,  0.01249257],
#        dtype=float32),
#  array([-0.13374045,  0.214514  ,  0.13484332,  0.08827244,  0.03705419,
#         -0.49885574,  0.13321817,  0.4876191 , -0.23652883, -0.21910928,
#         -0.14730075, -0.3718678 , -0.09730686,  0.05164977,  0.18887615,
#         -0.16130763,  0.07638916, -0.31973198,  0.05303013, -0.58024234,
#          0.23453133,  0.11204591,  0.18092468, -0.12059394,  0.01856884,
#          0.06384484, -0.1614703 , -0.14594685, -0.2514101 ,  0.05559984,
#          0.22393495,  0.00614286,  0.11219978, -0.19657674, -0.11047647,
#          0.35158375,  0.05631658, -0.18696912, -0.1781308 , -0.49339214,
#          0.05495728, -0.23102063, -0.22300833,  0.00679687,  0.12204233,
#         -0.04260816, -0.15814458, -0.06877652,  0.21224473,  0.10809992,
#          0.14328189, -0.2077774 , -0.02994049,  0.02377921, -0.10842006,
#          0.03554983,  0.16873658,  0.10331753, -0.40245953,  0.11999585,
#         -0.00692632,  0.0811272 , -0.04118486, -0.12132841, -0.26629362,
#          0.25488004,  0.04883592,  0.22263642, -0.3096853 ,  0.33509165,
#         -0.19748922,  0.27360496,  0.35860685, -0.10990306,  0.3488454 ,
#          0.05445102,  0.01626249, -0.14008358, -0.20368524,  0.1374417 ,
#         -0.18273748, -0.06092782, -0.18688615,  0.3730422 , -0.12258798,
#         -0.06917159,  0.08502895,  0.1753707 ,  0.30316904,  0.09037276,
#          0.3635856 ,  0.16633439,  0.05794479,  0.0370063 ,  0.49436533,
#          0.25134146,  0.12234826, -0.25055352,  0.17322193,  0.02054348],
#        dtype=float32),
#  array([-0.15464015,  0.24813858,  0.17530677,  0.11399806,  0.04667298,
#         -0.58223087,  0.15791434,  0.5548365 , -0.27718663, -0.2613199 ,
#         -0.17750046, -0.4346587 , -0.13666333,  0.06259798,  0.21432382,
#         -0.19261932,  0.08511133, -0.38111457,  0.04346757, -0.6674473 ,
#          0.26891053,  0.14027362,  0.20989057, -0.14486654,  0.02630427,
#          0.06630491, -0.20032135, -0.15398474, -0.2783218 ,  0.0741827 ,
#          0.25996694,  0.00189101,  0.11581659, -0.21781625, -0.12196007,
#          0.39554647,  0.08249509, -0.22020292, -0.21421804, -0.5856526 ,
#          0.06599399, -0.2711375 , -0.25534835,  0.00959143,  0.12696049,
#         -0.04029675, -0.18269964, -0.07225142,  0.23473263,  0.120409  ,
#          0.16221596, -0.26115337, -0.03496335,  0.05045446, -0.13884349,
#          0.04418279,  0.20294806,  0.11698671, -0.4720316 ,  0.15432703,
#         -0.00370266,  0.08733393, -0.0348123 , -0.13489933, -0.30499354,
#          0.29318082,  0.06406818,  0.26297224, -0.36714366,  0.38722777,
#         -0.23628528,  0.32525134,  0.40101513, -0.13290483,  0.39178512,
#          0.04825014,  0.00654405, -0.15904975, -0.23237716,  0.13727854,
#         -0.19517688, -0.06154127, -0.21718813,  0.41592327, -0.11748864,
#         -0.05921125,  0.08879298,  0.19084612,  0.3378979 ,  0.1011366 ,
#          0.41721734,  0.18124829,  0.04259872,  0.0244512 ,  0.56996685,
#          0.2695074 ,  0.10540526, -0.3082296 ,  0.20853935,  0.04626191],
#        dtype=float32),
#  array([-0.17229727,  0.28689605,  0.18411463,  0.12767927,  0.04321301,
#         -0.6821158 ,  0.16933328,  0.6387744 , -0.31564867, -0.30720237,
#         -0.20831789, -0.4867381 , -0.15170841,  0.05626678,  0.24307482,
#         -0.21693712,  0.1008011 , -0.4443677 ,  0.06734861, -0.76807183,
#          0.29943833,  0.173854  ,  0.2452189 , -0.16571721,  0.04867636,
#          0.08667696, -0.2218912 , -0.1711879 , -0.33692414,  0.07389431,
#          0.28351915,  0.00628878,  0.12542239, -0.24887809, -0.14083558,
#          0.46891618,  0.10162308, -0.27021566, -0.25986165, -0.67519057,
#          0.07370436, -0.31690323, -0.32023022, -0.00636701,  0.14798047,
#         -0.05177954, -0.21148036, -0.08069985,  0.2747025 ,  0.13433991,
#          0.1759938 , -0.3031791 , -0.03785046,  0.0507007 , -0.18050481,
#          0.03539491,  0.21515028,  0.10956673, -0.54192656,  0.16408083,
#         -0.00216096,  0.10503756, -0.03657859, -0.16501279, -0.38231423,
#          0.3508015 ,  0.04945868,  0.3133942 , -0.43897808,  0.4655703 ,
#         -0.2743707 ,  0.40403512,  0.47314075, -0.16430746,  0.45997378,
#          0.07103109,  0.00819674, -0.18840824, -0.26568967,  0.16540357,
#         -0.22114693, -0.08495965, -0.2556452 ,  0.485762  , -0.14355677,
#         -0.08038746,  0.08983724,  0.21539809,  0.39212272,  0.14599165,
#          0.4660913 ,  0.2185255 ,  0.05062767,  0.03889189,  0.6562529 ,
#          0.32094777,  0.1200256 , -0.34012163,  0.24114852,  0.04347079],
#        dtype=float32),
#  array([-0.18069568,  0.24299271,  0.15043546,  0.0954873 ,  0.06722327,
#         -0.5970582 ,  0.15440649,  0.61695844, -0.29184535, -0.2458679 ,
#         -0.18636131, -0.45227724, -0.1172021 ,  0.07472527,  0.24661656,
#         -0.19917838,  0.10477355, -0.38056922,  0.05497219, -0.7175093 ,
#          0.29966137,  0.10922558,  0.22030464, -0.1498063 ,  0.02831144,
#          0.07193331, -0.18899819, -0.19301267, -0.30026993,  0.07430112,
#          0.29065892,  0.00356541,  0.14085789, -0.25196016, -0.13898504,
#          0.41682765,  0.0451018 , -0.21683803, -0.17755255, -0.57997555,
#          0.07999149, -0.26954058, -0.2539904 ,  0.01661017,  0.16657467,
#         -0.05914112, -0.18430173, -0.09966819,  0.24178505,  0.12906663,
#          0.17604324, -0.2316605 , -0.01702129,  0.0267458 , -0.10891455,
#          0.06816548,  0.21142001,  0.12878813, -0.4615801 ,  0.14975865,
#          0.01722924,  0.09886926, -0.05600043, -0.13682391, -0.29963338,
#          0.3060024 ,  0.08103649,  0.27025813, -0.34511518,  0.40356743,
#         -0.24029173,  0.2788241 ,  0.42485183, -0.12223464,  0.41282034,
#          0.06415309,  0.01613651, -0.14007933, -0.24777524,  0.16856894,
#         -0.2158674 , -0.06133203, -0.22380523,  0.46129656, -0.15761784,
#         -0.07849979,  0.14671488,  0.22992487,  0.3632992 ,  0.06914017,
#          0.4606173 ,  0.18938851,  0.0698316 ,  0.03969756,  0.60083807,
#          0.31034195,  0.17603728, -0.30838063,  0.19421649,  0.01845474],
#        dtype=float32),
#  array([-0.17449011,  0.26226687,  0.17034909,  0.11409871,  0.0551908 ,
#         -0.6457517 ,  0.16490322,  0.6053541 , -0.3029378 , -0.27909514,
#         -0.19397305, -0.45843092, -0.14406587,  0.05566597,  0.22970666,
#         -0.20429184,  0.11052408, -0.4200816 ,  0.04727893, -0.73181605,
#          0.28741086,  0.1579932 ,  0.23131569, -0.15027648,  0.04222333,
#          0.08389816, -0.20901978, -0.17261599, -0.31566462,  0.07870427,
#          0.27850342,  0.00277601,  0.12493385, -0.24637485, -0.1345424 ,
#          0.4355022 ,  0.08002648, -0.25206205, -0.2273175 , -0.6393836 ,
#          0.07476129, -0.29993847, -0.28650466,  0.00110553,  0.14164217,
#         -0.05263811, -0.20241816, -0.07635624,  0.24809255,  0.12383389,
#          0.16636619, -0.27807757, -0.02815799,  0.05267087, -0.16184375,
#          0.04300199,  0.21848841,  0.11203209, -0.5108559 ,  0.16945975,
#          0.0038743 ,  0.10263591, -0.042237  , -0.1531031 , -0.34157526,
#          0.338756  ,  0.05712926,  0.29678747, -0.39883915,  0.4321221 ,
#         -0.26567972,  0.36015108,  0.44354284, -0.1557694 ,  0.42893964,
#          0.05180311, -0.0008168 , -0.16565138, -0.2546325 ,  0.14675403,
#         -0.21300651, -0.06842954, -0.23303941,  0.4589072 , -0.13579655,
#         -0.07052082,  0.10146673,  0.21500254,  0.3663644 ,  0.1140837 ,
#          0.44441855,  0.20100404,  0.04648162,  0.03855436,  0.61577976,
#          0.30303884,  0.1201828 , -0.33482736,  0.2248385 ,  0.04223981],
#        dtype=float32),
#  array([-0.18320327,  0.28176528,  0.19239287,  0.12266236,  0.05363871,
#         -0.671472  ,  0.17495733,  0.6308951 , -0.3145091 , -0.29807702,
#         -0.2037588 , -0.49277887, -0.15233555,  0.05657642,  0.24614954,
#         -0.21408357,  0.10735752, -0.44556764,  0.05505096, -0.76800483,
#          0.29710478,  0.16864541,  0.24168624, -0.165415  ,  0.03913412,
#          0.08542959, -0.22818363, -0.17725201, -0.3233272 ,  0.08157986,
#          0.29738894, -0.00136709,  0.12863995, -0.25037065, -0.14211361,
#          0.45687014,  0.09261789, -0.25583714, -0.23798104, -0.6739405 ,
#          0.08363313, -0.31917113, -0.2994033 ,  0.00471528,  0.1479111 ,
#         -0.04940665, -0.20916188, -0.08197498,  0.2602568 ,  0.12658532,
#          0.17991267, -0.30222186, -0.03525143,  0.0600096 , -0.17031683,
#          0.04777367,  0.23338303,  0.12491657, -0.54646105,  0.17561273,
#         -0.00359434,  0.10062787, -0.03524243, -0.15517263, -0.36198053,
#          0.34725928,  0.0618961 ,  0.3090997 , -0.41888154,  0.44933677,
#         -0.2781269 ,  0.3838882 ,  0.4676218 , -0.15667042,  0.45120525,
#          0.05519055,  0.00228891, -0.1792057 , -0.26932833,  0.1580993 ,
#         -0.22347978, -0.06950472, -0.24410959,  0.48352343, -0.1328681 ,
#         -0.06984532,  0.10017388,  0.22208735,  0.38821682,  0.12179846,
#          0.47043076,  0.21165161,  0.05027957,  0.03250539,  0.65574723,
#          0.31865978,  0.12231526, -0.3523246 ,  0.24083214,  0.0487531 ],
#        dtype=float32),
#  array([-0.1812278 ,  0.25293532,  0.15781058,  0.10296112,  0.0643274 ,
#         -0.61209446,  0.16269991,  0.6243664 , -0.29583088, -0.25677285,
#         -0.18639626, -0.46452737, -0.11686759,  0.07592943,  0.247262  ,
#         -0.19984013,  0.10728984, -0.38778546,  0.06500908, -0.72881806,
#          0.30482972,  0.12013524,  0.22802366, -0.15249202,  0.02927394,
#          0.07408638, -0.19637983, -0.19396213, -0.30860507,  0.07358696,
#          0.29727492,  0.00492262,  0.14303431, -0.25202867, -0.14041518,
#          0.4309199 ,  0.05056956, -0.22131807, -0.18880129, -0.59415007,
#          0.08061951, -0.28002512, -0.26825002,  0.01360702,  0.1663978 ,
#         -0.05186982, -0.19368812, -0.09381392,  0.25189742,  0.13530226,
#          0.1844949 , -0.24040352, -0.02088832,  0.0274611 , -0.11600095,
#          0.06098906,  0.21667807,  0.13608932, -0.4796034 ,  0.15068161,
#          0.00620914,  0.09875727, -0.05190665, -0.1434621 , -0.31484666,
#          0.31215167,  0.07849681,  0.27748895, -0.35988277,  0.41664463,
#         -0.243608  ,  0.30302176,  0.4422301 , -0.12279437,  0.42829415,
#          0.06511547,  0.02173468, -0.15510114, -0.25184816,  0.17463903,
#         -0.22791447, -0.06356269, -0.22684386,  0.47176358, -0.15876205,
#         -0.08352342,  0.14129977,  0.22750328,  0.37466943,  0.08357504,
#          0.46476477,  0.19853665,  0.07516647,  0.04354145,  0.61596125,
#          0.32173064,  0.17688158, -0.3079737 ,  0.20587228,  0.01889968],
#        dtype=float32),
#  array([-0.16470088,  0.24743532,  0.15885006,  0.10319895,  0.05570383,
#         -0.59013003,  0.1555155 ,  0.5927265 , -0.28119424, -0.2530198 ,
#         -0.18036179, -0.4508718 , -0.11697802,  0.07076346,  0.23175448,
#         -0.19807397,  0.10362109, -0.38340425,  0.0582059 , -0.700334  ,
#          0.29235905,  0.12822884,  0.21638703, -0.1484313 ,  0.02246871,
#          0.06797934, -0.19559582, -0.18513042, -0.29273823,  0.07222392,
#          0.2760065 ,  0.00427499,  0.13096577, -0.23833947, -0.14065357,
#          0.41982186,  0.05946944, -0.2219669 , -0.1982162 , -0.58307964,
#          0.08234403, -0.27523294, -0.2536058 ,  0.01442954,  0.15812106,
#         -0.04437621, -0.19318773, -0.09395926,  0.24612355,  0.12433595,
#          0.17407572, -0.24295884, -0.02424761,  0.02791923, -0.12748231,
#          0.05312493,  0.20812356,  0.12889469, -0.4702035 ,  0.14856844,
#          0.00921484,  0.09345392, -0.04786353, -0.13928743, -0.30501655,
#          0.30031097,  0.06506733,  0.27227935, -0.35404363,  0.40744054,
#         -0.24168867,  0.30082008,  0.4263805 , -0.12321705,  0.41590202,
#          0.05758606,  0.01924464, -0.15483908, -0.24410683,  0.16394664,
#         -0.21724515, -0.06880009, -0.22527392,  0.45183775, -0.14801647,
#         -0.0719922 ,  0.12386936,  0.21625559,  0.36313474,  0.08624648,
#          0.44762623,  0.19312179,  0.06086901,  0.03510586,  0.5951603 ,
#          0.3021389 ,  0.15560164, -0.30082113,  0.2042924 ,  0.02799978],
#        dtype=float32),
#  array([-1.48995876e-01,  2.30055407e-01,  1.42279267e-01,  9.40298364e-02,
#          4.60309684e-02, -5.48799098e-01,  1.41543239e-01,  5.27423441e-01,
#         -2.62275606e-01, -2.35501006e-01, -1.68074653e-01, -4.01215881e-01,
#         -1.16900809e-01,  5.18344939e-02,  2.07871526e-01, -1.71690255e-01,
#          8.93470421e-02, -3.49286646e-01,  4.95168045e-02, -6.32180929e-01,
#          2.50579029e-01,  1.26360521e-01,  1.98420808e-01, -1.33479804e-01,
#          2.84143090e-02,  7.19249696e-02, -1.75122455e-01, -1.54262930e-01,
#         -2.74199039e-01,  6.16756044e-02,  2.40907475e-01,  2.75439513e-03,
#          1.11314990e-01, -2.18961999e-01, -1.16609901e-01,  3.82129431e-01,
#          6.38399497e-02, -2.06531644e-01, -1.92400575e-01, -5.40188968e-01,
#          6.34193346e-02, -2.50964344e-01, -2.43423313e-01,  6.72387751e-03,
#          1.32685214e-01, -4.71717305e-02, -1.69251963e-01, -7.21211806e-02,
#          2.17977807e-01,  1.12499967e-01,  1.49927169e-01, -2.29472741e-01,
#         -2.98259296e-02,  3.15706022e-02, -1.29420087e-01,  4.00311388e-02,
#          1.88034341e-01,  1.00366972e-01, -4.39591467e-01,  1.30285695e-01,
#          4.52150241e-04,  8.94858912e-02, -4.08245735e-02, -1.32720277e-01,
#         -2.94061840e-01,  2.86991298e-01,  5.18083014e-02,  2.53271163e-01,
#         -3.37120861e-01,  3.68582636e-01, -2.20039144e-01,  3.02991390e-01,
#          3.89466673e-01, -1.21225595e-01,  3.72914106e-01,  5.89155704e-02,
#          1.17560448e-02, -1.43823430e-01, -2.24353418e-01,  1.46379977e-01,
#         -1.92503154e-01, -6.34768754e-02, -2.02358574e-01,  4.03527766e-01,
#         -1.29006237e-01, -7.01430440e-02,  9.33001637e-02,  1.91805393e-01,
#          3.25407594e-01,  1.00816108e-01,  3.88285249e-01,  1.77968755e-01,
#          5.26474975e-02,  3.63651961e-02,  5.38973629e-01,  2.71112025e-01,
#          1.27305552e-01, -2.74844229e-01,  1.90714836e-01,  2.36038733e-02],
#        dtype=float32),
#  array([-1.66144371e-01,  2.38666460e-01,  1.50060639e-01,  9.68003795e-02,
#          6.29851148e-02, -5.85922182e-01,  1.58685058e-01,  6.10126257e-01,
#         -2.83662647e-01, -2.35404715e-01, -1.84058249e-01, -4.52614397e-01,
#         -1.13531537e-01,  7.90485665e-02,  2.41359577e-01, -1.91181049e-01,
#          9.95118842e-02, -3.74175638e-01,  5.55829220e-02, -7.04919100e-01,
#          3.03697109e-01,  1.10248961e-01,  2.06816956e-01, -1.45639703e-01,
#          1.71635952e-02,  7.20005780e-02, -1.87272429e-01, -2.01134041e-01,
#         -2.98884183e-01,  7.14154840e-02,  2.79445916e-01, -4.91285173e-04,
#          1.31560028e-01, -2.48504832e-01, -1.41812921e-01,  4.19096380e-01,
#          3.47186141e-02, -2.13311478e-01, -1.77650049e-01, -5.68894565e-01,
#          7.90946409e-02, -2.52316982e-01, -2.49293759e-01,  1.24416174e-02,
#          1.68486059e-01, -6.42998144e-02, -1.84665382e-01, -9.25691128e-02,
#          2.52324253e-01,  1.34937242e-01,  1.80002987e-01, -2.26180837e-01,
#         -2.48511937e-02,  1.21144215e-02, -1.08156286e-01,  7.24893212e-02,
#          2.13889226e-01,  1.40577152e-01, -4.61291164e-01,  1.36595562e-01,
#          3.20160133e-03,  1.05627574e-01, -6.53378367e-02, -1.40953422e-01,
#         -3.03868800e-01,  2.96307474e-01,  7.74189234e-02,  2.61645079e-01,
#         -3.38490963e-01,  3.95549625e-01, -2.33545557e-01,  2.73409516e-01,
#          4.23788697e-01, -1.27008140e-01,  4.07745749e-01,  6.32718876e-02,
#          2.55438685e-02, -1.50369689e-01, -2.56632835e-01,  1.78817272e-01,
#         -2.20254898e-01, -6.59919754e-02, -2.25761130e-01,  4.60780233e-01,
#         -1.63466945e-01, -8.68717805e-02,  1.36622608e-01,  2.38778010e-01,
#          3.68248850e-01,  7.12655112e-02,  4.51215237e-01,  1.99499771e-01,
#          7.52625689e-02,  4.90705632e-02,  5.98230779e-01,  3.14141214e-01,
#          1.90870926e-01, -2.92727947e-01,  1.99024037e-01,  9.12760291e-03],
#        dtype=float32),
#  array([-0.14934506,  0.19347505,  0.12600116,  0.07934552,  0.06026175,
#         -0.48367986,  0.12450829,  0.49623916, -0.23432334, -0.19821966,
#         -0.15577473, -0.36920595, -0.09287592,  0.06478115,  0.20440184,
#         -0.16216932,  0.08682383, -0.31087765,  0.04689499, -0.5838559 ,
#          0.24451514,  0.08575902,  0.17949592, -0.11757633,  0.02351987,
#          0.06092026, -0.15906568, -0.1677168 , -0.24056333,  0.0593296 ,
#          0.23513423,  0.00270164,  0.10847801, -0.19900833, -0.1143536 ,
#          0.34112513,  0.02096754, -0.17578061, -0.13900425, -0.4739128 ,
#          0.06761931, -0.21964866, -0.2039584 ,  0.01445751,  0.13142602,
#         -0.04645757, -0.15768935, -0.0822589 ,  0.19401914,  0.10571282,
#          0.14274007, -0.19039607, -0.0058095 ,  0.02125418, -0.09077116,
#          0.05925626,  0.1756977 ,  0.11477804, -0.37898704,  0.12345851,
#          0.00996076,  0.08019667, -0.0466235 , -0.11026996, -0.25021374,
#          0.23958111,  0.06712901,  0.22076507, -0.27515206,  0.3374027 ,
#         -0.19585711,  0.22276813,  0.34501445, -0.10391667,  0.3334274 ,
#          0.04848823,  0.01775127, -0.11569107, -0.20594923,  0.13639957,
#         -0.1768371 , -0.04975162, -0.17487384,  0.3812699 , -0.12956972,
#         -0.06454314,  0.12053127,  0.19353549,  0.29574135,  0.05011602,
#          0.37717715,  0.14871894,  0.05447852,  0.03691227,  0.48858953,
#          0.25839704,  0.15197708, -0.25293478,  0.15853356,  0.01218101],
#        dtype=float32),
#  array([-0.20916498,  0.27334216,  0.167154  ,  0.10501914,  0.0836724 ,
#         -0.6703629 ,  0.17157134,  0.6992574 , -0.3307975 , -0.27507776,
#         -0.21389453, -0.5115591 , -0.12285967,  0.09162967,  0.29521745,
#         -0.22588554,  0.12651135, -0.41759127,  0.06367152, -0.8128683 ,
#          0.33988386,  0.11604901,  0.25098538, -0.16670302,  0.0316614 ,
#          0.08399976, -0.2122509 , -0.22833058, -0.33660418,  0.08197948,
#          0.33673808,  0.00842487,  0.16160294, -0.28458402, -0.16160962,
#          0.4760844 ,  0.04096425, -0.23818207, -0.19491217, -0.6406272 ,
#          0.0873537 , -0.30500448, -0.2794088 ,  0.02664135,  0.198585  ,
#         -0.06625513, -0.21099842, -0.11345415,  0.2745985 ,  0.14979945,
#          0.20649004, -0.25525874, -0.02383001,  0.01087759, -0.11986784,
#          0.07881445,  0.24399969,  0.16031471, -0.5207988 ,  0.15689445,
#          0.02041374,  0.11544643, -0.05915206, -0.1530354 , -0.3315782 ,
#          0.3410918 ,  0.09658952,  0.3062599 , -0.3819124 ,  0.46128982,
#         -0.26370817,  0.31035033,  0.48039174, -0.1293321 ,  0.47515312,
#          0.077657  ,  0.02794869, -0.15877768, -0.28206542,  0.20386155,
#         -0.2541319 , -0.07508202, -0.25048405,  0.5363817 , -0.18599668,
#         -0.09487455,  0.17640667,  0.26356867,  0.420432  ,  0.07034005,
#          0.52702016,  0.21779053,  0.09060182,  0.05096766,  0.6896811 ,
#          0.3670544 ,  0.22939777, -0.33780187,  0.21215208,  0.01390703],
#        dtype=float32),
#  array([-0.1328626 ,  0.20264798,  0.12605159,  0.08641271,  0.04280039,
#         -0.49284214,  0.12465586,  0.46516243, -0.23220362, -0.21055204,
#         -0.14681536, -0.35391605, -0.11065587,  0.04241082,  0.17662667,
#         -0.15294161,  0.08480428, -0.31985506,  0.03833321, -0.56317604,
#          0.21599549,  0.11945723,  0.1718433 , -0.11518957,  0.03190438,
#          0.06684488, -0.15550719, -0.13177943, -0.24132721,  0.05704687,
#          0.21467693,  0.00316165,  0.09695365, -0.19220923, -0.10189209,
#          0.33340877,  0.05865795, -0.18823357, -0.16907111, -0.48789024,
#          0.05735692, -0.22420055, -0.2197184 ,  0.0034481 ,  0.11400393,
#         -0.04344029, -0.15783836, -0.05979928,  0.18762141,  0.0938567 ,
#          0.12334621, -0.20975167, -0.02424777,  0.03659473, -0.11886363,
#          0.03429489,  0.16829368,  0.08576182, -0.38931447,  0.12572145,
#          0.00249706,  0.07935027, -0.03331885, -0.11676732, -0.26063198,
#          0.26074576,  0.04765625,  0.22722234, -0.2991277 ,  0.3259923 ,
#         -0.20088416,  0.27021477,  0.34078538, -0.11530227,  0.32823122,
#          0.04109811,  0.00182631, -0.12835152, -0.19290763,  0.11720325,
#         -0.16396284, -0.05183033, -0.17797734,  0.35436714, -0.10327733,
#         -0.05716421,  0.08008835,  0.16849452,  0.28594363,  0.09009454,
#          0.3376857 ,  0.15517418,  0.04143934,  0.02887728,  0.47363165,
#          0.23498528,  0.09964053, -0.25105172,  0.1746245 ,  0.02756462],
#        dtype=float32),
#  array([-0.20521772,  0.2464695 ,  0.16284135,  0.09674709,  0.07949483,
#         -0.6164294 ,  0.1574996 ,  0.6463847 , -0.30494848, -0.2557852 ,
#         -0.19810648, -0.48235574, -0.11445827,  0.09414624,  0.26926523,
#         -0.20377001,  0.11936273, -0.38877958,  0.06777906, -0.75517476,
#          0.32062644,  0.09989049,  0.24306594, -0.15585467,  0.0356    ,
#          0.08315437, -0.20163858, -0.21692708, -0.30174828,  0.08416389,
#          0.32395157,  0.01000201,  0.14903939, -0.25142127, -0.14576638,
#          0.43825722,  0.02584624, -0.21389854, -0.16226646, -0.5983626 ,
#          0.10137979, -0.28619197, -0.25771496,  0.02154994,  0.17198841,
#         -0.05447105, -0.2033479 , -0.1134006 ,  0.2438712 ,  0.13654454,
#          0.19657956, -0.23882036, -0.00439083,  0.02877192, -0.10900178,
#          0.0865044 ,  0.2305073 ,  0.15038946, -0.4840078 ,  0.16107681,
#          0.01430161,  0.10310803, -0.05235735, -0.13163444, -0.3045711 ,
#          0.30883282,  0.09886222,  0.2799517 , -0.34184265,  0.4363216 ,
#         -0.24654272,  0.27348202,  0.44487435, -0.11455466,  0.43084547,
#          0.06475338,  0.01889098, -0.14418277, -0.25798374,  0.18249393,
#         -0.231409  , -0.06077152, -0.21335557,  0.48811388, -0.16529581,
#         -0.07779443,  0.17430738,  0.24227177,  0.38025588,  0.04980188,
#          0.49735972,  0.19287577,  0.07364935,  0.04087828,  0.6276531 ,
#          0.33887687,  0.20971015, -0.33268264,  0.19417416,  0.02063176],
#        dtype=float32),
#  array([-0.17214002,  0.28406918,  0.1714344 ,  0.11952894,  0.04684996,
#         -0.66044146,  0.18095309,  0.65598017, -0.31235197, -0.28043202,
#         -0.19233756, -0.48587623, -0.13524199,  0.07276722,  0.24754585,
#         -0.21471277,  0.0978193 , -0.41682824,  0.0642469 , -0.7702019 ,
#          0.320051  ,  0.14808449,  0.23097852, -0.1559635 ,  0.02328094,
#          0.07986551, -0.20938042, -0.19355601, -0.33464158,  0.07835144,
#          0.28856918,  0.01006521,  0.15498346, -0.28287837, -0.1508395 ,
#          0.4644851 ,  0.06828209, -0.2493627 , -0.23671383, -0.6512508 ,
#          0.06723578, -0.29535705, -0.28912196,  0.00204674,  0.17793481,
#         -0.05912299, -0.21041404, -0.08941612,  0.2883022 ,  0.14594789,
#          0.19014066, -0.25618723, -0.04793523,  0.01566792, -0.13567348,
#          0.04113553,  0.22720303,  0.14115405, -0.5288964 ,  0.14716122,
#         -0.00226815,  0.11364116, -0.06255863, -0.16865893, -0.35259137,
#          0.3346329 ,  0.07036006,  0.29612958, -0.41561234,  0.43803933,
#         -0.25708327,  0.34900326,  0.47071266, -0.14415115,  0.4669804 ,
#          0.06876875,  0.02933884, -0.18430242, -0.27319303,  0.1849969 ,
#         -0.24778922, -0.08313596, -0.25829738,  0.49559674, -0.1673443 ,
#         -0.10451662,  0.11744837,  0.2346985 ,  0.4051457 ,  0.11742161,
#          0.47550386,  0.2189479 ,  0.08143912,  0.05039157,  0.6613882 ,
#          0.33402795,  0.16889994, -0.31829977,  0.22817129,  0.02584346],
#        dtype=float32),
#  array([-0.16203657,  0.22616379,  0.1432199 ,  0.0913052 ,  0.06434608,
#         -0.5491769 ,  0.14488518,  0.5710038 , -0.2680051 , -0.21882048,
#         -0.17596486, -0.41570368, -0.10629202,  0.0765858 ,  0.23234713,
#         -0.1870757 ,  0.09589283, -0.35032547,  0.04881606, -0.66237414,
#          0.27796322,  0.10202082,  0.19954138, -0.13629875,  0.02193203,
#          0.06908231, -0.18094291, -0.18851003, -0.2775268 ,  0.07128325,
#          0.26517993,  0.0021945 ,  0.12253647, -0.23206088, -0.13446395,
#          0.38523322,  0.0297113 , -0.19595723, -0.16349295, -0.53837967,
#          0.07102071, -0.23646435, -0.22472247,  0.01518041,  0.15109214,
#         -0.06068722, -0.17586777, -0.0945037 ,  0.22998226,  0.12435738,
#          0.16202955, -0.21276732, -0.01509899,  0.01450963, -0.09682153,
#          0.06595111,  0.19826928,  0.12647995, -0.42906356,  0.1347988 ,
#          0.01385286,  0.09588394, -0.0530664 , -0.12563774, -0.27968976,
#          0.27750146,  0.06636689,  0.2443792 , -0.3136937 ,  0.36989692,
#         -0.22182684,  0.2549903 ,  0.39336666, -0.11698713,  0.38263363,
#          0.05742642,  0.02188825, -0.12769768, -0.23669472,  0.15567979,
#         -0.1991918 , -0.06171885, -0.21095955,  0.42537206, -0.15161921,
#         -0.07803724,  0.13290164,  0.22145641,  0.34159237,  0.05988452,
#          0.43042326,  0.17804667,  0.06199177,  0.03570203,  0.5586508 ,
#          0.28700513,  0.17385654, -0.28381944,  0.18170843,  0.01405005],
#        dtype=float32),
#  array([-0.16997907,  0.2358585 ,  0.14843807,  0.09395301,  0.06815436,
#         -0.5678198 ,  0.14501156,  0.5808315 , -0.27860364, -0.22165248,
#         -0.18606289, -0.42571798, -0.11620632,  0.0729593 ,  0.23690659,
#         -0.19054957,  0.09551492, -0.36880782,  0.04174193, -0.67433214,
#          0.2759371 ,  0.11767922,  0.2021091 , -0.13680229,  0.02459896,
#          0.07286453, -0.19234543, -0.18926111, -0.2818646 ,  0.07284293,
#          0.26438007, -0.00099036,  0.11023572, -0.22966425, -0.13919175,
#          0.3901858 ,  0.03552359, -0.20510766, -0.1654914 , -0.5655594 ,
#          0.07360496, -0.24259187, -0.23965028,  0.01094272,  0.1504573 ,
#         -0.06440776, -0.1799466 , -0.09216902,  0.23590524,  0.1209105 ,
#          0.15739883, -0.22572418, -0.0144803 ,  0.02067028, -0.11372903,
#          0.06608297,  0.20807242,  0.12179536, -0.43945262,  0.14254756,
#          0.01167887,  0.0969725 , -0.05756512, -0.1319552 , -0.2983489 ,
#          0.28543678,  0.06350226,  0.25730768, -0.3285166 ,  0.38267916,
#         -0.23409218,  0.27028775,  0.39930305, -0.13518739,  0.38497815,
#          0.05394824,  0.01417543, -0.1370191 , -0.24603714,  0.14877094,
#         -0.19578855, -0.06469683, -0.21398564,  0.43526798, -0.15099162,
#         -0.08024683,  0.122849  ,  0.22805369,  0.3407661 ,  0.06382079,
#          0.42955717,  0.18237302,  0.05690955,  0.03318921,  0.5700555 ,
#          0.29303685,  0.1706577 , -0.29868048,  0.19354203,  0.01665174],
#        dtype=float32),
#  array([-0.20402966,  0.26251945,  0.16837835,  0.10568953,  0.08158592,
#         -0.6603333 ,  0.16848454,  0.6851859 , -0.32266343, -0.27603662,
#         -0.20862961, -0.5036671 , -0.13126022,  0.09111426,  0.2796444 ,
#         -0.2174054 ,  0.12258678, -0.42206746,  0.06867032, -0.7921832 ,
#          0.32827604,  0.1171372 ,  0.2537887 , -0.17028773,  0.04006791,
#          0.08444369, -0.21498995, -0.21545814, -0.32435888,  0.08448847,
#          0.33046514,  0.00437964,  0.15201525, -0.27275467, -0.15313196,
#          0.4626131 ,  0.04390763, -0.23540384, -0.18616007, -0.6359648 ,
#          0.0945052 , -0.3003158 , -0.28165892,  0.02135094,  0.18210918,
#         -0.0626694 , -0.20657098, -0.11256514,  0.2656623 ,  0.14416713,
#          0.19911484, -0.25632244, -0.01081121,  0.03242577, -0.11661728,
#          0.08344816,  0.23503551,  0.15001677, -0.50679463,  0.16971432,
#          0.01822658,  0.11145877, -0.05754865, -0.14479624, -0.33326462,
#          0.33626482,  0.092979  ,  0.2956069 , -0.3712649 ,  0.45726198,
#         -0.2624236 ,  0.3038272 ,  0.46974814, -0.13441518,  0.45969668,
#          0.06963253,  0.01337983, -0.15508305, -0.27592006,  0.18838233,
#         -0.2385582 , -0.06326682, -0.24678902,  0.5089298 , -0.17074607,
#         -0.08021277,  0.16784418,  0.2556947 ,  0.40423077,  0.07417792,
#          0.5138036 ,  0.20655285,  0.07174473,  0.04156711,  0.6609554 ,
#          0.34681728,  0.20221305, -0.34308147,  0.2159802 ,  0.01631477],
#        dtype=float32),
#  array([-0.13968442,  0.18659858,  0.12150597,  0.07725951,  0.05244136,
#         -0.46385652,  0.11691599,  0.4741038 , -0.22453175, -0.19106694,
#         -0.14635438, -0.3493034 , -0.09083389,  0.06343924,  0.19291674,
#         -0.15133959,  0.08200984, -0.29702675,  0.04242821, -0.5551304 ,
#          0.23030843,  0.08644062,  0.17042117, -0.11532905,  0.02374012,
#          0.06010719, -0.15116973, -0.15249047, -0.22968076,  0.05797912,
#          0.2245285 ,  0.0035675 ,  0.10565528, -0.19285037, -0.11200475,
#          0.32545108,  0.03361243, -0.16988808, -0.13868903, -0.45516834,
#          0.06285017, -0.20846397, -0.19691461,  0.00990495,  0.12760994,
#         -0.04713695, -0.1471012 , -0.07553927,  0.18331498,  0.10166872,
#          0.13598146, -0.1803078 , -0.01345932,  0.01985091, -0.08645949,
#          0.05197079,  0.16340634,  0.1031753 , -0.36320674,  0.11335209,
#          0.01032005,  0.07621914, -0.04363249, -0.10216553, -0.23592243,
#          0.23627724,  0.05937686,  0.21213531, -0.26497614,  0.3175916 ,
#         -0.18554679,  0.22002268,  0.33004755, -0.09920881,  0.32136446,
#          0.0449423 ,  0.01321103, -0.11383554, -0.19337481,  0.12916388,
#         -0.16712175, -0.04965347, -0.1709853 ,  0.3607554 , -0.12026313,
#         -0.05884415,  0.11288342,  0.1817488 ,  0.28117397,  0.05302709,
#          0.35832343,  0.14313039,  0.05462563,  0.03135673,  0.4644974 ,
#          0.24449295,  0.13770439, -0.24363862,  0.15248488,  0.01306259],
#        dtype=float32),
#  array([-0.2012437 ,  0.2821602 ,  0.18329136,  0.11122505,  0.06836837,
#         -0.67954135,  0.17388082,  0.69421315, -0.328491  , -0.292476  ,
#         -0.21348599, -0.5123795 , -0.12456956,  0.08301081,  0.28407204,
#         -0.22637567,  0.1202812 , -0.44527626,  0.0661077 , -0.8165958 ,
#          0.3279705 ,  0.13694045,  0.25393003, -0.16997   ,  0.02974137,
#          0.08615631, -0.23084807, -0.22434607, -0.32947078,  0.091442  ,
#          0.32752642,  0.00115016,  0.15166463, -0.25921568, -0.16479619,
#          0.48299474,  0.04950904, -0.25177705, -0.21210083, -0.674499  ,
#          0.09209664, -0.31109414, -0.29470766,  0.02039739,  0.17622611,
#         -0.06456637, -0.21978328, -0.11107787,  0.26605856,  0.14916924,
#          0.19752756, -0.27531207, -0.01913872,  0.03826638, -0.13445508,
#          0.0734667 ,  0.2428955 ,  0.1464394 , -0.5316821 ,  0.17075628,
#          0.00701457,  0.10456491, -0.05905264, -0.15474857, -0.35604587,
#          0.349878  ,  0.08015901,  0.30559224, -0.40206975,  0.46484575,
#         -0.2803714 ,  0.34009433,  0.48756933, -0.15042594,  0.46705836,
#          0.07345462,  0.02305569, -0.16982138, -0.2872647 ,  0.18283883,
#         -0.2400021 , -0.07295831, -0.24729684,  0.5267941 , -0.1765148 ,
#         -0.08232161,  0.14986113,  0.25111243,  0.40972054,  0.08332139,
#          0.5222829 ,  0.21685597,  0.06546217,  0.04843844,  0.6834792 ,
#          0.3500659 ,  0.19524266, -0.35898805,  0.231504  ,  0.02286986],
#        dtype=float32),
#  array([-0.19052245,  0.2203653 ,  0.15213749,  0.08403427,  0.07841332,
#         -0.55871224,  0.13982242,  0.59365505, -0.27795365, -0.23534988,
#         -0.17977698, -0.44208354, -0.09942973,  0.08615244,  0.24855033,
#         -0.1824673 ,  0.1161008 , -0.3565974 ,  0.06440926, -0.6902187 ,
#          0.28782293,  0.09223301,  0.22192582, -0.15278047,  0.03616672,
#          0.07249766, -0.18047158, -0.19571581, -0.27219632,  0.07768457,
#          0.30482915,  0.00518093,  0.13440312, -0.22038133, -0.12842539,
#          0.3983299 ,  0.02450201, -0.19121753, -0.13545924, -0.5342075 ,
#          0.09979697, -0.2633403 , -0.24132559,  0.02283947,  0.15826075,
#         -0.04719055, -0.18346164, -0.1018225 ,  0.2103075 ,  0.1214579 ,
#          0.18151018, -0.21377967,  0.00460731,  0.03308992, -0.0876644 ,
#          0.08307509,  0.20783891,  0.13764237, -0.4281577 ,  0.15276858,
#          0.01332069,  0.08471207, -0.04639114, -0.116381  , -0.2708791 ,
#          0.2795367 ,  0.0945983 ,  0.2505305 , -0.295524  ,  0.3948891 ,
#         -0.22816283,  0.23894951,  0.40304536, -0.10205031,  0.3856473 ,
#          0.05662634,  0.01598852, -0.12932995, -0.22889449,  0.16567674,
#         -0.2053592 , -0.04256397, -0.19209883,  0.44073308, -0.14826164,
#         -0.05771845,  0.1686542 ,  0.21825685,  0.3458681 ,  0.04281062,
#          0.45861763,  0.17017436,  0.06634279,  0.03596178,  0.5645839 ,
#          0.30973005,  0.18795945, -0.3014112 ,  0.1770764 ,  0.01600271],
#        dtype=float32),
#  array([-0.20511556,  0.27138323,  0.1756157 ,  0.10670803,  0.08577301,
#         -0.6706694 ,  0.17035268,  0.7085977 , -0.3328042 , -0.27732524,
#         -0.21996877, -0.5139867 , -0.13448195,  0.10029764,  0.29136628,
#         -0.21795948,  0.12367543, -0.42964014,  0.06215009, -0.8145016 ,
#          0.33798733,  0.10870607,  0.25418606, -0.18116708,  0.03593951,
#          0.08320755, -0.21853958, -0.22329383, -0.33302763,  0.08754588,
#          0.33498472,  0.00684508,  0.15828626, -0.28553596, -0.15808   ,
#          0.4703974 ,  0.05130513, -0.23827429, -0.19687834, -0.64484805,
#          0.09221767, -0.29905272, -0.28409252,  0.02496173,  0.1935796 ,
#         -0.06784598, -0.21491592, -0.11548246,  0.27359453,  0.15508819,
#          0.20514336, -0.25880295, -0.01415453,  0.03302129, -0.11551821,
#          0.08746751,  0.23713677,  0.1508516 , -0.51701385,  0.17297097,
#          0.02287487,  0.11032289, -0.05832656, -0.14696272, -0.33189496,
#          0.34270886,  0.09658208,  0.30144233, -0.37445316,  0.46368766,
#         -0.27122343,  0.30768916,  0.4744842 , -0.13392304,  0.46265104,
#          0.06828498,  0.01983259, -0.15879245, -0.2771416 ,  0.19556133,
#         -0.24231139, -0.06869422, -0.25298676,  0.52161574, -0.17819655,
#         -0.08393218,  0.17646547,  0.2685196 ,  0.41260558,  0.07173315,
#          0.53233004,  0.21367909,  0.0739307 ,  0.04225134,  0.67749125,
#          0.35825747,  0.20761219, -0.3513362 ,  0.21767005,  0.01693234],
#        dtype=float32),
#  array([-0.18520562,  0.24561638,  0.14964563,  0.0951232 ,  0.07621378,
#         -0.6007739 ,  0.15299617,  0.6343709 , -0.2923301 , -0.24860628,
#         -0.18752141, -0.46159187, -0.11145318,  0.09031246,  0.26340997,
#         -0.19083904,  0.10826001, -0.3756059 ,  0.0624279 , -0.73570067,
#          0.30575007,  0.09704771,  0.22620153, -0.14953187,  0.02388016,
#          0.0719125 , -0.19141385, -0.20910122, -0.29714954,  0.07675061,
#          0.30205038,  0.00324914,  0.15074968, -0.25918195, -0.1439532 ,
#          0.42650306,  0.03228772, -0.20977455, -0.17464167, -0.57554984,
#          0.07734005, -0.26374564, -0.2476823 ,  0.02034604,  0.17848843,
#         -0.06798169, -0.18791078, -0.10953569,  0.24628595,  0.14140476,
#          0.18821757, -0.22298391, -0.01915791,  0.01615997, -0.09729226,
#          0.07673798,  0.22563921,  0.14782308, -0.46244594,  0.14442232,
#          0.01561532,  0.10418102, -0.06465471, -0.13241114, -0.2973381 ,
#          0.30101264,  0.09138051,  0.2719262 , -0.3299585 ,  0.41252652,
#         -0.2381733 ,  0.2607103 ,  0.4316239 , -0.11441898,  0.42188832,
#          0.05879227,  0.02569663, -0.14130688, -0.25705677,  0.18405312,
#         -0.23024231, -0.061208  , -0.21845044,  0.47828496, -0.17050178,
#         -0.08227394,  0.16427231,  0.24655342,  0.37657523,  0.05801469,
#          0.47956976,  0.19365539,  0.07955975,  0.04797512,  0.61964536,
#          0.32613876,  0.20846975, -0.3095791 ,  0.1871167 ,  0.00755489],
#        dtype=float32),
#  array([-0.21081023,  0.2746384 ,  0.17498082,  0.11153466,  0.07970883,
#         -0.6737435 ,  0.16744578,  0.69826853, -0.32960626, -0.2800278 ,
#         -0.21507047, -0.5130449 , -0.13042614,  0.09227603,  0.28614476,
#         -0.21882673,  0.12468076, -0.43332723,  0.0678314 , -0.81649935,
#          0.33763945,  0.12075403,  0.2546058 , -0.17213494,  0.0369555 ,
#          0.08741456, -0.22365724, -0.22382294, -0.33241048,  0.09072472,
#          0.33536065,  0.00452117,  0.15937178, -0.28038415, -0.15978731,
#          0.47197774,  0.04361545, -0.24223608, -0.19379464, -0.6525792 ,
#          0.09467578, -0.3051081 , -0.2852854 ,  0.02134643,  0.18681964,
#         -0.06866281, -0.21409744, -0.11442757,  0.26812002,  0.1448912 ,
#          0.20309854, -0.2603454 , -0.01549322,  0.03241377, -0.11944578,
#          0.08235522,  0.24424194,  0.15449397, -0.5230933 ,  0.17509551,
#          0.01700482,  0.11529462, -0.06478403, -0.14601032, -0.33405975,
#          0.340201  ,  0.09540183,  0.30524805, -0.37794495,  0.463257  ,
#         -0.27148196,  0.3097429 ,  0.47646198, -0.13761401,  0.46654722,
#          0.06850457,  0.01541793, -0.15909225, -0.27842623,  0.19162512,
#         -0.24374364, -0.07072367, -0.24515022,  0.52517587, -0.17738277,
#         -0.08199102,  0.1737192 ,  0.2631586 ,  0.4128934 ,  0.06827788,
#          0.5294471 ,  0.2103558 ,  0.07505477,  0.04637216,  0.6782579 ,
#          0.35089448,  0.20845881, -0.35418966,  0.2181074 ,  0.02194749],
#        dtype=float32),
#  array([-0.21157034,  0.28708285,  0.17802916,  0.11045594,  0.08032015,
#         -0.69367534,  0.18674736,  0.7287927 , -0.34164995, -0.27975714,
#         -0.22143985, -0.5328974 , -0.1361622 ,  0.09574844,  0.29831645,
#         -0.23144016,  0.12248516, -0.43902558,  0.06771109, -0.8436766 ,
#          0.3549351 ,  0.12054843,  0.2589256 , -0.17299697,  0.02434924,
#          0.08564633, -0.22479418, -0.23875809, -0.35016358,  0.08758397,
#          0.3448534 ,  0.00150021,  0.16523637, -0.29998276, -0.16989157,
#          0.4925874 ,  0.03948463, -0.2456249 , -0.20774767, -0.6742019 ,
#          0.0949859 , -0.31050038, -0.290797  ,  0.02471677,  0.20195116,
#         -0.07894153, -0.21874985, -0.12206758,  0.2884323 ,  0.15697318,
#          0.21386866, -0.26653263, -0.0191837 ,  0.01901354, -0.1216526 ,
#          0.08394842,  0.25568542,  0.16624705, -0.5457911 ,  0.1644537 ,
#          0.01715661,  0.11931553, -0.07323425, -0.16289149, -0.35005435,
#          0.3515523 ,  0.09974843,  0.3137976 , -0.39643106,  0.47536412,
#         -0.28035167,  0.3205833 ,  0.5028998 , -0.1412925 ,  0.4915975 ,
# ...
#          0.17899635, -0.2547493 , -0.03309853,  0.02684449, -0.13746145,
#          0.05179191,  0.2153455 ,  0.12886384, -0.4981227 ,  0.14496012,
#          0.00708797,  0.10467681, -0.0520438 , -0.15365198, -0.3291759 ,
#          0.32054737,  0.07077296,  0.2862058 , -0.389066  ,  0.42190176,
#         -0.25082272,  0.3292628 ,  0.44396314, -0.13555218,  0.43494254,
#          0.06727608,  0.01817637, -0.16361693, -0.26088846,  0.17384896,
#         -0.2257173 , -0.07392221, -0.24357986,  0.470776  , -0.15415214,
#         -0.09194316,  0.11405727,  0.22921672,  0.38478708,  0.10261597,
#          0.45993194,  0.20517509,  0.06566035,  0.04208342,  0.6277943 ,
#          0.31369725,  0.16347764, -0.31322938,  0.21139121,  0.02419741],
#        dtype=float32),
#  array([-0.15001397,  0.2148512 ,  0.14243296,  0.09232511,  0.05393835,
#         -0.52002877,  0.14362296,  0.52358276, -0.25452507, -0.22058024,
#         -0.16047704, -0.38927224, -0.10459837,  0.06363503,  0.20687796,
#         -0.17027746,  0.08826504, -0.33730355,  0.0445038 , -0.62085366,
#          0.25482288,  0.11343826,  0.19391124, -0.12593725,  0.03035193,
#          0.0634426 , -0.1721928 , -0.16029459, -0.25915304,  0.06591006,
#          0.2425442 ,  0.00309822,  0.11440224, -0.20292355, -0.12332337,
#          0.36852497,  0.04983237, -0.19542569, -0.17595229, -0.5243199 ,
#          0.06519501, -0.23606767, -0.22766206,  0.01043565,  0.1338269 ,
#         -0.0421014 , -0.17220348, -0.07382177,  0.20988871,  0.11010708,
#          0.14764634, -0.22024359, -0.02535209,  0.02907404, -0.11292449,
#          0.04618273,  0.18026556,  0.10528573, -0.41574335,  0.12958065,
#          0.00496317,  0.08352189, -0.04031232, -0.12333512, -0.2735895 ,
#          0.26842335,  0.06037761,  0.24165648, -0.32108995,  0.35888442,
#         -0.2133922 ,  0.27306587,  0.37206092, -0.11796745,  0.35901865,
#          0.04603294,  0.0121213 , -0.13566685, -0.21881908,  0.14057015,
#         -0.18412285, -0.06085511, -0.19753055,  0.39820898, -0.1263361 ,
#         -0.06568743,  0.1103285 ,  0.1914205 ,  0.31219786,  0.07621957,
#          0.3877514 ,  0.1689003 ,  0.04897187,  0.0303167 ,  0.524544  ,
#          0.26577324,  0.13698918, -0.27259552,  0.18221651,  0.02234789],
#        dtype=float32),
#  array([-1.8079793e-01,  2.9803833e-01,  1.7740510e-01,  1.0334684e-01,
#          6.3793182e-02, -6.7536259e-01,  1.8782318e-01,  6.9658756e-01,
#         -3.2154429e-01, -2.8908402e-01, -2.1452132e-01, -5.2770561e-01,
#         -1.3722022e-01,  7.4916445e-02,  2.6700652e-01, -2.2897285e-01,
#          1.0792746e-01, -4.2043495e-01,  7.6148018e-02, -8.1841636e-01,
#          3.4608036e-01,  1.4267939e-01,  2.3679250e-01, -1.5406269e-01,
#          2.2457330e-02,  8.1251867e-02, -2.1811619e-01, -2.1694656e-01,
#         -3.5895774e-01,  7.5419091e-02,  3.0775672e-01,  9.1725867e-03,
#          1.6170865e-01, -2.9048589e-01, -1.5854789e-01,  4.8207468e-01,
#          4.5260884e-02, -2.5956595e-01, -2.3950304e-01, -6.8643355e-01,
#          8.3703399e-02, -3.0584845e-01, -3.0468589e-01,  6.5467879e-04,
#          1.9470571e-01, -8.3681226e-02, -2.1528482e-01, -1.1357341e-01,
#          2.9565001e-01,  1.6498746e-01,  2.1711433e-01, -2.7951002e-01,
#         -3.9740436e-02,  4.5459718e-04, -1.3367708e-01,  5.3029433e-02,
#          2.5160858e-01,  1.6802377e-01, -5.4898274e-01,  1.4461002e-01,
#         -5.5601588e-03,  1.2213005e-01, -6.9664709e-02, -1.9075722e-01,
#         -3.6745036e-01,  3.4699005e-01,  8.5200697e-02,  3.2139850e-01,
#         -4.3292207e-01,  4.5954597e-01, -2.7214324e-01,  3.5433614e-01,
#          5.2168238e-01, -1.4017235e-01,  4.9065486e-01,  8.1291690e-02,
#          3.1166892e-02, -1.9110152e-01, -3.0087161e-01,  2.1556011e-01,
#         -2.7968204e-01, -9.0707168e-02, -2.6147509e-01,  5.4329371e-01,
#         -1.9260237e-01, -1.2073632e-01,  1.4565465e-01,  2.5123587e-01,
#          4.3799841e-01,  1.1430796e-01,  5.0997323e-01,  2.3654132e-01,
#          9.7126335e-02,  4.8539653e-02,  7.1331382e-01,  3.6874273e-01,
#          2.1750844e-01, -3.2169715e-01,  2.3480530e-01,  1.8823626e-02],
#        dtype=float32),
#  array([-0.18225896,  0.27506268,  0.16440657,  0.1072104 ,  0.06336038,
#         -0.649555  ,  0.17900681,  0.6693615 , -0.31491527, -0.2657351 ,
#         -0.19992171, -0.49364957, -0.12673025,  0.08021433,  0.26483324,
#         -0.21197096,  0.11248635, -0.40661716,  0.06560438, -0.7836233 ,
#          0.33023238,  0.12788631,  0.24289985, -0.1632335 ,  0.02503645,
#          0.07661756, -0.2013325 , -0.2121286 , -0.32959732,  0.07731666,
#          0.3100222 ,  0.00298289,  0.15202276, -0.27619463, -0.15322529,
#          0.46193796,  0.0496271 , -0.2402035 , -0.20819041, -0.6405787 ,
#          0.08352689, -0.29711398, -0.2776225 ,  0.01171784,  0.18305592,
#         -0.06163714, -0.20666316, -0.10516993,  0.27589327,  0.14131477,
#          0.19913355, -0.25514206, -0.03169199,  0.01728163, -0.12475099,
#          0.06932227,  0.23524287,  0.14816728, -0.5190297 ,  0.14573891,
#          0.00941297,  0.11018278, -0.06353766, -0.15961601, -0.3314746 ,
#          0.3357181 ,  0.08263289,  0.29731062, -0.39165524,  0.4454506 ,
#         -0.26140586,  0.32171494,  0.47849485, -0.13085951,  0.45952043,
#          0.07456692,  0.03181262, -0.16807139, -0.27655745,  0.19730994,
#         -0.2517529 , -0.07396887, -0.24955578,  0.51095104, -0.1770465 ,
#         -0.09953982,  0.14549015,  0.24880402,  0.4100614 ,  0.0925519 ,
#          0.49825206,  0.21338676,  0.08515714,  0.04769867,  0.6678285 ,
#          0.3479521 ,  0.20120306, -0.3198534 ,  0.21403587,  0.01517752],
#        dtype=float32),
#  array([-0.19900526,  0.27318844,  0.16688988,  0.11501031,  0.07469974,
#         -0.6800674 ,  0.17644978,  0.7066375 , -0.33908957, -0.2698329 ,
#         -0.21460533, -0.50667006, -0.13689592,  0.09536222,  0.27720204,
#         -0.2284548 ,  0.11813476, -0.43463993,  0.04899006, -0.80852115,
#          0.33756763,  0.12608603,  0.24215591, -0.16385421,  0.02814044,
#          0.08122291, -0.2213494 , -0.22639544, -0.33915502,  0.08498025,
#          0.318505  ,  0.00368347,  0.15513012, -0.29078776, -0.16278513,
#          0.46963477,  0.0465221 , -0.23859894, -0.2018024 , -0.66089106,
#          0.08384502, -0.29044053, -0.28474686,  0.01962053,  0.1855471 ,
#         -0.07889209, -0.20864575, -0.11239769,  0.28390664,  0.14942169,
#          0.1863866 , -0.25829926, -0.01501957,  0.01781548, -0.12050191,
#          0.08053814,  0.24298596,  0.14746785, -0.51670086,  0.17366332,
#          0.02486715,  0.11459432, -0.07077585, -0.15943924, -0.34551254,
#          0.34353837,  0.08297454,  0.30186236, -0.39015386,  0.45729166,
#         -0.26921886,  0.30949074,  0.47522265, -0.14781952,  0.46671247,
#          0.0682572 ,  0.02205603, -0.1584064 , -0.28648812,  0.1843827 ,
#         -0.23440668, -0.0700507 , -0.2657873 ,  0.514739  , -0.18811157,
#         -0.097017  ,  0.1635301 ,  0.2701374 ,  0.40871796,  0.08102475,
#          0.51553494,  0.21343637,  0.07661289,  0.04501481,  0.6788737 ,
#          0.34473088,  0.20201127, -0.34939498,  0.22991756,  0.01303009],
#        dtype=float32),
#  array([-0.14404024,  0.21756363,  0.13621035,  0.0873381 ,  0.05378321,
#         -0.517316  ,  0.13617805,  0.52698714, -0.2490703 , -0.21582161,
#         -0.1564248 , -0.3969583 , -0.09234098,  0.06241247,  0.21015358,
#         -0.17078531,  0.09115516, -0.32228962,  0.0525259 , -0.61892986,
#          0.25800362,  0.10970737,  0.18788789, -0.12767562,  0.01871269,
#          0.06383623, -0.16322112, -0.16398847, -0.26412857,  0.06137969,
#          0.24985898,  0.00537956,  0.1186706 , -0.2062253 , -0.12663817,
#          0.36930725,  0.03813334, -0.1935809 , -0.1707687 , -0.51563174,
#          0.0698129 , -0.24025233, -0.21942347,  0.00777038,  0.14922547,
#         -0.04687389, -0.16849233, -0.0845371 ,  0.21155123,  0.11027343,
#          0.15742202, -0.21009424, -0.03298927,  0.01478881, -0.11361102,
#          0.04638069,  0.1859384 ,  0.11406007, -0.4187435 ,  0.11613403,
#          0.00378709,  0.08726381, -0.04610684, -0.12913865, -0.2735414 ,
#          0.26960972,  0.06435771,  0.23768023, -0.31948334,  0.3523372 ,
#         -0.21007928,  0.26372367,  0.3804383 , -0.10458058,  0.36860558,
#          0.0577044 ,  0.02050141, -0.13622384, -0.21769607,  0.15302896,
#         -0.19297679, -0.0623488 , -0.19677909,  0.4065699 , -0.13213842,
#         -0.07788544,  0.11028374,  0.19096759,  0.32720414,  0.07372236,
#          0.39153457,  0.1751462 ,  0.06477343,  0.04054208,  0.5331378 ,
#          0.27995908,  0.15735462, -0.25799245,  0.17631757,  0.01823897],
#        dtype=float32),
#  array([-0.21529254,  0.291692  ,  0.19001684,  0.11755997,  0.09135552,
#         -0.7201382 ,  0.18429185,  0.7533823 , -0.3523618 , -0.30970725,
#         -0.23051588, -0.5610562 , -0.14140466,  0.098619  ,  0.3070973 ,
#         -0.23753627,  0.13435516, -0.47521406,  0.06817424, -0.8680676 ,
#          0.3543505 ,  0.13098578,  0.26448444, -0.18723711,  0.02908309,
#          0.09466997, -0.24322   , -0.23223324, -0.3476338 ,  0.09757171,
#          0.35941103,  0.00196072,  0.16759738, -0.28976193, -0.18012333,
#          0.5051999 ,  0.06288252, -0.25497943, -0.20997784, -0.70887786,
#          0.09597734, -0.33301347, -0.29992738,  0.02599417,  0.20296557,
#         -0.06302972, -0.23313054, -0.12031968,  0.28723598,  0.1548214 ,
#          0.21173629, -0.27965766, -0.01577086,  0.03836668, -0.13362285,
#          0.08059049,  0.2618859 ,  0.16342922, -0.5566994 ,  0.19396225,
#          0.0142618 ,  0.11897373, -0.05745497, -0.14986071, -0.36468458,
#          0.3748948 ,  0.10201526,  0.32378134, -0.4116559 ,  0.49505574,
#         -0.28786755,  0.3289052 ,  0.50806534, -0.15180154,  0.49784222,
#          0.06024091,  0.01516641, -0.17032038, -0.3037015 ,  0.1934249 ,
#         -0.25467205, -0.07051178, -0.26529306,  0.5605408 , -0.17434153,
#         -0.07652943,  0.18321747,  0.28018516,  0.42747474,  0.0660625 ,
#          0.56881106,  0.2242209 ,  0.08219375,  0.04759942,  0.7243061 ,
#          0.36628824,  0.21162245, -0.3842368 ,  0.24116501,  0.02511158],
#        dtype=float32),
#  array([-0.19049935,  0.25195444,  0.16340911,  0.10494231,  0.07126405,
#         -0.62177294,  0.15922819,  0.63743496, -0.30158672, -0.2623544 ,
#         -0.19025256, -0.46352777, -0.12003472,  0.07747063,  0.25102326,
#         -0.1987618 ,  0.11373345, -0.39853743,  0.0544643 , -0.74113744,
#          0.3008679 ,  0.11545797,  0.23052056, -0.14647804,  0.03211063,
#          0.08032631, -0.19999932, -0.19450009, -0.31400225,  0.07636101,
#          0.28952938,  0.00874343,  0.14260429, -0.2617172 , -0.14377455,
#          0.4339119 ,  0.05022695, -0.23305126, -0.19763519, -0.6039379 ,
#          0.07373779, -0.276776  , -0.26285973,  0.01434033,  0.16801739,
#         -0.06636083, -0.1979198 , -0.09493647,  0.24752967,  0.13983326,
#          0.17648022, -0.24131773, -0.02730097,  0.02725497, -0.11941445,
#          0.06858306,  0.2285821 ,  0.13359767, -0.48152718,  0.15571691,
#          0.01685937,  0.10757712, -0.05414569, -0.14347877, -0.32352093,
#          0.31663868,  0.07923348,  0.28133348, -0.36173967,  0.42345476,
#         -0.24326347,  0.3003983 ,  0.4402479 , -0.13648048,  0.4296156 ,
#          0.0653472 ,  0.01276203, -0.15251115, -0.26025233,  0.16947429,
#         -0.2196836 , -0.05836485, -0.22561651,  0.4759841 , -0.16367184,
#         -0.08343285,  0.14743909,  0.2461518 ,  0.37453294,  0.08093015,
#          0.47030282,  0.19883902,  0.0670051 ,  0.04384896,  0.6272802 ,
#          0.32435477,  0.17895724, -0.3236948 ,  0.20649402,  0.01835267],
#        dtype=float32),
#  array([-0.20414783,  0.26393405,  0.17259972,  0.10797434,  0.08174273,
#         -0.6603213 ,  0.16629766,  0.68416876, -0.32436043, -0.2741881 ,
#         -0.20809045, -0.49811077, -0.13091882,  0.09266834,  0.27408078,
#         -0.21406288,  0.11988762, -0.42263505,  0.05512245, -0.79055226,
#          0.3241464 ,  0.11602778,  0.24585411, -0.16510463,  0.03786353,
#          0.08637229, -0.21399061, -0.21236825, -0.32562009,  0.0861423 ,
#          0.3219851 ,  0.00449038,  0.15040843, -0.27538213, -0.15663232,
#          0.46152154,  0.05218209, -0.24088812, -0.19672136, -0.6368801 ,
#          0.08647535, -0.2940416 , -0.27894565,  0.01790089,  0.18329722,
#         -0.06652369, -0.21174523, -0.11057855,  0.26487738,  0.14623114,
#          0.19092864, -0.256509  , -0.01323991,  0.03164016, -0.12179319,
#          0.08145854,  0.2377028 ,  0.14655665, -0.50514895,  0.16874477,
#          0.02069795,  0.11285699, -0.05881445, -0.1468588 , -0.33281854,
#          0.3337014 ,  0.0887929 ,  0.2985474 , -0.37327257,  0.45209974,
#         -0.26092127,  0.30550262,  0.46287313, -0.13941345,  0.4528059 ,
#          0.06129932,  0.01522816, -0.15741006, -0.27527985,  0.1784398 ,
#         -0.23152067, -0.06674292, -0.24328583,  0.5064741 , -0.17646123,
#         -0.08402417,  0.16308978,  0.25866452,  0.39568824,  0.07136495,
#          0.51097965,  0.20623358,  0.07020909,  0.03875493,  0.6618373 ,
#          0.34556034,  0.19583264, -0.34755054,  0.21670741,  0.01882676],
#        dtype=float32),
#  array([-0.1992269 ,  0.27392894,  0.1698599 ,  0.11065999,  0.07360597,
#         -0.66072726,  0.17666024,  0.6870954 , -0.32420868, -0.2723932 ,
#         -0.20600708, -0.5049046 , -0.12522542,  0.09060696,  0.27609384,
#         -0.22099735,  0.11896184, -0.41759938,  0.06568256, -0.800764  ,
#          0.33548814,  0.12057739,  0.24791138, -0.16429797,  0.02470603,
#          0.08207184, -0.21207982, -0.22097634, -0.33448678,  0.08663698,
#          0.32733086,  0.0040636 ,  0.1575541 , -0.2785382 , -0.15873152,
#          0.47257006,  0.04171905, -0.23635352, -0.19950947, -0.6448004 ,
#          0.09255187, -0.30505744, -0.28153062,  0.01684252,  0.18836868,
#         -0.06353345, -0.21078292, -0.11189103,  0.27535388,  0.14651658,
#          0.20627317, -0.25728762, -0.02249822,  0.01661121, -0.12265341,
#          0.07404733,  0.23812847,  0.15458031, -0.52669066,  0.15670909,
#          0.01135957,  0.10913225, -0.06281335, -0.15496546, -0.33540684,
#          0.3354853 ,  0.09178445,  0.3016619 , -0.38594726,  0.4555445 ,
#         -0.26408252,  0.31380528,  0.482032  , -0.13230751,  0.46580482,
#          0.06911975,  0.02793985, -0.16364028, -0.27757534,  0.19632027,
#         -0.2504515 , -0.07554051, -0.24734803,  0.5205779 , -0.1798402 ,
#         -0.09588847,  0.16640311,  0.25904423,  0.41182378,  0.07717444,
#          0.51786715,  0.21389708,  0.08441179,  0.04855682,  0.6754766 ,
#          0.3550037 ,  0.21233083, -0.3378796 ,  0.21625061,  0.01732469],
#        dtype=float32),
#  array([-0.18469478,  0.26035032,  0.16171822,  0.10828044,  0.07443074,
#         -0.6395677 ,  0.16876939,  0.6529584 , -0.31532285, -0.25825658,
#         -0.20417559, -0.47260386, -0.12892687,  0.08079311,  0.25648302,
#         -0.20987204,  0.11089572, -0.41076112,  0.04916652, -0.7615544 ,
#          0.3100535 ,  0.12479904,  0.2295445 , -0.15711267,  0.03239249,
#          0.08042137, -0.2110542 , -0.20864595, -0.32215878,  0.08531689,
#          0.2930662 ,  0.00454237,  0.13827291, -0.27046654, -0.14995967,
#          0.4431883 ,  0.04558856, -0.22954382, -0.19408816, -0.6290842 ,
#          0.07953811, -0.2787282 , -0.27041164,  0.01462839,  0.17081806,
#         -0.0765097 , -0.2002981 , -0.10184721,  0.26578042,  0.13585083,
#          0.1754671 , -0.25202146, -0.01452425,  0.02250435, -0.12264516,
#          0.06992181,  0.22485621,  0.13249831, -0.49265653,  0.16455446,
#          0.02137755,  0.10558826, -0.0589781 , -0.14742999, -0.3324701 ,
#          0.32793358,  0.07625346,  0.28895614, -0.37648678,  0.43057138,
#         -0.26112065,  0.30586618,  0.45257086, -0.14623345,  0.43613866,
#          0.06161403,  0.01320202, -0.1540401 , -0.27018026,  0.16966054,
#         -0.22177747, -0.06459363, -0.24892838,  0.48386016, -0.16960737,
#         -0.09064649,  0.1457455 ,  0.2554322 ,  0.38670158,  0.08071743,
#          0.4815132 ,  0.20152305,  0.06429821,  0.0399714 ,  0.636475  ,
#          0.32633194,  0.18055901, -0.331227  ,  0.21875615,  0.01527247],
#        dtype=float32),
#  ...]

# %%
len(X)
# Out:
# 5569

# %%
#independent features
X_new=np.array(X)
# Out:
# /var/folders/pg/0spg6ylx1qq_w7r30vn2y_5h0000gn/T/ipykernel_1722/799135103.py:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X_new=np.array(X)

# %%
messages.shape
# Out:
# (5572, 2)

# %%
X_new.shape
# Out:
# (5569,)

# %%
X_new[0].shape
# Out:
# (100,)

# %%
#dependent feature
#Output features
y=messages[list(map(lambda x: len(x)>0,corpus))]
y=pd.get_dummies(y['label'])
y=y.iloc[:,0].values

# %%
y.shape
# Out:
# (5569,)

# %%
X[0].reshape(1,-1).shape
# Out:
# (1, 100)

# %%
#this is the final independent features
import pandas as pd
df=pd.DataFrame()
for i in range(0,len(X)):
    df=df.append(pd.DataFrame(X[i].reshape(1,-1)),ignore_index=True)
# Out:
# /var/folders/pg/0spg6ylx1qq_w7r30vn2y_5h0000gn/T/ipykernel_1722/896054354.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(pd.DataFrame(X[i].reshape(1,-1)),ignore_index=True)

# %%
df.shape
# Out:
# (5569, 100)

# %%
df.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.140610  0.208715  0.128140  0.083141  0.053187 -0.500768  0.137725
# 1 -0.136879  0.187495  0.115749  0.075326  0.056519 -0.452725  0.112714
# 2 -0.144545  0.226595  0.144200  0.099859  0.040332 -0.541643  0.138092
# 3 -0.202212  0.281546  0.171305  0.117871  0.076312 -0.685135  0.178996
# 4 -0.171625  0.232274  0.150584  0.095496  0.068947 -0.569989  0.150546
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.512731 -0.240799 -0.204101  ...  0.380211  0.163066  0.057600  0.035060
# 1  0.467063 -0.219535 -0.177505  ...  0.350221  0.138600  0.046369  0.022753
# 2  0.506534 -0.253027 -0.236525  ...  0.372322  0.170464  0.039911  0.029035
# 3  0.709087 -0.336663 -0.268874  ...  0.527549  0.215259  0.076611  0.048020
# 4  0.597628 -0.283294 -0.233595  ...  0.445312  0.178739  0.070893  0.042622
#
#          94        95        96        97        98        99
# 0  0.512355  0.259776  0.150461 -0.252454  0.168814  0.014490
# 1  0.448464  0.227461  0.136041 -0.238670  0.156199  0.006676
# 2  0.519040  0.253814  0.097928 -0.278234  0.192148  0.036546
# 3  0.688455  0.355500  0.223284 -0.355307  0.230390  0.012656
# 4  0.579883  0.299081  0.180330 -0.302552  0.189038  0.010570
#
# [5 rows x 100 columns]

# %%
df['Output']=y

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.140610  0.208715  0.128140  0.083141  0.053187 -0.500768  0.137725
# 1 -0.136879  0.187495  0.115749  0.075326  0.056519 -0.452725  0.112714
# 2 -0.144545  0.226595  0.144200  0.099859  0.040332 -0.541643  0.138092
# 3 -0.202212  0.281546  0.171305  0.117871  0.076312 -0.685135  0.178996
# 4 -0.171625  0.232274  0.150584  0.095496  0.068947 -0.569989  0.150546
#
#           7         8         9  ...        91        92        93        94  \
# 0  0.512731 -0.240799 -0.204101  ...  0.163066  0.057600  0.035060  0.512355
# 1  0.467063 -0.219535 -0.177505  ...  0.138600  0.046369  0.022753  0.448464
# 2  0.506534 -0.253027 -0.236525  ...  0.170464  0.039911  0.029035  0.519040
# 3  0.709087 -0.336663 -0.268874  ...  0.215259  0.076611  0.048020  0.688455
# 4  0.597628 -0.283294 -0.233595  ...  0.178739  0.070893  0.042622  0.579883
#
#          95        96        97        98        99  Output
# 0  0.259776  0.150461 -0.252454  0.168814  0.014490       1
# 1  0.227461  0.136041 -0.238670  0.156199  0.006676       1
# 2  0.253814  0.097928 -0.278234  0.192148  0.036546       0
# 3  0.355500  0.223284 -0.355307  0.230390  0.012656       1
# 4  0.299081  0.180330 -0.302552  0.189038  0.010570       1
#
# [5 rows x 101 columns]

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 96        0
# 97        0
# 98        0
# 99        0
# Output    0
# Length: 101, dtype: int64

# %%
#independent features
X=df

# %%
X.isnull().sum()
# Out:
# 0     12
# 1     12
# 2     12
# 3     12
# 4     12
#       ..
# 95    12
# 96    12
# 97    12
# 98    12
# 99    12
# Length: 100, dtype: int64

# %%
y=df['Output']

# %%
#Train Test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20)

# %%
X_train.head()
# Out:
#              0         1         2         3         4         5         6  \
# 4135 -0.185327  0.226393  0.151505  0.088859  0.075902 -0.566270  0.141667
# 1227 -0.184639  0.270452  0.169751  0.111803  0.061142 -0.651695  0.166057
# 2499 -0.148331  0.222981  0.124266  0.091680  0.055271 -0.516651  0.138006
# 5234 -0.189488  0.271113  0.185719  0.110594  0.066972 -0.658729  0.168382
# 2509 -0.148486  0.218620  0.130649  0.085716  0.059304 -0.522291  0.139290
#
#              7         8         9  ...        91        92        93  \
# 4135  0.592858 -0.277980 -0.244792  ...  0.174353  0.063874  0.038120
# 1227  0.635725 -0.311365 -0.278414  ...  0.206108  0.059573  0.038571
# 2499  0.538919 -0.253235 -0.211933  ...  0.174953  0.068438  0.036288
# 5234  0.657594 -0.316822 -0.284514  ...  0.207177  0.056986  0.037142
# 2509  0.543108 -0.255686 -0.209744  ...  0.168749  0.061277  0.034412
#
#             94        95        96        97        98        99  Output
# 4135  0.573792  0.302782  0.178669 -0.303648  0.182143  0.026012       1
# 1227  0.640313  0.322321  0.154788 -0.333059  0.222568  0.032587       0
# 2499  0.526949  0.273465  0.164904 -0.260148  0.171495  0.006736       1
# 5234  0.653398  0.327419  0.157079 -0.347820  0.224619  0.034069       0
# 2509  0.532292  0.274840  0.162252 -0.264215  0.172097  0.008068       1
#
# [5 rows x 101 columns]

# %%
y_train
# Out:
# 4135    1
# 1227    0
# 2499    1
# 5234    0
# 2509    1
#        ..
# 1538    1
# 843     1
# 2564    1
# 5121    1
# 4960    1
# Name: Output, Length: 4445, dtype: uint8

# %%
from sklearn.ensemble import RandomForestClassifier
classifier=RandomForestClassifier()

# %%
classifier.fit(X_train,y_train)
# Out:
# /Users/udaykiran/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   warnings.warn(
# RandomForestClassifier()

# %%
y_pred=classifier.predict(X_test)
# Out:
# /Users/udaykiran/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   warnings.warn(

# %%
from sklearn.metrics import accuracy_score,classification_report
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9973021582733813

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       157
#            1       1.00      1.00      1.00       955
#
#     accuracy                           1.00      1112
#    macro avg       1.00      0.99      0.99      1112
# weighted avg       1.00      1.00      1.00      1112
